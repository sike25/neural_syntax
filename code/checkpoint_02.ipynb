# %%
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ### Hyperparameters

# %%
# the number of objects in each world
WORLD_SIZE = 5

# the dimension of the feature vector of each object
# as produced by the encoder
OBJECT_FEATURE_DIMENSION = 6

# the dimension of the speaker's generated vector representation
NEURALESE_DIMENSION = 12

# %% [markdown]
# ### Model Components

# %%
class ObjectEncoder(nn.Module):
    """
    Encodes a single (3x3) Object into a feature vector
    Input     : [[001][100][010]] or Purple-Cirle-No-Outline. See metadata.json
    InputSize : (3,3)
    OutputSize: (OBJECT_FEATURE_DIMENSION)
    """
    def __init__(self, output_dimension=OBJECT_FEATURE_DIMENSION):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size=2),  # → (batch, 4, 2, 2)
            nn.Flatten(),                    # → (batch, 16)
            nn.Linear(16, output_dimension)
        )

    def forward(self, x):
        return self.encoder(x)

# %%
class Speaker(nn.Module):
    """
    Transforms the encoded objects in world W + boolean inclusion mask for target subset X
    into a representative vector

    InputSize : (WORLD_SIZE * OBJECT_FEATURE_DIMENSION) + WORLD_SIZE)
    OutputSize: (NEURALESE_DIMENSION)
    """
    def __init__(self, input_dimension=(WORLD_SIZE * OBJECT_FEATURE_DIMENSION) + WORLD_SIZE,
                 output_dimension=NEURALESE_DIMENSION):
        super().__init__()
        self.speaker_net = nn.Sequential(
            nn.Linear(input_dimension, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, output_dimension)
        )

    def forward(self, x):
        return self.speaker_net(x)

# %%
class Listener(nn.Module):
    """
    Takes the resultant vector from the speaker, along with W_i (an element of the world W)
    and predicts whether this element belongs to X, the target subset.

    InputSize : (NEURALESE_DIMENSION + OBJECT_FEATURE_DIMENSION)
    OutputSize: (1) -> logit for binary classification
    """
    def __init__(self, input_dimension=NEURALESE_DIMENSION + OBJECT_FEATURE_DIMENSION,
                 output_dimension=1):
        super().__init__()
        self.listener_net = nn.Sequential(
            nn.Linear(input_dimension, 32),
            nn.ReLU(),
            nn.Linear(32, 8),
            nn.ReLU(),
            nn.Linear(8, output_dimension)
        )

    def forward(self, x):
        return self.listener_net(x)

# %%
class SpeakerListenerSystem(nn.Module):
    """
    The end-to-end system.
    Encoder -> Speaker -> Listener
    """
    def __init__(self, world_size, feature_dimension, neuralese_dimension):
        super().__init__()

        self.world_size          = world_size
        self.feature_dimension   = feature_dimension
        self.neuralese_dimension = neuralese_dimension

        speaker_input_size  = (self.world_size * self.feature_dimension) + self.world_size
        listener_input_size = self.neuralese_dimension + self.feature_dimension

        self.encoder  = ObjectEncoder(output_dimension=self.feature_dimension)
        self.speaker  = Speaker(input_dimension=speaker_input_size, output_dimension=neuralese_dimension)
        self.listener = Listener(input_dimension=listener_input_size, output_dimension=1)


    def forward(self, W, X_mask, return_neuralese_only=False):
        """
        W:      A batch of worlds.
                Each world is a set of (3x3) objects.
                Tensor of shape (batch_size, world_size, 3, 3).

        X_mask: A batch of boolean masks
                Each value indicated whether the object at that index in W
                is included in the target subset X
                Tensor of shape (batch_size, world_size)
        """
        batch_size = W.shape[0]

        ### STEP 1: Encode all objects in the world
        # Reshape for batch processing ny the encoder (B, 5, 3, 3) -> (B*5, 1, 3, 3)
        W_flat = W.view(-1, 1, 3, 3)
        # Get features for all objects: (B*5, feature_dim)
        object_features_flat = self.encoder(W_flat)
        # Reshape back to per-batch item:(B, 5, feature_dim)
        object_features = object_features_flat.view(batch_size, self.world_size, self.feature_dimension)


        ### STEP 2: Assemble the inputs to the speaker model
        # Flatten object features: (B, 5, feature_dim) -> (B, 5*feature_dim)
        V_W =  object_features.view(batch_size, -1)
        # Create the indicator mask
        M_X = X_mask
        # Concatenate features and mask
        speaker_input = torch.cat([V_W, M_X], dim=1)


        ### STEP 3: Speaker generates neuralese
        # representation has shape (B, neuralese_dimension)
        representation = self.speaker(speaker_input)

        if return_neuralese_only:
            return representation

        ### STEP 4: Prepare the listener's input
        # The listener needs to pair the speaker's representation with each object feature
        # Expand the representation to match the number of objects
        # (B, rep_dim) -> (B, 1, rep_dim) -> (B, world_size, rep_dim)
        r_expanded = representation.unsqueeze(1).repeat(1, self.world_size, 1)
        # Concatenate with object features: (B, 5, rep_dim) + (B, 5, feature_dim)
        listener_input = torch.cat([r_expanded, object_features], dim=2)


        ### STEP 5: Shuffle inputs to the listener
        # This is to avoid the speaker simply learning to tell the listener about X_mask
        # without learning anything about the objects in X themselves.
        # Create a random permutation for each item in the batch
        shuffled_indices = [torch.randperm(self.world_size) for _ in range(batch_size)]
        # Apply the shuffle
        shuffled_input   = torch.stack([features[p] for features, p in zip(listener_input, shuffled_indices)])
        shuffled_labels  = torch.stack([labels[p]   for labels,   p in zip(X_mask, shuffled_indices)])


        ### STEP 6: Listener makes an inclusion prediction for each object
        # Reshape for batch processing by the listener
        # (B, 5, rep_dim + feature_dim) -> (B*5, rep_dim + feature_dim)
        listener_input_flat = shuffled_input.view(-1, self.neuralese_dimension + self.feature_dimension)
        # Get predictions (logits) -> (B*5, 1)
        predictions_flat = self.listener(listener_input_flat)
        # Reshape back to (B, world_size)
        predictions = predictions_flat.view(batch_size, self.world_size)

        return predictions, shuffled_labels

# %%
class Translator(nn.Module):
    """
    Translates neuralese representation V into natural language rule R.

    Takes the learned communication vector V (produced by the speaker) and
    predicts the original rule R as a fixed-length sequence of tokens.
    Each position in the sequence is predicted independently via classification
    over the vocabulary (features, logical operators, and blank token).
    """
    def __init__(self, neuralese_dimension=NEURALESE_DIMENSION,
                 max_rule_length=3, vocab_size=13, hidden_dimension=128):
        super().__init__()
        self.max_rule_length     = max_rule_length
        self.neuralese_dimension = neuralese_dimension
        self.vocab_size          = vocab_size

        self.translation_net = nn.Sequential(
        nn.Linear(neuralese_dimension, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, max_rule_length * vocab_size)
        )


    def forward(self, V):
        """
        Arguments:
        V : A batch of neuralese representations (batch_size,  neuralese_dimension)

        Returns:
        logits : (batch_size, max_rule_length, vocab_size)
        """
        batch_size = V.shape[0]

        output = self.translation_net(V)  # (batch_size, max_rule_length * vocab_size)
        logits = output.view(batch_size, self.max_rule_length, self.vocab_size)

        return logits

# Alternative architectures to consider:

# Autoregressive (if you want token dependencies):
# Use an RNN/LSTM that generates one token at a time
# token_1 depends only on V
# token_2 depends on V and token_1, etc.

# Deeper MLP with position embeddings:
# Add learnable position embeddings to help the model
# know which position it's predicting

# %% [markdown]
# ### Data Loading

# %%
def generate_batch(batch_size, world_size):
    """Generates a batch of dummy data"""

    # Random 3x3 objects for the world
    W_batch = torch.rand(batch_size, world_size, 3, 3)

    # Random binary masks
    X_mask_batch = torch.randint(0, 2, (batch_size, world_size)).float()

    # Ensure at least one object is selected in each world
    for i in range(batch_size):
        if X_mask_batch[i].sum() == 0:
            # Randomly select one object
            X_mask_batch[i, random.randint(0, world_size-1)] = 1.0


    return W_batch, X_mask_batch

# %%
def load_dataset(path='dataset.npz'):
    """Load the real dataset from npz file"""

    data = np.load(path, allow_pickle=True)

    W = data['W']
    X_mask = data['X_mask']
    rule_encodings = data['rule_encodings']
    rule_texts = data['rule_texts']

    # Load metadata
    metadata_path = path.replace('.npz', '_metadata.json')
    with open(metadata_path, 'r') as f:
        metadata = json.load(f)

    return W, X_mask, rule_encodings, rule_texts, metadata

# %%
def split_dataset(W, X_mask, rule_encodings, rule_texts,
                speaker_listener_ratio=0.5,
                translator_train_ratio=0.4,
                translator_test_ratio =0.1,
                seed=42):

    """
    Split dataset into three portions with shuffling:
    1. Speaker-Listener training (50%)
    2. Translator training (40%)
    3. Translator testing (10%)

    Args:
        W: World matrices [N, 5, 3, 3]
        X_mask: Subset masks [N, 5]
        rule_encodings: Rule encodings [N, ...]
        rule_texts: Rule text strings [N]
        speaker_listener_ratio: Fraction for speaker-listener
        translator_train_ratio: Fraction for translator training
        translator_test_ratio: Fraction for translator testing
        seed: Random seed for reproducibility

    Returns:
        Dictionary with all splits
    """

    assert abs(speaker_listener_ratio + translator_train_ratio + translator_test_ratio - 1.0) < 1e-6, \
           "Ratios must sum to 1.0"
    np.random.seed(seed)

    # Shuffle the dataset
    N_total = len(W)
    indices = np.random.permutation(N_total)

    # Calculate sizes of data portions
    speaker_listener_size = int(N_total * speaker_listener_ratio)
    translator_train_size = int(N_total * translator_train_ratio)
    translator_test_size  = int(N_total * translator_test_ratio)

    # Calculate indices for splitting
    speaker_listener_idx = indices[:speaker_listener_size]
    translator_train_idx = indices[speaker_listener_size:speaker_listener_size + translator_train_size]
    translator_test_idx  = indices[speaker_listener_size + translator_train_size:]

    # Split the data
    split_dataset = {
        'speaker_listener': {
            'W':              torch.tensor(W[speaker_listener_idx]).float(),
            'X_mask':         torch.tensor(X_mask[speaker_listener_idx]).float(),
            'rule_encodings': rule_encodings[speaker_listener_idx],
            'rule_texts':     rule_texts[speaker_listener_idx]
        },
        'translator_train': {
            'W':              torch.tensor(W[translator_train_idx]).float(),
            'X_mask':         torch.tensor(X_mask[translator_train_idx]).float(),
            'rule_encodings': rule_encodings[translator_train_idx],
            'rule_texts':     rule_texts[translator_train_idx]
        },
        'translator_test': {
            'W':              torch.tensor(W[translator_test_idx]).float(),
            'X_mask':         torch.tensor(X_mask[translator_test_idx]).float(),
            'rule_encodings': rule_encodings[translator_test_idx],
            'rule_texts':     rule_texts[translator_test_idx]
        }
    }

    print("Dataset Split:")
    print(f"  Speaker-Listener:  {len(speaker_listener_idx):,} ({speaker_listener_ratio*100:.0f}%)")
    print(f"  Translator Train:  {len(translator_train_idx):,} ({translator_train_ratio*100:.0f}%)")
    print(f"  Translator Test:   {len(translator_test_idx):,}  ({translator_test_ratio*100:.0f}%)")
    print(f"  Total:             {N_total:,}")

    return split_dataset

# %%
# Load dataset and split
W_data, X_mask_data, rule_encodings_data, rule_texts_data, metadata = load_dataset('dataset.npz')
dataset_splits = split_dataset(W_data, X_mask_data, rule_encodings_data, rule_texts_data)

def load_batch(split_name, start_idx, batch_size, include_rules=False):
    """Load a batch of data from the specified split"""
    split = dataset_splits[split_name]
    end_idx = start_idx + batch_size

    Wb = split['W'][start_idx:end_idx]
    Xb = split['X_mask'][start_idx:end_idx]

    if include_rules:
        rb = split['rule_tokens'][start_idx:end_idx]
        return Wb, Xb, rb

    return Wb, Xb
# Out:
# Dataset Split:
#   Speaker-Listener:  852,916 (50%)
#   Translator Train:  682,333 (40%)
#   Translator Test:   170,584  (10%)
#   Total:             1,705,833

# %% [markdown]
# ### Visualizations

# %%
def plot_metric(values, step_size, metric_name, save_path=None, figsize=(10,6)):
    """
    Plot training metric (loss or accuracy) over epochs

    Args:
        values: List or array of metric values recorded during training
        step_size: Number of epochs between each recorded value (e.g., 50 if you log every 50 epochs)
        metric_name: Name of the metric for labels (e.g., 'Loss', 'Accuracy')
        save_path: Optional path to save the figure (e.g., 'speaker_loss.png')
        figsize: Tuple specifying figure size (width, height)

    Example:
        plot_metric(losses, 50, 'Loss', save_path='speaker_loss.png')
        plot_metric(accuracies, 50, 'Accuracy', save_path='speaker_accuracy
    """

    # Calculate epochs based on step size
    epochs = np.arange(step_size, len(values)*step_size + 1, step_size)

    # Create the plot
    plt.figure(figsize=figsize)
    plt.plot(epochs, values, linewidth=2, color="#B41F1F" if 'loss' in metric_name.lower() else "#35B457")

    # Styling
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric_name, fontsize=12)
    plt.title(f'{metric_name} over Training', fontsize=14)

    # Tight layout for better spacing
    plt.tight_layout()

    # Save if path provided
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to {save_path}")

    plt.show()

# %% [markdown]
# ## The  Speaker Listener

# %% [markdown]
# ### Training

# %%
# Hyperparameters for training
BATCH_SIZE    = 32 # 32
NUM_EPOCHS    = 2  # 10
LEARNING_RATE = 1e-4

# %%
# Instantiate the system
model = SpeakerListenerSystem(
    world_size          = WORLD_SIZE,
    feature_dimension   = OBJECT_FEATURE_DIMENSION,
    neuralese_dimension = NEURALESE_DIMENSION,
)

# Use BCEWithLogitsLoss because our model outputs raw logits (more stable)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
step = 0
start_index = 0
N_DATA = len(dataset_splits['speaker_listener']['W'])

losses = []
accuracies = []

print("Starting speaker-listener training...")
for epoch in range(NUM_EPOCHS):
    start_index = 0

    # Stop when we run out of data
    while start_index < N_DATA:
        batch_size = min(BATCH_SIZE, N_DATA - start_index)

        # Load a batch of speaker-listener training data
        W, X_mask = load_batch('speaker_listener', start_index, batch_size)
        start_index += BATCH_SIZE
        step += 1

        # Forward pass - y_truth is the shuffled X_mask
        optimizer.zero_grad()
        y_logits, y_truth = model(W, X_mask)

        # Calculate loss - (y_truth serves as the ground truth)
        loss = criterion(y_logits, y_truth)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        if (step + 1) % 500 == 0:
            # Track data consumption
            print(f"Epoch: {epoch}. start_index: {start_index}, end_index: {start_index + batch_size}")

            # Calculate accuracy for monitoring
            preds    = torch.sigmoid(y_logits) > 0.5
            accuracy = (preds.float() == y_truth).float().mean()
            print(f"Step [{step+1}/{NUM_EPOCHS * (N_DATA // BATCH_SIZE) + 1}], Loss: {loss.item():.4f}, Accuracy: {accuracy.item():.4f}")

            # Store metrics
            losses.append(loss.item())
            accuracies.append(accuracy.item())

print("Training finished.")
# Out:
# Starting speaker-listener training...
# Epoch: 0. start_index: 15968, end_index: 16000
# Step [500/53307], Loss: 0.6413, Accuracy: 0.6938
# Epoch: 0. start_index: 31968, end_index: 32000
# Step [1000/53307], Loss: 0.6013, Accuracy: 0.6812
# Epoch: 0. start_index: 47968, end_index: 48000
# Step [1500/53307], Loss: 0.6076, Accuracy: 0.6750
# Epoch: 0. start_index: 63968, end_index: 64000
# Step [2000/53307], Loss: 0.5832, Accuracy: 0.6938
# Epoch: 0. start_index: 79968, end_index: 80000
# Step [2500/53307], Loss: 0.5412, Accuracy: 0.7188
# Epoch: 0. start_index: 95968, end_index: 96000
# Step [3000/53307], Loss: 0.4971, Accuracy: 0.7625
# Epoch: 0. start_index: 111968, end_index: 112000
# Step [3500/53307], Loss: 0.4969, Accuracy: 0.7375
# Epoch: 0. start_index: 127968, end_index: 128000
# Step [4000/53307], Loss: 0.4468, Accuracy: 0.7937
# Epoch: 0. start_index: 143968, end_index: 144000
# Step [4500/53307], Loss: 0.4418, Accuracy: 0.7563
# Epoch: 0. start_index: 159968, end_index: 160000
# Step [5000/53307], Loss: 0.3880, Accuracy: 0.7875
# Epoch: 0. start_index: 175968, end_index: 176000
# Step [5500/53307], Loss: 0.4101, Accuracy: 0.7688
# Epoch: 0. start_index: 191968, end_index: 192000
# Step [6000/53307], Loss: 0.3814, Accuracy: 0.7750
# Epoch: 0. start_index: 207968, end_index: 208000
# Step [6500/53307], Loss: 0.3611, Accuracy: 0.8125
# Epoch: 0. start_index: 223968, end_index: 224000
# Step [7000/53307], Loss: 0.3968, Accuracy: 0.8188
# Epoch: 0. start_index: 239968, end_index: 240000
# Step [7500/53307], Loss: 0.3620, Accuracy: 0.8562
# Epoch: 0. start_index: 255968, end_index: 256000
# Step [8000/53307], Loss: 0.2965, Accuracy: 0.8562
# Epoch: 0. start_index: 271968, end_index: 272000
# Step [8500/53307], Loss: 0.2949, Accuracy: 0.8625
# Epoch: 0. start_index: 287968, end_index: 288000
# Step [9000/53307], Loss: 0.3382, Accuracy: 0.8562
# Epoch: 0. start_index: 303968, end_index: 304000
# Step [9500/53307], Loss: 0.2984, Accuracy: 0.8813
# Epoch: 0. start_index: 319968, end_index: 320000
# Step [10000/53307], Loss: 0.2775, Accuracy: 0.8562
# Epoch: 0. start_index: 335968, end_index: 336000
# Step [10500/53307], Loss: 0.2651, Accuracy: 0.8687
# Epoch: 0. start_index: 351968, end_index: 352000
# Step [11000/53307], Loss: 0.2993, Accuracy: 0.8562
# Epoch: 0. start_index: 367968, end_index: 368000
# Step [11500/53307], Loss: 0.2568, Accuracy: 0.8813
# Epoch: 0. start_index: 383968, end_index: 384000
# Step [12000/53307], Loss: 0.3076, Accuracy: 0.8375
# Epoch: 0. start_index: 399968, end_index: 400000
# Step [12500/53307], Loss: 0.2947, Accuracy: 0.8750
# Epoch: 0. start_index: 415968, end_index: 416000
# Step [13000/53307], Loss: 0.2669, Accuracy: 0.8938
# Epoch: 0. start_index: 431968, end_index: 432000
# Step [13500/53307], Loss: 0.2180, Accuracy: 0.9250
# Epoch: 0. start_index: 447968, end_index: 448000
# Step [14000/53307], Loss: 0.2267, Accuracy: 0.8938
# Epoch: 0. start_index: 463968, end_index: 464000
# Step [14500/53307], Loss: 0.2284, Accuracy: 0.9125
# Epoch: 0. start_index: 479968, end_index: 480000
# Step [15000/53307], Loss: 0.2013, Accuracy: 0.9250
# Epoch: 0. start_index: 495968, end_index: 496000
# Step [15500/53307], Loss: 0.2068, Accuracy: 0.9187
# Epoch: 0. start_index: 511968, end_index: 512000
# Step [16000/53307], Loss: 0.1443, Accuracy: 0.9375
# Epoch: 0. start_index: 527968, end_index: 528000
# Step [16500/53307], Loss: 0.1964, Accuracy: 0.9187
# Epoch: 0. start_index: 543968, end_index: 544000
# Step [17000/53307], Loss: 0.2373, Accuracy: 0.9187
# Epoch: 0. start_index: 559968, end_index: 560000
# Step [17500/53307], Loss: 0.1991, Accuracy: 0.9125
# Epoch: 0. start_index: 575968, end_index: 576000
# Step [18000/53307], Loss: 0.2439, Accuracy: 0.9187
# Epoch: 0. start_index: 591968, end_index: 592000
# Step [18500/53307], Loss: 0.1707, Accuracy: 0.9375
# Epoch: 0. start_index: 607968, end_index: 608000
# Step [19000/53307], Loss: 0.1531, Accuracy: 0.9312
# Epoch: 0. start_index: 623968, end_index: 624000
# Step [19500/53307], Loss: 0.1486, Accuracy: 0.9438
# Epoch: 0. start_index: 639968, end_index: 640000
# Step [20000/53307], Loss: 0.2278, Accuracy: 0.9000
# Epoch: 0. start_index: 655968, end_index: 656000
# Step [20500/53307], Loss: 0.1707, Accuracy: 0.9375
# Epoch: 0. start_index: 671968, end_index: 672000
# Step [21000/53307], Loss: 0.2095, Accuracy: 0.9125
# Epoch: 0. start_index: 687968, end_index: 688000
# Step [21500/53307], Loss: 0.1563, Accuracy: 0.9312
# Epoch: 0. start_index: 703968, end_index: 704000
# Step [22000/53307], Loss: 0.1266, Accuracy: 0.9500
# Epoch: 0. start_index: 719968, end_index: 720000
# Step [22500/53307], Loss: 0.1439, Accuracy: 0.9312
# Epoch: 0. start_index: 735968, end_index: 736000
# Step [23000/53307], Loss: 0.1651, Accuracy: 0.9500
# Epoch: 0. start_index: 751968, end_index: 752000
# Step [23500/53307], Loss: 0.1145, Accuracy: 0.9563
# Epoch: 0. start_index: 767968, end_index: 768000
# Step [24000/53307], Loss: 0.1934, Accuracy: 0.9125
# Epoch: 0. start_index: 783968, end_index: 784000
# Step [24500/53307], Loss: 0.1257, Accuracy: 0.9500
# Epoch: 0. start_index: 799968, end_index: 800000
# Step [25000/53307], Loss: 0.1479, Accuracy: 0.9500
# Epoch: 0. start_index: 815968, end_index: 816000
# Step [25500/53307], Loss: 0.1023, Accuracy: 0.9625
# Epoch: 0. start_index: 831968, end_index: 832000
# Step [26000/53307], Loss: 0.1518, Accuracy: 0.9312
# Epoch: 0. start_index: 847968, end_index: 848000
# Step [26500/53307], Loss: 0.0899, Accuracy: 0.9688
# Epoch: 1. start_index: 11040, end_index: 11072
# Step [27000/53307], Loss: 0.1386, Accuracy: 0.9375
# Epoch: 1. start_index: 27040, end_index: 27072
# Step [27500/53307], Loss: 0.0825, Accuracy: 0.9750
# Epoch: 1. start_index: 43040, end_index: 43072
# Step [28000/53307], Loss: 0.0934, Accuracy: 0.9625
# Epoch: 1. start_index: 59040, end_index: 59072
# Step [28500/53307], Loss: 0.1473, Accuracy: 0.9312
# Epoch: 1. start_index: 75040, end_index: 75072
# Step [29000/53307], Loss: 0.1107, Accuracy: 0.9500
# Epoch: 1. start_index: 91040, end_index: 91072
# Step [29500/53307], Loss: 0.1465, Accuracy: 0.9250
# Epoch: 1. start_index: 107040, end_index: 107072
# Step [30000/53307], Loss: 0.1153, Accuracy: 0.9625
# Epoch: 1. start_index: 123040, end_index: 123072
# Step [30500/53307], Loss: 0.1186, Accuracy: 0.9500
# Epoch: 1. start_index: 139040, end_index: 139072
# Step [31000/53307], Loss: 0.1329, Accuracy: 0.9312
# Epoch: 1. start_index: 155040, end_index: 155072
# Step [31500/53307], Loss: 0.1146, Accuracy: 0.9312
# Epoch: 1. start_index: 171040, end_index: 171072
# Step [32000/53307], Loss: 0.0853, Accuracy: 0.9750
# Epoch: 1. start_index: 187040, end_index: 187072
# Step [32500/53307], Loss: 0.1163, Accuracy: 0.9500
# Epoch: 1. start_index: 203040, end_index: 203072
# Step [33000/53307], Loss: 0.0973, Accuracy: 0.9688
# Epoch: 1. start_index: 219040, end_index: 219072
# Step [33500/53307], Loss: 0.1006, Accuracy: 0.9625
# Epoch: 1. start_index: 235040, end_index: 235072
# Step [34000/53307], Loss: 0.0481, Accuracy: 0.9937
# Epoch: 1. start_index: 251040, end_index: 251072
# Step [34500/53307], Loss: 0.0734, Accuracy: 0.9812
# Epoch: 1. start_index: 267040, end_index: 267072
# Step [35000/53307], Loss: 0.1086, Accuracy: 0.9500
# Epoch: 1. start_index: 283040, end_index: 283072
# Step [35500/53307], Loss: 0.1463, Accuracy: 0.9375
# Epoch: 1. start_index: 299040, end_index: 299072
# Step [36000/53307], Loss: 0.0728, Accuracy: 0.9812
# Epoch: 1. start_index: 315040, end_index: 315072
# Step [36500/53307], Loss: 0.0994, Accuracy: 0.9563
# Epoch: 1. start_index: 331040, end_index: 331072
# Step [37000/53307], Loss: 0.0990, Accuracy: 0.9375
# Epoch: 1. start_index: 347040, end_index: 347072
# Step [37500/53307], Loss: 0.0732, Accuracy: 0.9688
# Epoch: 1. start_index: 363040, end_index: 363072
# Step [38000/53307], Loss: 0.0833, Accuracy: 0.9563
# Epoch: 1. start_index: 379040, end_index: 379072
# Step [38500/53307], Loss: 0.0761, Accuracy: 0.9812
# Epoch: 1. start_index: 395040, end_index: 395072
# Step [39000/53307], Loss: 0.0885, Accuracy: 0.9688
# Epoch: 1. start_index: 411040, end_index: 411072
# Step [39500/53307], Loss: 0.0687, Accuracy: 0.9750
# Epoch: 1. start_index: 427040, end_index: 427072
# Step [40000/53307], Loss: 0.0760, Accuracy: 0.9812
# Epoch: 1. start_index: 443040, end_index: 443072
# Step [40500/53307], Loss: 0.0578, Accuracy: 0.9875
# Epoch: 1. start_index: 459040, end_index: 459072
# Step [41000/53307], Loss: 0.0624, Accuracy: 0.9688
# Epoch: 1. start_index: 475040, end_index: 475072
# Step [41500/53307], Loss: 0.0743, Accuracy: 0.9750
# Epoch: 1. start_index: 491040, end_index: 491072
# Step [42000/53307], Loss: 0.0431, Accuracy: 0.9875
# Epoch: 1. start_index: 507040, end_index: 507072
# Step [42500/53307], Loss: 0.0712, Accuracy: 0.9688
# Epoch: 1. start_index: 523040, end_index: 523072
# Step [43000/53307], Loss: 0.0718, Accuracy: 0.9750
# Epoch: 1. start_index: 539040, end_index: 539072
# Step [43500/53307], Loss: 0.0753, Accuracy: 0.9875
# Epoch: 1. start_index: 555040, end_index: 555072
# Step [44000/53307], Loss: 0.0745, Accuracy: 0.9625
# Epoch: 1. start_index: 571040, end_index: 571072
# Step [44500/53307], Loss: 0.0756, Accuracy: 0.9812
# Epoch: 1. start_index: 587040, end_index: 587072
# Step [45000/53307], Loss: 0.0451, Accuracy: 0.9812
# Epoch: 1. start_index: 603040, end_index: 603072
# Step [45500/53307], Loss: 0.0724, Accuracy: 0.9563
# Epoch: 1. start_index: 619040, end_index: 619072
# Step [46000/53307], Loss: 0.0617, Accuracy: 0.9750
# Epoch: 1. start_index: 635040, end_index: 635072
# Step [46500/53307], Loss: 0.0422, Accuracy: 0.9750
# Epoch: 1. start_index: 651040, end_index: 651072
# Step [47000/53307], Loss: 0.0448, Accuracy: 0.9937
# Epoch: 1. start_index: 667040, end_index: 667072
# Step [47500/53307], Loss: 0.0306, Accuracy: 0.9937
# Epoch: 1. start_index: 683040, end_index: 683072
# Step [48000/53307], Loss: 0.0533, Accuracy: 0.9812
# Epoch: 1. start_index: 699040, end_index: 699072
# Step [48500/53307], Loss: 0.0451, Accuracy: 0.9812
# Epoch: 1. start_index: 715040, end_index: 715072
# Step [49000/53307], Loss: 0.0381, Accuracy: 0.9875
# Epoch: 1. start_index: 731040, end_index: 731072
# Step [49500/53307], Loss: 0.0562, Accuracy: 0.9750
# Epoch: 1. start_index: 747040, end_index: 747072
# Step [50000/53307], Loss: 0.0566, Accuracy: 0.9750
# Epoch: 1. start_index: 763040, end_index: 763072
# Step [50500/53307], Loss: 0.0309, Accuracy: 1.0000
# Epoch: 1. start_index: 779040, end_index: 779072
# Step [51000/53307], Loss: 0.0393, Accuracy: 0.9875
# Epoch: 1. start_index: 795040, end_index: 795072
# Step [51500/53307], Loss: 0.0311, Accuracy: 0.9937
# Epoch: 1. start_index: 811040, end_index: 811072
# Step [52000/53307], Loss: 0.1045, Accuracy: 0.9625
# Epoch: 1. start_index: 827040, end_index: 827072
# Step [52500/53307], Loss: 0.0824, Accuracy: 0.9750
# Epoch: 1. start_index: 843040, end_index: 843072
# Step [53000/53307], Loss: 0.0376, Accuracy: 0.9937
# Training finished.

# %%
# Training graphs
plot_metric(losses, step_size=50, metric_name='Speaker Listener Loss', save_path='speaker_loss.png')
plot_metric(accuracies, step_size=50, metric_name='Speaker Listener Accuracy', save_path='speaker_accuracy.png')
# Out:
# Plot saved to speaker_loss.png
# Plot saved to speaker_accuracy.png

# %% [markdown]
# ### Inference

# %%
# Freeze the speaker-listener model parameters
for param in model.parameters():
    param.requires_grad = False

model.eval()
# Out:
# SpeakerListenerSystem(
#   (encoder): ObjectEncoder(
#     (encoder): Sequential(
#       (0): Conv2d(1, 4, kernel_size=(2, 2), stride=(1, 1))
#       (1): Flatten(start_dim=1, end_dim=-1)
#       (2): Linear(in_features=16, out_features=6, bias=True)
#     )
#   )
#   (speaker): Speaker(
#     (speaker_net): Sequential(
#       (0): Linear(in_features=35, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=32, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=32, out_features=12, bias=True)
#     )
#   )
#   (listener): Listener(
#     (listener_net): Sequential(
#       (0): Linear(in_features=18, out_features=32, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=32, out_features=8, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=8, out_features=1, bias=True)
#     )
#   )
# )

# %%
print("\n--- Running a test example ---")

with torch.no_grad():
    W_test, X_test_mask = dataset_splits['speaker_listener']['W'][0:1], dataset_splits['speaker_listener']['X_mask'][0:1]

    # dummy data
    # generate_batch(1, WORLD_SIZE)

    print("Test World W has 5 objects.")
    print(f"Target set X is selected by mask: {X_test_mask[0]}")


    y_test_logits, y_test_labels = model(W_test, X_test_mask)
    y_test_probs  = torch.sigmoid(y_test_logits)

    print(f"Ground truth vector: {y_test_labels.numpy().flatten()}")

    print(f"Model prediction (probabilities): {y_test_probs.numpy().flatten()}")
    print(f"Final prediction (rounded): {[round(p, 2) for p in y_test_probs.numpy().flatten()]}")
# Out:
# --- Running a test example ---
# Test World W has 5 objects.
# Target set X is selected by mask: tensor([0., 1., 1., 1., 1.])
# Ground truth vector: [0. 1. 1. 1. 1.]
# Model prediction (probabilities): [5.581179e-27 9.910048e-01 9.999999e-01 9.998671e-01 9.999807e-01]
# Final prediction (rounded): [np.float32(0.0), np.float32(0.99), np.float32(1.0), np.float32(1.0), np.float32(1.0)]

# %%
# Evaluate speaker-listener on full test set
print("\n--- Evaluating speaker-listener on full test set ---")

test_losses = []
test_accuracies = []

N_TEST = len(dataset_splits['translator_test']['W'])
start_index = 0

with torch.no_grad():  # Important: no gradients during eval
    while start_index < N_TEST:
        batch_size = min(BATCH_SIZE, N_TEST - start_index)

        # Load test batch
        W_batch, X_mask_batch = load_batch(
            'translator_test', start_index, batch_size
        )

        # Predict
        test_logits, test_truth = model(W_batch, X_mask_batch)

        # Calculate loss
        loss = criterion(test_logits, test_truth)

         # Calculate accuracy for monitoring
        preds    = torch.sigmoid(test_logits) > 0.5
        accuracy = (preds.float() == test_truth).float().mean()

        # Store metrics
        test_losses.append(loss.item())
        test_accuracies.append(accuracy.item())

        start_index += batch_size

# Print overall results
print(f"Test Loss: {np.mean(test_losses):.4f}")
print(f"Test Accuracy: {np.mean(test_accuracies):.4f}")
# Out:
# --- Evaluating speaker-listener on full test set ---
# Test Loss: 0.0428
# Test Accuracy: 0.9873

# %% [markdown]
# ### Validation
# We want to check that the speaker learns the actual features of the subset with respect to the larger world, instead of some cheat like the mask positions.
# We do this by testing whether the neuralese representing similar rules are closer in distance than different rules.

# %%
# Select 9 rules out of our total of 72
rules = ["red", "triangle", "purple or no-outline",
         "green or circle", "red and square", "triangle and slim-outline",
         "not purple", "not thick-outline", "red or no-outline"]

# %%
# Retrieve n examples that fit this rule
def get_world_with_rule(rule, n):
    """
    Retrieve n examples from dataset that match the given rule.

    Args:
        rule: string like "red", "circle", "not thick-outline", etc.
        n: number of examples to retrieve

    Returns:
        W_list: list of world tensors
        X_mask_list: list of mask tensors
    """
    # Use the translator train split
    rule_texts = dataset_splits['translator_train']['rule_texts']

    # Find indices that match the rule
    matched_indices = []
    for i, rt in enumerate(rule_texts):
      if rt == rule:
        matched_indices.append(i)
        if len(matched_indices) == n:
          break

    # Load the matching data
    W_list = []
    X_list = []
    for i in matched_indices:
      W, X = load_batch('translator_train', i, 1)
      W_list.append(W)
      X_list.append(X)

    return W_list, X_list

# %%
# Generate 100 neuralese examples for each rule
neuralese_by_rule = {}
for rule in rules:
    vectors = []
    W, X = get_world_with_rule(rule, n=100)
    for idx in range(100):
        V = model(W[idx], X[idx], return_neuralese_only=True)
        vectors.append(V)
    neuralese_by_rule[rule] = torch.cat(vectors, dim=0) # (100, neuralese_dimension)

# %%
# Compute within-rule and between-rule similarities
# within-rule (should be HIGH if consistent)
# between-rule (should be LOW if discriminative)

within_rule  = []
between_rule = []

for rule in rules:
  vectors = neuralese_by_rule[rule]

  # pair-wise within rule
  for i in range(100):
      for j in range(i+1, 100):
          sim = F.cosine_similarity(vectors[i], vectors[j], dim=0)
          within_rule.append(sim.item())

  # between rules
  for rule_1 in rules:
      for rule_2 in rules:
          if rule_1 != rule_2:
              rand_idx = random.randint(0, 99)
              v_1 = neuralese_by_rule[rule_1][rand_idx]
              v_2 = neuralese_by_rule[rule_2][rand_idx]
              sim = F.cosine_similarity(v_1, v_2, dim=0)
              between_rule.append(sim.item())

# %%
print(f"Within-rule:  {np.mean(within_rule):.3f}  ± {np.std(within_rule):.3f}")
print(f"Between-rule: {np.mean(between_rule):.3f} ± {np.std(between_rule):.3f}")
# Out:
# Within-rule:  0.908  ± 0.090
# Between-rule: 0.865 ± 0.097

# %% [markdown]
# The signal is weak - only 4.3% separation. The neuralese vectors are pointing in very similar directions regardless of rule.
#
# But this weakness might explain the ~35% translation accuracy. The translator model is trying to extract a very weak signal.
#
# The similarity between vectors might be indicative of a dominant baseline signal.
#
# So we will try to normalize for it.
#
#
# **Centering**

# %%
# Collect all neuralese vectors within our test rules
all_V = []
for rule in rules:
    all_V.append(neuralese_by_rule[rule])
all_V = torch.cat(all_V, dim=0) # (num_rules (9) * 100, 12)

# Compute global mean
mean_V = all_V.mean(dim=0) # (12)

# Center all vectors
neuralese_by_rule_centered = {}
for rule in rules:
    neuralese_by_rule_centered[rule] = neuralese_by_rule[rule] - mean_V

# %%
# Repeat experiment with centered neuralese
within_rule  = []
between_rule = []

for rule in rules:
  vectors = neuralese_by_rule_centered[rule]

  # pair-wise within rule
  for i in range(100):
      for j in range(i+1, 100):
          sim = F.cosine_similarity(vectors[i], vectors[j], dim=0)
          within_rule.append(sim.item())

  # between rules
  for rule_1 in rules:
      for rule_2 in rules:
          if rule_1 != rule_2:
              rand_idx = random.randint(0, 99)
              v_1 = neuralese_by_rule_centered[rule_1][rand_idx]
              v_2 = neuralese_by_rule_centered[rule_2][rand_idx]
              sim = F.cosine_similarity(v_1, v_2, dim=0)
              between_rule.append(sim.item())

# %%
print(f"Within-rule:  {np.mean(within_rule):.3f}  ± {np.std(within_rule):.3f}")
print(f"Between-rule: {np.mean(between_rule):.3f} ± {np.std(between_rule):.3f}")
# Out:
# Within-rule:  0.342  ± 0.519
# Between-rule: -0.055 ± 0.563

# %% [markdown]
# This shows that the rule information IS consistently encoded in the neuralese, but is hidden under a massive baseline signal. After removing the baseline, the rules separate beautifully.
#
# So the translator had weak prediction power because it was drowning in the baseline signal...
# We can now go on to train the translator on centered neuralese.

# %% [markdown]
# ## The Translator

# %% [markdown]
# ### Prepare Translator Data

# %%
# map vocabulary to tokens
VOCABULARY = {
    '<blank>'      : 0,
    'not'          : 1,
    'and'          : 2,
    'or'           : 3,
    'red'          : 4,
    'green'        : 5,
    'purple'       : 6,
    'circle'       : 7,
    'square'       : 8,
    'triangle'     : 9,
    'no-outline'   : 10,
    'slim-outline' : 11,
    'thick-outline': 12
}
IDX_TO_TOKEN = {v: k for k, v in VOCABULARY.items()}

# %%
# Convert rules to token sequences
def rule_text_to_tokens(rule_text, max_rule_length=3):
    """
    Convert rule text string into a fixed-length sequence of tokens.

    Arguments:
        rule_text: String representation of the rule (e.g., "red and circle")
        max_rule_length: Fixed sequence length (default 3)

    Returns:
        List of token indices representing the rule, padded with <blank> tokens.
    """
    tokens = rule_text.split()
    token_indices = [VOCABULARY[token] for token in tokens]

    # Pad with <blank> tokens if necessary
    while len(token_indices) < max_rule_length:
        token_indices.append(VOCABULARY['<blank>'])

    return token_indices[:max_rule_length]


train_rule_tokens = [
    rule_text_to_tokens(rule_text)
    for rule_text in dataset_splits['translator_train']['rule_texts']
]

test_rule_tokens = [
    rule_text_to_tokens(rule_text)
    for rule_text in dataset_splits['translator_test']['rule_texts']
]
train_targets = torch.tensor(train_rule_tokens, dtype=torch.long)
test_targets  = torch.tensor(test_rule_tokens, dtype=torch.long)

# Add tokenized rules to dataset splits
dataset_splits['translator_train']['rule_tokens'] = train_targets
dataset_splits['translator_test']['rule_tokens']  = test_targets

# Print shapes and examples
print(f"Train targets shape: {train_targets.shape}")
print(f"Test targets shape : {test_targets.shape}")
print(f"\nFirst 5 train examples:")
for i in range(5):
    rule_text = dataset_splits['translator_train']['rule_texts'][i]
    tokens = train_targets[i].tolist()
    decoded = [IDX_TO_TOKEN[t] for t in tokens]
    print(f"  '{rule_text}' -> {tokens} -> {decoded}")
# Out:
# Train targets shape: torch.Size([682333, 3])
# Test targets shape : torch.Size([170584, 3])
#
# First 5 train examples:
#   'green and triangle' -> [5, 2, 9] -> ['green', 'and', 'triangle']
#   'not square' -> [1, 8, 0] -> ['not', 'square', '<blank>']
#   'purple or square' -> [6, 3, 8] -> ['purple', 'or', 'square']
#   'triangle or slim-outline' -> [9, 3, 11] -> ['triangle', 'or', 'slim-outline']
#   'circle' -> [7, 0, 0] -> ['circle', '<blank>', '<blank>']

# %% [markdown]
# ### Training

# %%
# Hyperparameters for training
BATCH_SIZE    = 32 # 32
NUM_EPOCHS    = 15 # 2000
LEARNING_RATE = 1e-4

# %%
# Initialize the translator model
translator_model = Translator(
    neuralese_dimension = NEURALESE_DIMENSION,
    max_rule_length     = 3,
    vocab_size          = len(VOCABULARY),
    hidden_dimension    = 128
)

translator_optimizer = optim.Adam(translator_model.parameters(), lr=LEARNING_RATE)
translator_criterion = nn.CrossEntropyLoss()

# %%
# Training loop
step = 0
start_index = 0
N_DATA = len(dataset_splits['translator_train']['W'])

losses = []
token_accuracies = []
sequence_accuracies = []

print("Starting translator training...")
for epoch in range(NUM_EPOCHS):
    start_index = 0

    # Stop when we run out of data
    while start_index < N_DATA:
        batch_size = min(BATCH_SIZE, N_DATA - start_index)

        # Load a batch of translator training data
        W_batch, X_mask_batch, rule_tokens_batch = load_batch(
            'translator_train', start_index, batch_size, include_rules=True
        )
        start_index += BATCH_SIZE
        step += 1

        # Get the neuralese representations from the frozen speaker
        with torch.no_grad():
            # (batch_size, neuralese_dimension)
            V_batch = model(W_batch, X_mask_batch, return_neuralese_only=True)

        # Predict the rule tokens
        # (batch_size, max_rule_length, vocab_size)
        translator_optimizer.zero_grad()
        predicted_logits = translator_model(V_batch)

        # Calculate loss for each position in the rule
        loss = translator_criterion(
            predicted_logits.view(-1, len(VOCABULARY)),  # (batch_size * max_rule_length, vocab_size)
            rule_tokens_batch.view(-1)                   # (batch_size * max_rule_length,)
        )

        # Optimize
        loss.backward()
        translator_optimizer.step()

        if (step + 1) % 500 == 0:
            # Track data consumption
            print(f"Epoch: {epoch}. start_index: {start_index}, end_index: {start_index + batch_size}")

            # Calculate token-level accuracy
            predicted_tokens = torch.argmax(predicted_logits, dim=2)  # (batch_size, max_rule_length)
            correct_tokens   = (predicted_tokens == rule_tokens_batch).float()
            token_accuracy   = correct_tokens.mean().item()

            # Calculate sequence-level accuracy
            sequence_correct = (correct_tokens.sum(dim=1) == correct_tokens.shape[1]).float()
            sequence_accuracy = sequence_correct.mean().item()

            print(f"Step [{step+1}/{NUM_EPOCHS * (N_DATA // BATCH_SIZE) + 1}], Loss: {loss.item():.4f}, Token Acc: {token_accuracy:.4f}, Seq Acc: {sequence_accuracy:.4f}")

            # Store metrics
            losses.append(loss.item())
            token_accuracies.append(token_accuracy)
            sequence_accuracies.append(sequence_accuracy)

print("Translator training finished.")
# Out:
# Starting translator training...
# Epoch: 0. start_index: 15968, end_index: 16000
# Step [500/---], Loss: 1.7899, Token Acc: 0.4375, Seq Acc: 0.0312
# Epoch: 0. start_index: 31968, end_index: 32000
# Step [1000/---], Loss: 1.6819, Token Acc: 0.4375, Seq Acc: 0.0625
# Epoch: 0. start_index: 47968, end_index: 48000
# Step [1500/---], Loss: 1.6666, Token Acc: 0.4583, Seq Acc: 0.0312
# Epoch: 0. start_index: 63968, end_index: 64000
# Step [2000/---], Loss: 1.4744, Token Acc: 0.5417, Seq Acc: 0.1250
# Epoch: 0. start_index: 79968, end_index: 80000
# Step [2500/---], Loss: 1.5761, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 0. start_index: 95968, end_index: 96000
# Step [3000/---], Loss: 1.5328, Token Acc: 0.5000, Seq Acc: 0.1250
# Epoch: 0. start_index: 111968, end_index: 112000
# Step [3500/---], Loss: 1.5893, Token Acc: 0.4792, Seq Acc: 0.0938
# Epoch: 0. start_index: 127968, end_index: 128000
# Step [4000/---], Loss: 1.7133, Token Acc: 0.4271, Seq Acc: 0.0625
# Epoch: 0. start_index: 143968, end_index: 144000
# Step [4500/---], Loss: 1.5455, Token Acc: 0.4583, Seq Acc: 0.0625
# Epoch: 0. start_index: 159968, end_index: 160000
# Step [5000/---], Loss: 1.4356, Token Acc: 0.5312, Seq Acc: 0.0938
# Epoch: 0. start_index: 175968, end_index: 176000
# Step [5500/---], Loss: 1.4194, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 0. start_index: 191968, end_index: 192000
# Step [6000/---], Loss: 1.6116, Token Acc: 0.4583, Seq Acc: 0.0938
# Epoch: 0. start_index: 207968, end_index: 208000
# Step [6500/---], Loss: 1.6228, Token Acc: 0.4479, Seq Acc: 0.0625
# Epoch: 0. start_index: 223968, end_index: 224000
# Step [7000/---], Loss: 1.2180, Token Acc: 0.6354, Seq Acc: 0.2812
# Epoch: 0. start_index: 239968, end_index: 240000
# Step [7500/---], Loss: 1.3559, Token Acc: 0.5625, Seq Acc: 0.1562
# Epoch: 0. start_index: 255968, end_index: 256000
# Step [8000/---], Loss: 1.4403, Token Acc: 0.5312, Seq Acc: 0.0625
# Epoch: 0. start_index: 271968, end_index: 272000
# Step [8500/---], Loss: 1.3757, Token Acc: 0.5521, Seq Acc: 0.1562
# Epoch: 0. start_index: 287968, end_index: 288000
# Step [9000/---], Loss: 1.5229, Token Acc: 0.5417, Seq Acc: 0.1250
# Epoch: 0. start_index: 303968, end_index: 304000
# Step [9500/---], Loss: 1.1944, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 0. start_index: 319968, end_index: 320000
# Step [10000/---], Loss: 1.4703, Token Acc: 0.5208, Seq Acc: 0.0625
# Epoch: 0. start_index: 335968, end_index: 336000
# Step [10500/---], Loss: 1.4471, Token Acc: 0.5208, Seq Acc: 0.1875
# Epoch: 0. start_index: 351968, end_index: 352000
# Step [11000/---], Loss: 1.3501, Token Acc: 0.5729, Seq Acc: 0.1250
# Epoch: 0. start_index: 367968, end_index: 368000
# Step [11500/---], Loss: 1.3430, Token Acc: 0.6146, Seq Acc: 0.1562
# Epoch: 0. start_index: 383968, end_index: 384000
# Step [12000/---], Loss: 1.4553, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 0. start_index: 399968, end_index: 400000
# Step [12500/---], Loss: 1.4376, Token Acc: 0.4688, Seq Acc: 0.0938
# Epoch: 0. start_index: 415968, end_index: 416000
# Step [13000/---], Loss: 1.3643, Token Acc: 0.5208, Seq Acc: 0.1562
# Epoch: 0. start_index: 431968, end_index: 432000
# Step [13500/---], Loss: 1.4900, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 0. start_index: 447968, end_index: 448000
# Step [14000/---], Loss: 1.4470, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 0. start_index: 463968, end_index: 464000
# Step [14500/---], Loss: 1.2945, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 0. start_index: 479968, end_index: 480000
# Step [15000/---], Loss: 1.4583, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 0. start_index: 495968, end_index: 496000
# Step [15500/---], Loss: 1.1993, Token Acc: 0.6562, Seq Acc: 0.2188
# Epoch: 0. start_index: 511968, end_index: 512000
# Step [16000/---], Loss: 1.5265, Token Acc: 0.4583, Seq Acc: 0.0312
# Epoch: 0. start_index: 527968, end_index: 528000
# Step [16500/---], Loss: 1.4330, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 0. start_index: 543968, end_index: 544000
# Step [17000/---], Loss: 1.2482, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 0. start_index: 559968, end_index: 560000
# Step [17500/---], Loss: 1.6170, Token Acc: 0.4375, Seq Acc: 0.0625
# Epoch: 0. start_index: 575968, end_index: 576000
# Step [18000/---], Loss: 1.4442, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 0. start_index: 591968, end_index: 592000
# Step [18500/---], Loss: 1.4273, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 0. start_index: 607968, end_index: 608000
# Step [19000/---], Loss: 1.4337, Token Acc: 0.4792, Seq Acc: 0.1250
# Epoch: 0. start_index: 623968, end_index: 624000
# Step [19500/---], Loss: 1.4066, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 0. start_index: 639968, end_index: 640000
# Step [20000/---], Loss: 1.4435, Token Acc: 0.5208, Seq Acc: 0.0938
# Epoch: 0. start_index: 655968, end_index: 656000
# Step [20500/---], Loss: 1.3600, Token Acc: 0.4896, Seq Acc: 0.0938
# Epoch: 0. start_index: 671968, end_index: 672000
# Step [21000/---], Loss: 1.3132, Token Acc: 0.5104, Seq Acc: 0.0938
# Epoch: 1. start_index: 5632, end_index: 5664
# Step [21500/---], Loss: 1.4430, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 1. start_index: 21632, end_index: 21664
# Step [22000/---], Loss: 1.3419, Token Acc: 0.5312, Seq Acc: 0.2812
# Epoch: 1. start_index: 37632, end_index: 37664
# Step [22500/---], Loss: 1.1562, Token Acc: 0.6250, Seq Acc: 0.2812
# Epoch: 1. start_index: 53632, end_index: 53664
# Step [23000/---], Loss: 1.4539, Token Acc: 0.4688, Seq Acc: 0.0938
# Epoch: 1. start_index: 69632, end_index: 69664
# Step [23500/---], Loss: 1.4007, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 1. start_index: 85632, end_index: 85664
# Step [24000/---], Loss: 1.5145, Token Acc: 0.5104, Seq Acc: 0.1875
# Epoch: 1. start_index: 101632, end_index: 101664
# Step [24500/---], Loss: 1.4883, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 1. start_index: 117632, end_index: 117664
# Step [25000/---], Loss: 1.3843, Token Acc: 0.5104, Seq Acc: 0.2188
# Epoch: 1. start_index: 133632, end_index: 133664
# Step [25500/---], Loss: 1.2393, Token Acc: 0.5833, Seq Acc: 0.1875
# Epoch: 1. start_index: 149632, end_index: 149664
# Step [26000/---], Loss: 1.2792, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 1. start_index: 165632, end_index: 165664
# Step [26500/---], Loss: 1.3829, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 1. start_index: 181632, end_index: 181664
# Step [27000/---], Loss: 1.3064, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 1. start_index: 197632, end_index: 197664
# Step [27500/---], Loss: 1.5294, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 1. start_index: 213632, end_index: 213664
# Step [28000/---], Loss: 1.3319, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 1. start_index: 229632, end_index: 229664
# Step [28500/---], Loss: 1.3080, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 1. start_index: 245632, end_index: 245664
# Step [29000/---], Loss: 1.3041, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 1. start_index: 261632, end_index: 261664
# Step [29500/---], Loss: 1.2800, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 1. start_index: 277632, end_index: 277664
# Step [30000/---], Loss: 1.5358, Token Acc: 0.4375, Seq Acc: 0.1562
# Epoch: 1. start_index: 293632, end_index: 293664
# Step [30500/---], Loss: 1.3377, Token Acc: 0.4896, Seq Acc: 0.1875
# Epoch: 1. start_index: 309632, end_index: 309664
# Step [31000/---], Loss: 1.2845, Token Acc: 0.5938, Seq Acc: 0.2188
# Epoch: 1. start_index: 325632, end_index: 325664
# Step [31500/---], Loss: 1.3120, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 1. start_index: 341632, end_index: 341664
# Step [32000/---], Loss: 1.2607, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 1. start_index: 357632, end_index: 357664
# Step [32500/---], Loss: 1.3270, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 1. start_index: 373632, end_index: 373664
# Step [33000/---], Loss: 1.1983, Token Acc: 0.5938, Seq Acc: 0.3750
# Epoch: 1. start_index: 389632, end_index: 389664
# Step [33500/---], Loss: 1.2063, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 1. start_index: 405632, end_index: 405664
# Step [34000/---], Loss: 1.3102, Token Acc: 0.5729, Seq Acc: 0.2812
# Epoch: 1. start_index: 421632, end_index: 421664
# Step [34500/---], Loss: 1.3918, Token Acc: 0.6042, Seq Acc: 0.1875
# Epoch: 1. start_index: 437632, end_index: 437664
# Step [35000/---], Loss: 1.5101, Token Acc: 0.5000, Seq Acc: 0.0625
# Epoch: 1. start_index: 453632, end_index: 453664
# Step [35500/---], Loss: 1.2229, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 1. start_index: 469632, end_index: 469664
# Step [36000/---], Loss: 1.4353, Token Acc: 0.5104, Seq Acc: 0.2188
# Epoch: 1. start_index: 485632, end_index: 485664
# Step [36500/---], Loss: 1.1547, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 1. start_index: 501632, end_index: 501664
# Step [37000/---], Loss: 1.3885, Token Acc: 0.5521, Seq Acc: 0.2188
# Epoch: 1. start_index: 517632, end_index: 517664
# Step [37500/---], Loss: 1.2515, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 1. start_index: 533632, end_index: 533664
# Step [38000/---], Loss: 1.2986, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 1. start_index: 549632, end_index: 549664
# Step [38500/---], Loss: 1.3463, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 1. start_index: 565632, end_index: 565664
# Step [39000/---], Loss: 1.5400, Token Acc: 0.4688, Seq Acc: 0.1250
# Epoch: 1. start_index: 581632, end_index: 581664
# Step [39500/---], Loss: 1.4715, Token Acc: 0.4583, Seq Acc: 0.1562
# Epoch: 1. start_index: 597632, end_index: 597664
# Step [40000/---], Loss: 1.3873, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 1. start_index: 613632, end_index: 613664
# Step [40500/---], Loss: 1.2447, Token Acc: 0.5833, Seq Acc: 0.1875
# Epoch: 1. start_index: 629632, end_index: 629664
# Step [41000/---], Loss: 1.5694, Token Acc: 0.3854, Seq Acc: 0.0625
# Epoch: 1. start_index: 645632, end_index: 645664
# Step [41500/---], Loss: 1.1675, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 1. start_index: 661632, end_index: 661664
# Step [42000/---], Loss: 1.2608, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 1. start_index: 677632, end_index: 677664
# Step [42500/---], Loss: 1.5346, Token Acc: 0.4479, Seq Acc: 0.0938
# Epoch: 2. start_index: 11296, end_index: 11328
# Step [43000/---], Loss: 1.3155, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 2. start_index: 27296, end_index: 27328
# Step [43500/---], Loss: 1.1432, Token Acc: 0.5521, Seq Acc: 0.1562
# Epoch: 2. start_index: 43296, end_index: 43328
# Step [44000/---], Loss: 1.1634, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 2. start_index: 59296, end_index: 59328
# Step [44500/---], Loss: 1.2372, Token Acc: 0.5208, Seq Acc: 0.1875
# Epoch: 2. start_index: 75296, end_index: 75328
# Step [45000/---], Loss: 1.1292, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 2. start_index: 91296, end_index: 91328
# Step [45500/---], Loss: 1.3594, Token Acc: 0.5104, Seq Acc: 0.0938
# Epoch: 2. start_index: 107296, end_index: 107328
# Step [46000/---], Loss: 1.2857, Token Acc: 0.5938, Seq Acc: 0.1875
# Epoch: 2. start_index: 123296, end_index: 123328
# Step [46500/---], Loss: 1.1862, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 2. start_index: 139296, end_index: 139328
# Step [47000/---], Loss: 1.4033, Token Acc: 0.5000, Seq Acc: 0.1562
# Epoch: 2. start_index: 155296, end_index: 155328
# Step [47500/---], Loss: 1.2355, Token Acc: 0.5521, Seq Acc: 0.2188
# Epoch: 2. start_index: 171296, end_index: 171328
# Step [48000/---], Loss: 1.1712, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 2. start_index: 187296, end_index: 187328
# Step [48500/---], Loss: 1.3392, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 2. start_index: 203296, end_index: 203328
# Step [49000/---], Loss: 1.3501, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 2. start_index: 219296, end_index: 219328
# Step [49500/---], Loss: 1.1931, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 2. start_index: 235296, end_index: 235328
# Step [50000/---], Loss: 1.2654, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 2. start_index: 251296, end_index: 251328
# Step [50500/---], Loss: 1.2174, Token Acc: 0.5208, Seq Acc: 0.2188
# Epoch: 2. start_index: 267296, end_index: 267328
# Step [51000/---], Loss: 1.1156, Token Acc: 0.6667, Seq Acc: 0.2812
# Epoch: 2. start_index: 283296, end_index: 283328
# Step [51500/---], Loss: 1.4029, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 2. start_index: 299296, end_index: 299328
# Step [52000/---], Loss: 1.2438, Token Acc: 0.5417, Seq Acc: 0.1250
# Epoch: 2. start_index: 315296, end_index: 315328
# Step [52500/---], Loss: 1.3266, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 2. start_index: 331296, end_index: 331328
# Step [53000/---], Loss: 1.2090, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 2. start_index: 347296, end_index: 347328
# Step [53500/---], Loss: 1.1467, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 2. start_index: 363296, end_index: 363328
# Step [54000/---], Loss: 1.4650, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 2. start_index: 379296, end_index: 379328
# Step [54500/---], Loss: 1.2845, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 2. start_index: 395296, end_index: 395328
# Step [55000/---], Loss: 1.0661, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 2. start_index: 411296, end_index: 411328
# Step [55500/---], Loss: 1.2592, Token Acc: 0.5729, Seq Acc: 0.1562
# Epoch: 2. start_index: 427296, end_index: 427328
# Step [56000/---], Loss: 1.3961, Token Acc: 0.4792, Seq Acc: 0.0312
# Epoch: 2. start_index: 443296, end_index: 443328
# Step [56500/---], Loss: 1.3607, Token Acc: 0.5417, Seq Acc: 0.2500
# Epoch: 2. start_index: 459296, end_index: 459328
# Step [57000/---], Loss: 1.2089, Token Acc: 0.5938, Seq Acc: 0.1875
# Epoch: 2. start_index: 475296, end_index: 475328
# Step [57500/---], Loss: 1.2301, Token Acc: 0.6042, Seq Acc: 0.2188
# Epoch: 2. start_index: 491296, end_index: 491328
# Step [58000/---], Loss: 1.1316, Token Acc: 0.6146, Seq Acc: 0.3750
# Epoch: 2. start_index: 507296, end_index: 507328
# Step [58500/---], Loss: 1.3325, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 2. start_index: 523296, end_index: 523328
# Step [59000/---], Loss: 1.2246, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 2. start_index: 539296, end_index: 539328
# Step [59500/---], Loss: 1.0744, Token Acc: 0.6667, Seq Acc: 0.3125
# Epoch: 2. start_index: 555296, end_index: 555328
# Step [60000/---], Loss: 1.2389, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 2. start_index: 571296, end_index: 571328
# Step [60500/---], Loss: 1.4920, Token Acc: 0.5208, Seq Acc: 0.0938
# Epoch: 2. start_index: 587296, end_index: 587328
# Step [61000/---], Loss: 1.1201, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 2. start_index: 603296, end_index: 603328
# Step [61500/---], Loss: 1.1379, Token Acc: 0.6250, Seq Acc: 0.3125
# Epoch: 2. start_index: 619296, end_index: 619328
# Step [62000/---], Loss: 1.3351, Token Acc: 0.5104, Seq Acc: 0.0938
# Epoch: 2. start_index: 635296, end_index: 635328
# Step [62500/---], Loss: 1.0152, Token Acc: 0.6458, Seq Acc: 0.4062
# Epoch: 2. start_index: 651296, end_index: 651328
# Step [63000/---], Loss: 1.2055, Token Acc: 0.6042, Seq Acc: 0.2188
# Epoch: 2. start_index: 667296, end_index: 667328
# Step [63500/---], Loss: 1.3516, Token Acc: 0.5729, Seq Acc: 0.1562
# Epoch: 3. start_index: 960, end_index: 992
# Step [64000/---], Loss: 1.2017, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 3. start_index: 16960, end_index: 16992
# Step [64500/---], Loss: 1.2489, Token Acc: 0.5521, Seq Acc: 0.1562
# Epoch: 3. start_index: 32960, end_index: 32992
# Step [65000/---], Loss: 1.0392, Token Acc: 0.6875, Seq Acc: 0.3750
# Epoch: 3. start_index: 48960, end_index: 48992
# Step [65500/---], Loss: 1.2297, Token Acc: 0.5729, Seq Acc: 0.1562
# Epoch: 3. start_index: 64960, end_index: 64992
# Step [66000/---], Loss: 1.2081, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 3. start_index: 80960, end_index: 80992
# Step [66500/---], Loss: 1.1107, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 3. start_index: 96960, end_index: 96992
# Step [67000/---], Loss: 1.1059, Token Acc: 0.7083, Seq Acc: 0.4062
# Epoch: 3. start_index: 112960, end_index: 112992
# Step [67500/---], Loss: 1.1809, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 3. start_index: 128960, end_index: 128992
# Step [68000/---], Loss: 1.4581, Token Acc: 0.4792, Seq Acc: 0.1250
# Epoch: 3. start_index: 144960, end_index: 144992
# Step [68500/---], Loss: 1.0937, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 3. start_index: 160960, end_index: 160992
# Step [69000/---], Loss: 1.1115, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 3. start_index: 176960, end_index: 176992
# Step [69500/---], Loss: 1.1891, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 3. start_index: 192960, end_index: 192992
# Step [70000/---], Loss: 1.0048, Token Acc: 0.6562, Seq Acc: 0.2812
# Epoch: 3. start_index: 208960, end_index: 208992
# Step [70500/---], Loss: 1.2758, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 3. start_index: 224960, end_index: 224992
# Step [71000/---], Loss: 1.3295, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 3. start_index: 240960, end_index: 240992
# Step [71500/---], Loss: 1.2656, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 3. start_index: 256960, end_index: 256992
# Step [72000/---], Loss: 1.2890, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 3. start_index: 272960, end_index: 272992
# Step [72500/---], Loss: 1.1303, Token Acc: 0.5938, Seq Acc: 0.3438
# Epoch: 3. start_index: 288960, end_index: 288992
# Step [73000/---], Loss: 1.2168, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 3. start_index: 304960, end_index: 304992
# Step [73500/---], Loss: 1.1818, Token Acc: 0.6042, Seq Acc: 0.2188
# Epoch: 3. start_index: 320960, end_index: 320992
# Step [74000/---], Loss: 1.2443, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 3. start_index: 336960, end_index: 336992
# Step [74500/---], Loss: 1.1518, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 3. start_index: 352960, end_index: 352992
# Step [75000/---], Loss: 1.1335, Token Acc: 0.5938, Seq Acc: 0.2500
# Epoch: 3. start_index: 368960, end_index: 368992
# Step [75500/---], Loss: 1.2676, Token Acc: 0.5417, Seq Acc: 0.2812
# Epoch: 3. start_index: 384960, end_index: 384992
# Step [76000/---], Loss: 1.3257, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 3. start_index: 400960, end_index: 400992
# Step [76500/---], Loss: 1.4222, Token Acc: 0.5104, Seq Acc: 0.1875
# Epoch: 3. start_index: 416960, end_index: 416992
# Step [77000/---], Loss: 1.2533, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 3. start_index: 432960, end_index: 432992
# Step [77500/---], Loss: 1.1028, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 3. start_index: 448960, end_index: 448992
# Step [78000/---], Loss: 1.1722, Token Acc: 0.6042, Seq Acc: 0.2188
# Epoch: 3. start_index: 464960, end_index: 464992
# Step [78500/---], Loss: 1.1507, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 3. start_index: 480960, end_index: 480992
# Step [79000/---], Loss: 1.1757, Token Acc: 0.6667, Seq Acc: 0.2500
# Epoch: 3. start_index: 496960, end_index: 496992
# Step [79500/---], Loss: 1.3295, Token Acc: 0.5104, Seq Acc: 0.1250
# Epoch: 3. start_index: 512960, end_index: 512992
# Step [80000/---], Loss: 1.2259, Token Acc: 0.6354, Seq Acc: 0.2812
# Epoch: 3. start_index: 528960, end_index: 528992
# Step [80500/---], Loss: 1.6646, Token Acc: 0.3854, Seq Acc: 0.0000
# Epoch: 3. start_index: 544960, end_index: 544992
# Step [81000/---], Loss: 1.4679, Token Acc: 0.4583, Seq Acc: 0.1250
# Epoch: 3. start_index: 560960, end_index: 560992
# Step [81500/---], Loss: 1.0512, Token Acc: 0.6250, Seq Acc: 0.3125
# Epoch: 3. start_index: 576960, end_index: 576992
# Step [82000/---], Loss: 1.1207, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 3. start_index: 592960, end_index: 592992
# Step [82500/---], Loss: 1.3773, Token Acc: 0.4896, Seq Acc: 0.1562
# Epoch: 3. start_index: 608960, end_index: 608992
# Step [83000/---], Loss: 1.3550, Token Acc: 0.5521, Seq Acc: 0.1250
# Epoch: 3. start_index: 624960, end_index: 624992
# Step [83500/---], Loss: 1.1638, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 3. start_index: 640960, end_index: 640992
# Step [84000/---], Loss: 1.2931, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 3. start_index: 656960, end_index: 656992
# Step [84500/---], Loss: 1.1478, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 3. start_index: 672960, end_index: 672992
# Step [85000/---], Loss: 1.1370, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 4. start_index: 6624, end_index: 6656
# Step [85500/---], Loss: 1.1232, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 4. start_index: 22624, end_index: 22656
# Step [86000/---], Loss: 1.1256, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 4. start_index: 38624, end_index: 38656
# Step [86500/---], Loss: 1.1238, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 4. start_index: 54624, end_index: 54656
# Step [87000/---], Loss: 1.3059, Token Acc: 0.5417, Seq Acc: 0.1250
# Epoch: 4. start_index: 70624, end_index: 70656
# Step [87500/---], Loss: 1.2209, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 4. start_index: 86624, end_index: 86656
# Step [88000/---], Loss: 1.2252, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 4. start_index: 102624, end_index: 102656
# Step [88500/---], Loss: 1.1420, Token Acc: 0.6042, Seq Acc: 0.1875
# Epoch: 4. start_index: 118624, end_index: 118656
# Step [89000/---], Loss: 1.3870, Token Acc: 0.4583, Seq Acc: 0.1875
# Epoch: 4. start_index: 134624, end_index: 134656
# Step [89500/---], Loss: 1.3422, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 4. start_index: 150624, end_index: 150656
# Step [90000/---], Loss: 1.0658, Token Acc: 0.6458, Seq Acc: 0.3125
# Epoch: 4. start_index: 166624, end_index: 166656
# Step [90500/---], Loss: 1.1486, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 4. start_index: 182624, end_index: 182656
# Step [91000/---], Loss: 1.3053, Token Acc: 0.4583, Seq Acc: 0.1562
# Epoch: 4. start_index: 198624, end_index: 198656
# Step [91500/---], Loss: 1.2609, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 4. start_index: 214624, end_index: 214656
# Step [92000/---], Loss: 1.2324, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 4. start_index: 230624, end_index: 230656
# Step [92500/---], Loss: 1.2558, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 4. start_index: 246624, end_index: 246656
# Step [93000/---], Loss: 1.1324, Token Acc: 0.6250, Seq Acc: 0.2812
# Epoch: 4. start_index: 262624, end_index: 262656
# Step [93500/---], Loss: 0.9730, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 4. start_index: 278624, end_index: 278656
# Step [94000/---], Loss: 1.1763, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 4. start_index: 294624, end_index: 294656
# Step [94500/---], Loss: 1.3311, Token Acc: 0.4896, Seq Acc: 0.1562
# Epoch: 4. start_index: 310624, end_index: 310656
# Step [95000/---], Loss: 1.2092, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 4. start_index: 326624, end_index: 326656
# Step [95500/---], Loss: 1.1350, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 4. start_index: 342624, end_index: 342656
# Step [96000/---], Loss: 1.1160, Token Acc: 0.6042, Seq Acc: 0.1562
# Epoch: 4. start_index: 358624, end_index: 358656
# Step [96500/---], Loss: 0.9646, Token Acc: 0.6875, Seq Acc: 0.3438
# Epoch: 4. start_index: 374624, end_index: 374656
# Step [97000/---], Loss: 1.0219, Token Acc: 0.6562, Seq Acc: 0.3438
# Epoch: 4. start_index: 390624, end_index: 390656
# Step [97500/---], Loss: 1.1816, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 4. start_index: 406624, end_index: 406656
# Step [98000/---], Loss: 1.5053, Token Acc: 0.4896, Seq Acc: 0.0938
# Epoch: 4. start_index: 422624, end_index: 422656
# Step [98500/---], Loss: 1.2115, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 4. start_index: 438624, end_index: 438656
# Step [99000/---], Loss: 1.2556, Token Acc: 0.5000, Seq Acc: 0.1875
# Epoch: 4. start_index: 454624, end_index: 454656
# Step [99500/---], Loss: 1.2782, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 4. start_index: 470624, end_index: 470656
# Step [100000/---], Loss: 1.0065, Token Acc: 0.6354, Seq Acc: 0.2812
# Epoch: 4. start_index: 486624, end_index: 486656
# Step [100500/---], Loss: 1.1190, Token Acc: 0.6146, Seq Acc: 0.2188
# Epoch: 4. start_index: 502624, end_index: 502656
# Step [101000/---], Loss: 1.1212, Token Acc: 0.5417, Seq Acc: 0.2188
# Epoch: 4. start_index: 518624, end_index: 518656
# Step [101500/---], Loss: 0.9817, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 4. start_index: 534624, end_index: 534656
# Step [102000/---], Loss: 1.2031, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 4. start_index: 550624, end_index: 550656
# Step [102500/---], Loss: 1.1644, Token Acc: 0.6250, Seq Acc: 0.2188
# Epoch: 4. start_index: 566624, end_index: 566656
# Step [103000/---], Loss: 1.3532, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 4. start_index: 582624, end_index: 582656
# Step [103500/---], Loss: 1.3144, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 4. start_index: 598624, end_index: 598656
# Step [104000/---], Loss: 1.2151, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 4. start_index: 614624, end_index: 614656
# Step [104500/---], Loss: 1.2039, Token Acc: 0.5625, Seq Acc: 0.1562
# Epoch: 4. start_index: 630624, end_index: 630656
# Step [105000/---], Loss: 1.1828, Token Acc: 0.5208, Seq Acc: 0.1562
# Epoch: 4. start_index: 646624, end_index: 646656
# Step [105500/---], Loss: 1.0347, Token Acc: 0.5833, Seq Acc: 0.3125
# Epoch: 4. start_index: 662624, end_index: 662656
# Step [106000/---], Loss: 1.0223, Token Acc: 0.6562, Seq Acc: 0.3125
# Epoch: 4. start_index: 678624, end_index: 678656
# Step [106500/---], Loss: 1.3677, Token Acc: 0.5000, Seq Acc: 0.1250
# Epoch: 5. start_index: 12288, end_index: 12320
# Step [107000/---], Loss: 1.2453, Token Acc: 0.5521, Seq Acc: 0.1250
# Epoch: 5. start_index: 28288, end_index: 28320
# Step [107500/---], Loss: 1.2094, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 5. start_index: 44288, end_index: 44320
# Step [108000/---], Loss: 1.1624, Token Acc: 0.5417, Seq Acc: 0.2188
# Epoch: 5. start_index: 60288, end_index: 60320
# Step [108500/---], Loss: 1.1415, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 5. start_index: 76288, end_index: 76320
# Step [109000/---], Loss: 1.0891, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 5. start_index: 92288, end_index: 92320
# Step [109500/---], Loss: 1.3343, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 5. start_index: 108288, end_index: 108320
# Step [110000/---], Loss: 1.2480, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 5. start_index: 124288, end_index: 124320
# Step [110500/---], Loss: 1.3013, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 5. start_index: 140288, end_index: 140320
# Step [111000/---], Loss: 1.0943, Token Acc: 0.6458, Seq Acc: 0.2812
# Epoch: 5. start_index: 156288, end_index: 156320
# Step [111500/---], Loss: 1.2781, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 5. start_index: 172288, end_index: 172320
# Step [112000/---], Loss: 1.3343, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 5. start_index: 188288, end_index: 188320
# Step [112500/---], Loss: 1.0845, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 5. start_index: 204288, end_index: 204320
# Step [113000/---], Loss: 1.2936, Token Acc: 0.5833, Seq Acc: 0.1562
# Epoch: 5. start_index: 220288, end_index: 220320
# Step [113500/---], Loss: 1.1302, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 5. start_index: 236288, end_index: 236320
# Step [114000/---], Loss: 1.4232, Token Acc: 0.4792, Seq Acc: 0.0938
# Epoch: 5. start_index: 252288, end_index: 252320
# Step [114500/---], Loss: 1.0831, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 5. start_index: 268288, end_index: 268320
# Step [115000/---], Loss: 1.1986, Token Acc: 0.6146, Seq Acc: 0.3438
# Epoch: 5. start_index: 284288, end_index: 284320
# Step [115500/---], Loss: 1.3610, Token Acc: 0.5625, Seq Acc: 0.1250
# Epoch: 5. start_index: 300288, end_index: 300320
# Step [116000/---], Loss: 1.1879, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 5. start_index: 316288, end_index: 316320
# Step [116500/---], Loss: 1.2349, Token Acc: 0.5417, Seq Acc: 0.2500
# Epoch: 5. start_index: 332288, end_index: 332320
# Step [117000/---], Loss: 1.2765, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 5. start_index: 348288, end_index: 348320
# Step [117500/---], Loss: 1.4258, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 5. start_index: 364288, end_index: 364320
# Step [118000/---], Loss: 1.4606, Token Acc: 0.5104, Seq Acc: 0.0938
# Epoch: 5. start_index: 380288, end_index: 380320
# Step [118500/---], Loss: 0.9573, Token Acc: 0.6667, Seq Acc: 0.3125
# Epoch: 5. start_index: 396288, end_index: 396320
# Step [119000/---], Loss: 1.0322, Token Acc: 0.6562, Seq Acc: 0.3125
# Epoch: 5. start_index: 412288, end_index: 412320
# Step [119500/---], Loss: 1.3066, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 5. start_index: 428288, end_index: 428320
# Step [120000/---], Loss: 1.1976, Token Acc: 0.5938, Seq Acc: 0.3125
# Epoch: 5. start_index: 444288, end_index: 444320
# Step [120500/---], Loss: 1.1331, Token Acc: 0.5833, Seq Acc: 0.3125
# Epoch: 5. start_index: 460288, end_index: 460320
# Step [121000/---], Loss: 1.1893, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 5. start_index: 476288, end_index: 476320
# Step [121500/---], Loss: 1.3731, Token Acc: 0.4792, Seq Acc: 0.0312
# Epoch: 5. start_index: 492288, end_index: 492320
# Step [122000/---], Loss: 1.2266, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 5. start_index: 508288, end_index: 508320
# Step [122500/---], Loss: 1.2156, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 5. start_index: 524288, end_index: 524320
# Step [123000/---], Loss: 1.3372, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 5. start_index: 540288, end_index: 540320
# Step [123500/---], Loss: 1.2208, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 5. start_index: 556288, end_index: 556320
# Step [124000/---], Loss: 1.0277, Token Acc: 0.6667, Seq Acc: 0.3125
# Epoch: 5. start_index: 572288, end_index: 572320
# Step [124500/---], Loss: 1.2534, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 5. start_index: 588288, end_index: 588320
# Step [125000/---], Loss: 1.3116, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 5. start_index: 604288, end_index: 604320
# Step [125500/---], Loss: 1.3054, Token Acc: 0.5417, Seq Acc: 0.1250
# Epoch: 5. start_index: 620288, end_index: 620320
# Step [126000/---], Loss: 1.0387, Token Acc: 0.6667, Seq Acc: 0.2500
# Epoch: 5. start_index: 636288, end_index: 636320
# Step [126500/---], Loss: 0.9921, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 5. start_index: 652288, end_index: 652320
# Step [127000/---], Loss: 1.1951, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 5. start_index: 668288, end_index: 668320
# Step [127500/---], Loss: 1.1227, Token Acc: 0.5938, Seq Acc: 0.1875
# Epoch: 6. start_index: 1952, end_index: 1984
# Step [128000/---], Loss: 1.1477, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 6. start_index: 17952, end_index: 17984
# Step [128500/---], Loss: 1.3548, Token Acc: 0.5104, Seq Acc: 0.1875
# Epoch: 6. start_index: 33952, end_index: 33984
# Step [129000/---], Loss: 1.0233, Token Acc: 0.6146, Seq Acc: 0.3438
# Epoch: 6. start_index: 49952, end_index: 49984
# Step [129500/---], Loss: 1.2020, Token Acc: 0.5729, Seq Acc: 0.2812
# Epoch: 6. start_index: 65952, end_index: 65984
# Step [130000/---], Loss: 1.1013, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 6. start_index: 81952, end_index: 81984
# Step [130500/---], Loss: 1.2152, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 6. start_index: 97952, end_index: 97984
# Step [131000/---], Loss: 1.3593, Token Acc: 0.4792, Seq Acc: 0.1250
# Epoch: 6. start_index: 113952, end_index: 113984
# Step [131500/---], Loss: 1.1125, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 6. start_index: 129952, end_index: 129984
# Step [132000/---], Loss: 1.0000, Token Acc: 0.6979, Seq Acc: 0.3438
# Epoch: 6. start_index: 145952, end_index: 145984
# Step [132500/---], Loss: 1.2813, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 6. start_index: 161952, end_index: 161984
# Step [133000/---], Loss: 1.0025, Token Acc: 0.6771, Seq Acc: 0.3125
# Epoch: 6. start_index: 177952, end_index: 177984
# Step [133500/---], Loss: 1.0767, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 6. start_index: 193952, end_index: 193984
# Step [134000/---], Loss: 1.0934, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 6. start_index: 209952, end_index: 209984
# Step [134500/---], Loss: 1.2969, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 6. start_index: 225952, end_index: 225984
# Step [135000/---], Loss: 1.0965, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 6. start_index: 241952, end_index: 241984
# Step [135500/---], Loss: 1.0922, Token Acc: 0.6042, Seq Acc: 0.2188
# Epoch: 6. start_index: 257952, end_index: 257984
# Step [136000/---], Loss: 1.1072, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 6. start_index: 273952, end_index: 273984
# Step [136500/---], Loss: 1.3294, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 6. start_index: 289952, end_index: 289984
# Step [137000/---], Loss: 1.1766, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 6. start_index: 305952, end_index: 305984
# Step [137500/---], Loss: 1.0590, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 6. start_index: 321952, end_index: 321984
# Step [138000/---], Loss: 1.1129, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 6. start_index: 337952, end_index: 337984
# Step [138500/---], Loss: 1.1980, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 6. start_index: 353952, end_index: 353984
# Step [139000/---], Loss: 1.2072, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 6. start_index: 369952, end_index: 369984
# Step [139500/---], Loss: 1.1823, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 6. start_index: 385952, end_index: 385984
# Step [140000/---], Loss: 1.2640, Token Acc: 0.5521, Seq Acc: 0.2188
# Epoch: 6. start_index: 401952, end_index: 401984
# Step [140500/---], Loss: 1.2033, Token Acc: 0.5104, Seq Acc: 0.1875
# Epoch: 6. start_index: 417952, end_index: 417984
# Step [141000/---], Loss: 1.1729, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 6. start_index: 433952, end_index: 433984
# Step [141500/---], Loss: 1.4826, Token Acc: 0.4688, Seq Acc: 0.1250
# Epoch: 6. start_index: 449952, end_index: 449984
# Step [142000/---], Loss: 1.2166, Token Acc: 0.5938, Seq Acc: 0.2500
# Epoch: 6. start_index: 465952, end_index: 465984
# Step [142500/---], Loss: 1.2154, Token Acc: 0.5521, Seq Acc: 0.2188
# Epoch: 6. start_index: 481952, end_index: 481984
# Step [143000/---], Loss: 1.0246, Token Acc: 0.6250, Seq Acc: 0.2812
# Epoch: 6. start_index: 497952, end_index: 497984
# Step [143500/---], Loss: 1.2179, Token Acc: 0.5312, Seq Acc: 0.1562
# Epoch: 6. start_index: 513952, end_index: 513984
# Step [144000/---], Loss: 1.2722, Token Acc: 0.5312, Seq Acc: 0.1250
# Epoch: 6. start_index: 529952, end_index: 529984
# Step [144500/---], Loss: 1.1267, Token Acc: 0.5938, Seq Acc: 0.2188
# Epoch: 6. start_index: 545952, end_index: 545984
# Step [145000/---], Loss: 1.1314, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 6. start_index: 561952, end_index: 561984
# Step [145500/---], Loss: 1.0832, Token Acc: 0.6250, Seq Acc: 0.3125
# Epoch: 6. start_index: 577952, end_index: 577984
# Step [146000/---], Loss: 1.1489, Token Acc: 0.5833, Seq Acc: 0.1875
# Epoch: 6. start_index: 593952, end_index: 593984
# Step [146500/---], Loss: 1.2478, Token Acc: 0.5000, Seq Acc: 0.1875
# Epoch: 6. start_index: 609952, end_index: 609984
# Step [147000/---], Loss: 1.1364, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 6. start_index: 625952, end_index: 625984
# Step [147500/---], Loss: 0.8817, Token Acc: 0.6875, Seq Acc: 0.5000
# Epoch: 6. start_index: 641952, end_index: 641984
# Step [148000/---], Loss: 1.1009, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 6. start_index: 657952, end_index: 657984
# Step [148500/---], Loss: 1.2371, Token Acc: 0.4792, Seq Acc: 0.0625
# Epoch: 6. start_index: 673952, end_index: 673984
# Step [149000/---], Loss: 1.1780, Token Acc: 0.5625, Seq Acc: 0.2188
# Epoch: 7. start_index: 7616, end_index: 7648
# Step [149500/---], Loss: 1.3276, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 7. start_index: 23616, end_index: 23648
# Step [150000/---], Loss: 1.3544, Token Acc: 0.5000, Seq Acc: 0.1562
# Epoch: 7. start_index: 39616, end_index: 39648
# Step [150500/---], Loss: 1.0420, Token Acc: 0.6042, Seq Acc: 0.3750
# Epoch: 7. start_index: 55616, end_index: 55648
# Step [151000/---], Loss: 0.9940, Token Acc: 0.6979, Seq Acc: 0.3438
# Epoch: 7. start_index: 71616, end_index: 71648
# Step [151500/---], Loss: 1.1214, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 7. start_index: 87616, end_index: 87648
# Step [152000/---], Loss: 1.3584, Token Acc: 0.4896, Seq Acc: 0.0938
# Epoch: 7. start_index: 103616, end_index: 103648
# Step [152500/---], Loss: 1.1887, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 7. start_index: 119616, end_index: 119648
# Step [153000/---], Loss: 1.0890, Token Acc: 0.5729, Seq Acc: 0.3125
# Epoch: 7. start_index: 135616, end_index: 135648
# Step [153500/---], Loss: 1.0960, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 7. start_index: 151616, end_index: 151648
# Step [154000/---], Loss: 1.2659, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 7. start_index: 167616, end_index: 167648
# Step [154500/---], Loss: 1.1969, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 7. start_index: 183616, end_index: 183648
# Step [155000/---], Loss: 1.1336, Token Acc: 0.5625, Seq Acc: 0.1562
# Epoch: 7. start_index: 199616, end_index: 199648
# Step [155500/---], Loss: 1.1992, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 7. start_index: 215616, end_index: 215648
# Step [156000/---], Loss: 1.1779, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 7. start_index: 231616, end_index: 231648
# Step [156500/---], Loss: 1.3346, Token Acc: 0.5208, Seq Acc: 0.1875
# Epoch: 7. start_index: 247616, end_index: 247648
# Step [157000/---], Loss: 0.9875, Token Acc: 0.6562, Seq Acc: 0.4062
# Epoch: 7. start_index: 263616, end_index: 263648
# Step [157500/---], Loss: 1.3254, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 7. start_index: 279616, end_index: 279648
# Step [158000/---], Loss: 1.1130, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 7. start_index: 295616, end_index: 295648
# Step [158500/---], Loss: 1.3535, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 7. start_index: 311616, end_index: 311648
# Step [159000/---], Loss: 1.3240, Token Acc: 0.5312, Seq Acc: 0.1875
# Epoch: 7. start_index: 327616, end_index: 327648
# Step [159500/---], Loss: 0.8692, Token Acc: 0.7188, Seq Acc: 0.4375
# Epoch: 7. start_index: 343616, end_index: 343648
# Step [160000/---], Loss: 1.1704, Token Acc: 0.6146, Seq Acc: 0.2188
# Epoch: 7. start_index: 359616, end_index: 359648
# Step [160500/---], Loss: 1.1057, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 7. start_index: 375616, end_index: 375648
# Step [161000/---], Loss: 1.1932, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 7. start_index: 391616, end_index: 391648
# Step [161500/---], Loss: 0.9831, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 7. start_index: 407616, end_index: 407648
# Step [162000/---], Loss: 1.0633, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 7. start_index: 423616, end_index: 423648
# Step [162500/---], Loss: 1.2233, Token Acc: 0.5521, Seq Acc: 0.2812
# Epoch: 7. start_index: 439616, end_index: 439648
# Step [163000/---], Loss: 1.1598, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 7. start_index: 455616, end_index: 455648
# Step [163500/---], Loss: 1.0652, Token Acc: 0.6354, Seq Acc: 0.3750
# Epoch: 7. start_index: 471616, end_index: 471648
# Step [164000/---], Loss: 1.1418, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 7. start_index: 487616, end_index: 487648
# Step [164500/---], Loss: 1.1647, Token Acc: 0.5417, Seq Acc: 0.0938
# Epoch: 7. start_index: 503616, end_index: 503648
# Step [165000/---], Loss: 1.1799, Token Acc: 0.5833, Seq Acc: 0.3125
# Epoch: 7. start_index: 519616, end_index: 519648
# Step [165500/---], Loss: 1.1295, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 7. start_index: 535616, end_index: 535648
# Step [166000/---], Loss: 1.1535, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 7. start_index: 551616, end_index: 551648
# Step [166500/---], Loss: 1.2029, Token Acc: 0.5833, Seq Acc: 0.2500
# Epoch: 7. start_index: 567616, end_index: 567648
# Step [167000/---], Loss: 1.0274, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 7. start_index: 583616, end_index: 583648
# Step [167500/---], Loss: 1.1084, Token Acc: 0.6354, Seq Acc: 0.2500
# Epoch: 7. start_index: 599616, end_index: 599648
# Step [168000/---], Loss: 1.1492, Token Acc: 0.6146, Seq Acc: 0.3438
# Epoch: 7. start_index: 615616, end_index: 615648
# Step [168500/---], Loss: 0.9673, Token Acc: 0.6667, Seq Acc: 0.3125
# Epoch: 7. start_index: 631616, end_index: 631648
# Step [169000/---], Loss: 1.3795, Token Acc: 0.4896, Seq Acc: 0.0938
# Epoch: 7. start_index: 647616, end_index: 647648
# Step [169500/---], Loss: 0.9531, Token Acc: 0.6875, Seq Acc: 0.3750
# Epoch: 7. start_index: 663616, end_index: 663648
# Step [170000/---], Loss: 1.2043, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 7. start_index: 679616, end_index: 679648
# Step [170500/---], Loss: 1.3022, Token Acc: 0.5208, Seq Acc: 0.1875
# Epoch: 8. start_index: 13280, end_index: 13312
# Step [171000/---], Loss: 1.1209, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 8. start_index: 29280, end_index: 29312
# Step [171500/---], Loss: 1.1363, Token Acc: 0.5208, Seq Acc: 0.0938
# Epoch: 8. start_index: 45280, end_index: 45312
# Step [172000/---], Loss: 1.4205, Token Acc: 0.4688, Seq Acc: 0.1250
# Epoch: 8. start_index: 61280, end_index: 61312
# Step [172500/---], Loss: 1.3671, Token Acc: 0.4896, Seq Acc: 0.1250
# Epoch: 8. start_index: 77280, end_index: 77312
# Step [173000/---], Loss: 0.7131, Token Acc: 0.7917, Seq Acc: 0.5312
# Epoch: 8. start_index: 93280, end_index: 93312
# Step [173500/---], Loss: 1.1787, Token Acc: 0.6042, Seq Acc: 0.2500
# Epoch: 8. start_index: 109280, end_index: 109312
# Step [174000/---], Loss: 1.0658, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 8. start_index: 125280, end_index: 125312
# Step [174500/---], Loss: 1.1968, Token Acc: 0.5938, Seq Acc: 0.2188
# Epoch: 8. start_index: 141280, end_index: 141312
# Step [175000/---], Loss: 0.9761, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 8. start_index: 157280, end_index: 157312
# Step [175500/---], Loss: 1.0651, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 8. start_index: 173280, end_index: 173312
# Step [176000/---], Loss: 1.3069, Token Acc: 0.5208, Seq Acc: 0.1562
# Epoch: 8. start_index: 189280, end_index: 189312
# Step [176500/---], Loss: 1.2155, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 8. start_index: 205280, end_index: 205312
# Step [177000/---], Loss: 1.1307, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 8. start_index: 221280, end_index: 221312
# Step [177500/---], Loss: 1.1430, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 8. start_index: 237280, end_index: 237312
# Step [178000/---], Loss: 0.9853, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 8. start_index: 253280, end_index: 253312
# Step [178500/---], Loss: 1.3761, Token Acc: 0.5104, Seq Acc: 0.1250
# Epoch: 8. start_index: 269280, end_index: 269312
# Step [179000/---], Loss: 1.1166, Token Acc: 0.6458, Seq Acc: 0.2500
# Epoch: 8. start_index: 285280, end_index: 285312
# Step [179500/---], Loss: 1.2001, Token Acc: 0.5833, Seq Acc: 0.3125
# Epoch: 8. start_index: 301280, end_index: 301312
# Step [180000/---], Loss: 1.3977, Token Acc: 0.4167, Seq Acc: 0.1875
# Epoch: 8. start_index: 317280, end_index: 317312
# Step [180500/---], Loss: 1.2554, Token Acc: 0.5104, Seq Acc: 0.1562
# Epoch: 8. start_index: 333280, end_index: 333312
# Step [181000/---], Loss: 1.1361, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 8. start_index: 349280, end_index: 349312
# Step [181500/---], Loss: 1.2278, Token Acc: 0.5000, Seq Acc: 0.0938
# Epoch: 8. start_index: 365280, end_index: 365312
# Step [182000/---], Loss: 1.2562, Token Acc: 0.4896, Seq Acc: 0.1875
# Epoch: 8. start_index: 381280, end_index: 381312
# Step [182500/---], Loss: 1.0387, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 8. start_index: 397280, end_index: 397312
# Step [183000/---], Loss: 0.9766, Token Acc: 0.6562, Seq Acc: 0.3125
# Epoch: 8. start_index: 413280, end_index: 413312
# Step [183500/---], Loss: 1.2406, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 8. start_index: 429280, end_index: 429312
# Step [184000/---], Loss: 1.0450, Token Acc: 0.6354, Seq Acc: 0.2500
# Epoch: 8. start_index: 445280, end_index: 445312
# Step [184500/---], Loss: 1.0554, Token Acc: 0.6667, Seq Acc: 0.3750
# Epoch: 8. start_index: 461280, end_index: 461312
# Step [185000/---], Loss: 1.0309, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 8. start_index: 477280, end_index: 477312
# Step [185500/---], Loss: 1.2145, Token Acc: 0.5208, Seq Acc: 0.1250
# Epoch: 8. start_index: 493280, end_index: 493312
# Step [186000/---], Loss: 1.2840, Token Acc: 0.5625, Seq Acc: 0.1875
# Epoch: 8. start_index: 509280, end_index: 509312
# Step [186500/---], Loss: 1.1379, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 8. start_index: 525280, end_index: 525312
# Step [187000/---], Loss: 1.0712, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 8. start_index: 541280, end_index: 541312
# Step [187500/---], Loss: 1.0639, Token Acc: 0.5938, Seq Acc: 0.2500
# Epoch: 8. start_index: 557280, end_index: 557312
# Step [188000/---], Loss: 1.1472, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 8. start_index: 573280, end_index: 573312
# Step [188500/---], Loss: 1.1778, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 8. start_index: 589280, end_index: 589312
# Step [189000/---], Loss: 1.1696, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 8. start_index: 605280, end_index: 605312
# Step [189500/---], Loss: 1.0224, Token Acc: 0.6667, Seq Acc: 0.3750
# Epoch: 8. start_index: 621280, end_index: 621312
# Step [190000/---], Loss: 1.1503, Token Acc: 0.5833, Seq Acc: 0.1875
# Epoch: 8. start_index: 637280, end_index: 637312
# Step [190500/---], Loss: 1.2124, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 8. start_index: 653280, end_index: 653312
# Step [191000/---], Loss: 1.3915, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 8. start_index: 669280, end_index: 669312
# Step [191500/---], Loss: 1.0926, Token Acc: 0.6354, Seq Acc: 0.2812
# Epoch: 9. start_index: 2944, end_index: 2976
# Step [192000/---], Loss: 1.0616, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 9. start_index: 18944, end_index: 18976
# Step [192500/---], Loss: 1.1940, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 9. start_index: 34944, end_index: 34976
# Step [193000/---], Loss: 1.0802, Token Acc: 0.5938, Seq Acc: 0.2188
# Epoch: 9. start_index: 50944, end_index: 50976
# Step [193500/---], Loss: 0.9867, Token Acc: 0.6146, Seq Acc: 0.3750
# Epoch: 9. start_index: 66944, end_index: 66976
# Step [194000/---], Loss: 1.5469, Token Acc: 0.4375, Seq Acc: 0.0938
# Epoch: 9. start_index: 82944, end_index: 82976
# Step [194500/---], Loss: 1.1121, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 9. start_index: 98944, end_index: 98976
# Step [195000/---], Loss: 1.0462, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 9. start_index: 114944, end_index: 114976
# Step [195500/---], Loss: 1.0308, Token Acc: 0.6562, Seq Acc: 0.3125
# Epoch: 9. start_index: 130944, end_index: 130976
# Step [196000/---], Loss: 1.2273, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 9. start_index: 146944, end_index: 146976
# Step [196500/---], Loss: 1.0639, Token Acc: 0.6250, Seq Acc: 0.3125
# Epoch: 9. start_index: 162944, end_index: 162976
# Step [197000/---], Loss: 1.0105, Token Acc: 0.6771, Seq Acc: 0.3438
# Epoch: 9. start_index: 178944, end_index: 178976
# Step [197500/---], Loss: 1.0687, Token Acc: 0.6354, Seq Acc: 0.2812
# Epoch: 9. start_index: 194944, end_index: 194976
# Step [198000/---], Loss: 1.3504, Token Acc: 0.4896, Seq Acc: 0.1875
# Epoch: 9. start_index: 210944, end_index: 210976
# Step [198500/---], Loss: 1.2645, Token Acc: 0.5833, Seq Acc: 0.2188
# Epoch: 9. start_index: 226944, end_index: 226976
# Step [199000/---], Loss: 1.1391, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 9. start_index: 242944, end_index: 242976
# Step [199500/---], Loss: 1.1012, Token Acc: 0.6042, Seq Acc: 0.3750
# Epoch: 9. start_index: 258944, end_index: 258976
# Step [200000/---], Loss: 1.2734, Token Acc: 0.5417, Seq Acc: 0.2500
# Epoch: 9. start_index: 274944, end_index: 274976
# Step [200500/---], Loss: 1.2149, Token Acc: 0.5625, Seq Acc: 0.1562
# Epoch: 9. start_index: 290944, end_index: 290976
# Step [201000/---], Loss: 1.0868, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 9. start_index: 306944, end_index: 306976
# Step [201500/---], Loss: 1.0496, Token Acc: 0.6458, Seq Acc: 0.2812
# Epoch: 9. start_index: 322944, end_index: 322976
# Step [202000/---], Loss: 1.2963, Token Acc: 0.5000, Seq Acc: 0.1562
# Epoch: 9. start_index: 338944, end_index: 338976
# Step [202500/---], Loss: 0.8919, Token Acc: 0.6771, Seq Acc: 0.3438
# Epoch: 9. start_index: 354944, end_index: 354976
# Step [203000/---], Loss: 1.1049, Token Acc: 0.5938, Seq Acc: 0.2500
# Epoch: 9. start_index: 370944, end_index: 370976
# Step [203500/---], Loss: 1.1908, Token Acc: 0.4792, Seq Acc: 0.1250
# Epoch: 9. start_index: 386944, end_index: 386976
# Step [204000/---], Loss: 1.1723, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 9. start_index: 402944, end_index: 402976
# Step [204500/---], Loss: 1.0211, Token Acc: 0.6146, Seq Acc: 0.3125
# Epoch: 9. start_index: 418944, end_index: 418976
# Step [205000/---], Loss: 1.3432, Token Acc: 0.5312, Seq Acc: 0.2188
# Epoch: 9. start_index: 434944, end_index: 434976
# Step [205500/---], Loss: 0.9019, Token Acc: 0.6562, Seq Acc: 0.3438
# Epoch: 9. start_index: 450944, end_index: 450976
# Step [206000/---], Loss: 1.2323, Token Acc: 0.5521, Seq Acc: 0.1562
# Epoch: 9. start_index: 466944, end_index: 466976
# Step [206500/---], Loss: 0.9399, Token Acc: 0.6771, Seq Acc: 0.3438
# ...
# Epoch: 46. start_index: 596512, end_index: 596544
# Step [999500/---], Loss: 1.1262, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 46. start_index: 612512, end_index: 612544
# Step [1000000/---], Loss: 1.0345, Token Acc: 0.6875, Seq Acc: 0.3750
# Epoch: 46. start_index: 628512, end_index: 628544
# Step [1000500/---], Loss: 1.0349, Token Acc: 0.6562, Seq Acc: 0.4062
# Epoch: 46. start_index: 644512, end_index: 644544
# Step [1001000/---], Loss: 1.0803, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 46. start_index: 660512, end_index: 660544
# Step [1001500/---], Loss: 1.0984, Token Acc: 0.5625, Seq Acc: 0.3125
# Epoch: 46. start_index: 676512, end_index: 676544
# Step [1002000/---], Loss: 0.9754, Token Acc: 0.6354, Seq Acc: 0.3750
# Epoch: 47. start_index: 10176, end_index: 10208
# Step [1002500/---], Loss: 1.2126, Token Acc: 0.5729, Seq Acc: 0.2812
# Epoch: 47. start_index: 26176, end_index: 26208
# Step [1003000/---], Loss: 0.9398, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 47. start_index: 42176, end_index: 42208
# Step [1003500/---], Loss: 0.8764, Token Acc: 0.6875, Seq Acc: 0.3125
# Epoch: 47. start_index: 58176, end_index: 58208
# Step [1004000/---], Loss: 0.9372, Token Acc: 0.6458, Seq Acc: 0.4062
# Epoch: 47. start_index: 74176, end_index: 74208
# Step [1004500/---], Loss: 1.1286, Token Acc: 0.6250, Seq Acc: 0.2812
# Epoch: 47. start_index: 90176, end_index: 90208
# Step [1005000/---], Loss: 1.1960, Token Acc: 0.5938, Seq Acc: 0.3125
# Epoch: 47. start_index: 106176, end_index: 106208
# Step [1005500/---], Loss: 0.8621, Token Acc: 0.6562, Seq Acc: 0.4375
# Epoch: 47. start_index: 122176, end_index: 122208
# Step [1006000/---], Loss: 0.9764, Token Acc: 0.6458, Seq Acc: 0.3750
# Epoch: 47. start_index: 138176, end_index: 138208
# Step [1006500/---], Loss: 1.0185, Token Acc: 0.6458, Seq Acc: 0.2812
# Epoch: 47. start_index: 154176, end_index: 154208
# Step [1007000/---], Loss: 0.8759, Token Acc: 0.6979, Seq Acc: 0.4062
# Epoch: 47. start_index: 170176, end_index: 170208
# Step [1007500/---], Loss: 1.0778, Token Acc: 0.5938, Seq Acc: 0.3125
# Epoch: 47. start_index: 186176, end_index: 186208
# Step [1008000/---], Loss: 0.8275, Token Acc: 0.6667, Seq Acc: 0.4062
# Epoch: 47. start_index: 202176, end_index: 202208
# Step [1008500/---], Loss: 1.0077, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 47. start_index: 218176, end_index: 218208
# Step [1009000/---], Loss: 1.1528, Token Acc: 0.5000, Seq Acc: 0.2500
# Epoch: 47. start_index: 234176, end_index: 234208
# Step [1009500/---], Loss: 0.8457, Token Acc: 0.6875, Seq Acc: 0.4062
# Epoch: 47. start_index: 250176, end_index: 250208
# Step [1010000/---], Loss: 0.9574, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 47. start_index: 266176, end_index: 266208
# Step [1010500/---], Loss: 0.8995, Token Acc: 0.6562, Seq Acc: 0.4062
# Epoch: 47. start_index: 282176, end_index: 282208
# Step [1011000/---], Loss: 1.2056, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 47. start_index: 298176, end_index: 298208
# Step [1011500/---], Loss: 1.0616, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 47. start_index: 314176, end_index: 314208
# Step [1012000/---], Loss: 1.1542, Token Acc: 0.5104, Seq Acc: 0.2500
# Epoch: 47. start_index: 330176, end_index: 330208
# Step [1012500/---], Loss: 1.2729, Token Acc: 0.4167, Seq Acc: 0.2188
# Epoch: 47. start_index: 346176, end_index: 346208
# Step [1013000/---], Loss: 1.0206, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 47. start_index: 362176, end_index: 362208
# Step [1013500/---], Loss: 1.0630, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 47. start_index: 378176, end_index: 378208
# Step [1014000/---], Loss: 0.9066, Token Acc: 0.6979, Seq Acc: 0.4062
# Epoch: 47. start_index: 394176, end_index: 394208
# Step [1014500/---], Loss: 1.2186, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 47. start_index: 410176, end_index: 410208
# Step [1015000/---], Loss: 1.0704, Token Acc: 0.5208, Seq Acc: 0.3125
# Epoch: 47. start_index: 426176, end_index: 426208
# Step [1015500/---], Loss: 1.1218, Token Acc: 0.5938, Seq Acc: 0.2188
# Epoch: 47. start_index: 442176, end_index: 442208
# Step [1016000/---], Loss: 0.8967, Token Acc: 0.6979, Seq Acc: 0.4375
# Epoch: 47. start_index: 458176, end_index: 458208
# Step [1016500/---], Loss: 1.0996, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 47. start_index: 474176, end_index: 474208
# Step [1017000/---], Loss: 1.4372, Token Acc: 0.5521, Seq Acc: 0.2812
# Epoch: 47. start_index: 490176, end_index: 490208
# Step [1017500/---], Loss: 1.1261, Token Acc: 0.6146, Seq Acc: 0.2188
# Epoch: 47. start_index: 506176, end_index: 506208
# Step [1018000/---], Loss: 1.1948, Token Acc: 0.5417, Seq Acc: 0.1562
# Epoch: 47. start_index: 522176, end_index: 522208
# Step [1018500/---], Loss: 1.1954, Token Acc: 0.5729, Seq Acc: 0.2500
# Epoch: 47. start_index: 538176, end_index: 538208
# Step [1019000/---], Loss: 0.9024, Token Acc: 0.6667, Seq Acc: 0.4688
# Epoch: 47. start_index: 554176, end_index: 554208
# Step [1019500/---], Loss: 1.1553, Token Acc: 0.5729, Seq Acc: 0.1875
# Epoch: 47. start_index: 570176, end_index: 570208
# Step [1020000/---], Loss: 1.3198, Token Acc: 0.5521, Seq Acc: 0.1875
# Epoch: 47. start_index: 586176, end_index: 586208
# Step [1020500/---], Loss: 0.9158, Token Acc: 0.6771, Seq Acc: 0.3750
# Epoch: 47. start_index: 602176, end_index: 602208
# Step [1021000/---], Loss: 0.8607, Token Acc: 0.7083, Seq Acc: 0.5000
# Epoch: 47. start_index: 618176, end_index: 618208
# Step [1021500/---], Loss: 0.9351, Token Acc: 0.6146, Seq Acc: 0.3438
# Epoch: 47. start_index: 634176, end_index: 634208
# Step [1022000/---], Loss: 1.1090, Token Acc: 0.5104, Seq Acc: 0.1875
# Epoch: 47. start_index: 650176, end_index: 650208
# Step [1022500/---], Loss: 1.0144, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 47. start_index: 666176, end_index: 666208
# Step [1023000/---], Loss: 1.1189, Token Acc: 0.6250, Seq Acc: 0.3750
# Epoch: 47. start_index: 682176, end_index: 682208
# Step [1023500/---], Loss: 1.1967, Token Acc: 0.5521, Seq Acc: 0.2812
# Epoch: 48. start_index: 15840, end_index: 15872
# Step [1024000/---], Loss: 1.1655, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 48. start_index: 31840, end_index: 31872
# Step [1024500/---], Loss: 1.1723, Token Acc: 0.5625, Seq Acc: 0.3125
# Epoch: 48. start_index: 47840, end_index: 47872
# Step [1025000/---], Loss: 0.8899, Token Acc: 0.6146, Seq Acc: 0.4062
# Epoch: 48. start_index: 63840, end_index: 63872
# Step [1025500/---], Loss: 0.9267, Token Acc: 0.6979, Seq Acc: 0.4375
# Epoch: 48. start_index: 79840, end_index: 79872
# Step [1026000/---], Loss: 1.2440, Token Acc: 0.5208, Seq Acc: 0.2500
# Epoch: 48. start_index: 95840, end_index: 95872
# Step [1026500/---], Loss: 1.0564, Token Acc: 0.5938, Seq Acc: 0.3438
# Epoch: 48. start_index: 111840, end_index: 111872
# Step [1027000/---], Loss: 1.0371, Token Acc: 0.6562, Seq Acc: 0.3125
# Epoch: 48. start_index: 127840, end_index: 127872
# Step [1027500/---], Loss: 0.7912, Token Acc: 0.6875, Seq Acc: 0.4062
# Epoch: 48. start_index: 143840, end_index: 143872
# Step [1028000/---], Loss: 1.1458, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 48. start_index: 159840, end_index: 159872
# Step [1028500/---], Loss: 1.0514, Token Acc: 0.6042, Seq Acc: 0.2812
# Epoch: 48. start_index: 175840, end_index: 175872
# Step [1029000/---], Loss: 0.9793, Token Acc: 0.6771, Seq Acc: 0.4062
# Epoch: 48. start_index: 191840, end_index: 191872
# Step [1029500/---], Loss: 0.7823, Token Acc: 0.7292, Seq Acc: 0.4688
# Epoch: 48. start_index: 207840, end_index: 207872
# Step [1030000/---], Loss: 0.9571, Token Acc: 0.6667, Seq Acc: 0.3750
# Epoch: 48. start_index: 223840, end_index: 223872
# Step [1030500/---], Loss: 0.9920, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 48. start_index: 239840, end_index: 239872
# Step [1031000/---], Loss: 0.9715, Token Acc: 0.6458, Seq Acc: 0.4062
# Epoch: 48. start_index: 255840, end_index: 255872
# Step [1031500/---], Loss: 1.2290, Token Acc: 0.5208, Seq Acc: 0.1562
# Epoch: 48. start_index: 271840, end_index: 271872
# Step [1032000/---], Loss: 1.1026, Token Acc: 0.6250, Seq Acc: 0.3125
# Epoch: 48. start_index: 287840, end_index: 287872
# Step [1032500/---], Loss: 1.1363, Token Acc: 0.5625, Seq Acc: 0.1562
# Epoch: 48. start_index: 303840, end_index: 303872
# Step [1033000/---], Loss: 0.9509, Token Acc: 0.6562, Seq Acc: 0.4375
# Epoch: 48. start_index: 319840, end_index: 319872
# Step [1033500/---], Loss: 0.9357, Token Acc: 0.6354, Seq Acc: 0.4062
# Epoch: 48. start_index: 335840, end_index: 335872
# Step [1034000/---], Loss: 1.1659, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 48. start_index: 351840, end_index: 351872
# Step [1034500/---], Loss: 1.1790, Token Acc: 0.5729, Seq Acc: 0.2812
# Epoch: 48. start_index: 367840, end_index: 367872
# Step [1035000/---], Loss: 1.1048, Token Acc: 0.4688, Seq Acc: 0.1562
# Epoch: 48. start_index: 383840, end_index: 383872
# Step [1035500/---], Loss: 1.0430, Token Acc: 0.6458, Seq Acc: 0.4062
# Epoch: 48. start_index: 399840, end_index: 399872
# Step [1036000/---], Loss: 1.0974, Token Acc: 0.5417, Seq Acc: 0.3125
# Epoch: 48. start_index: 415840, end_index: 415872
# Step [1036500/---], Loss: 1.1932, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 48. start_index: 431840, end_index: 431872
# Step [1037000/---], Loss: 1.0925, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 48. start_index: 447840, end_index: 447872
# Step [1037500/---], Loss: 1.1712, Token Acc: 0.5417, Seq Acc: 0.1875
# Epoch: 48. start_index: 463840, end_index: 463872
# Step [1038000/---], Loss: 1.0986, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 48. start_index: 479840, end_index: 479872
# Step [1038500/---], Loss: 1.0483, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 48. start_index: 495840, end_index: 495872
# Step [1039000/---], Loss: 1.2400, Token Acc: 0.5521, Seq Acc: 0.2188
# Epoch: 48. start_index: 511840, end_index: 511872
# Step [1039500/---], Loss: 1.0353, Token Acc: 0.5938, Seq Acc: 0.4375
# Epoch: 48. start_index: 527840, end_index: 527872
# Step [1040000/---], Loss: 1.1226, Token Acc: 0.5208, Seq Acc: 0.2812
# Epoch: 48. start_index: 543840, end_index: 543872
# Step [1040500/---], Loss: 1.0964, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 48. start_index: 559840, end_index: 559872
# Step [1041000/---], Loss: 1.0596, Token Acc: 0.6354, Seq Acc: 0.3125
# Epoch: 48. start_index: 575840, end_index: 575872
# Step [1041500/---], Loss: 1.0180, Token Acc: 0.6667, Seq Acc: 0.3750
# Epoch: 48. start_index: 591840, end_index: 591872
# Step [1042000/---], Loss: 1.0151, Token Acc: 0.5938, Seq Acc: 0.2500
# Epoch: 48. start_index: 607840, end_index: 607872
# Step [1042500/---], Loss: 1.0820, Token Acc: 0.5521, Seq Acc: 0.3125
# Epoch: 48. start_index: 623840, end_index: 623872
# Step [1043000/---], Loss: 1.0846, Token Acc: 0.6458, Seq Acc: 0.3125
# Epoch: 48. start_index: 639840, end_index: 639872
# Step [1043500/---], Loss: 0.8358, Token Acc: 0.6458, Seq Acc: 0.3750
# Epoch: 48. start_index: 655840, end_index: 655872
# Step [1044000/---], Loss: 1.0107, Token Acc: 0.6458, Seq Acc: 0.3438
# Epoch: 48. start_index: 671840, end_index: 671872
# Step [1044500/---], Loss: 1.0184, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 49. start_index: 5504, end_index: 5536
# Step [1045000/---], Loss: 0.9336, Token Acc: 0.6354, Seq Acc: 0.3750
# Epoch: 49. start_index: 21504, end_index: 21536
# Step [1045500/---], Loss: 1.0548, Token Acc: 0.5625, Seq Acc: 0.2812
# Epoch: 49. start_index: 37504, end_index: 37536
# Step [1046000/---], Loss: 1.0422, Token Acc: 0.6354, Seq Acc: 0.3438
# Epoch: 49. start_index: 53504, end_index: 53536
# Step [1046500/---], Loss: 1.0958, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 49. start_index: 69504, end_index: 69536
# Step [1047000/---], Loss: 1.0269, Token Acc: 0.6146, Seq Acc: 0.2500
# Epoch: 49. start_index: 85504, end_index: 85536
# Step [1047500/---], Loss: 0.9748, Token Acc: 0.5833, Seq Acc: 0.3438
# Epoch: 49. start_index: 101504, end_index: 101536
# Step [1048000/---], Loss: 1.0836, Token Acc: 0.6042, Seq Acc: 0.3125
# Epoch: 49. start_index: 117504, end_index: 117536
# Step [1048500/---], Loss: 0.8868, Token Acc: 0.7500, Seq Acc: 0.4688
# Epoch: 49. start_index: 133504, end_index: 133536
# Step [1049000/---], Loss: 1.0714, Token Acc: 0.6042, Seq Acc: 0.3438
# Epoch: 49. start_index: 149504, end_index: 149536
# Step [1049500/---], Loss: 1.1633, Token Acc: 0.6146, Seq Acc: 0.3438
# Epoch: 49. start_index: 165504, end_index: 165536
# Step [1050000/---], Loss: 1.0623, Token Acc: 0.5938, Seq Acc: 0.3125
# Epoch: 49. start_index: 181504, end_index: 181536
# Step [1050500/---], Loss: 1.0134, Token Acc: 0.6146, Seq Acc: 0.3750
# Epoch: 49. start_index: 197504, end_index: 197536
# Step [1051000/---], Loss: 0.8958, Token Acc: 0.6562, Seq Acc: 0.4062
# Epoch: 49. start_index: 213504, end_index: 213536
# Step [1051500/---], Loss: 0.9456, Token Acc: 0.6250, Seq Acc: 0.2812
# Epoch: 49. start_index: 229504, end_index: 229536
# Step [1052000/---], Loss: 1.0027, Token Acc: 0.6042, Seq Acc: 0.3438
# Epoch: 49. start_index: 245504, end_index: 245536
# Step [1052500/---], Loss: 0.8713, Token Acc: 0.6458, Seq Acc: 0.4062
# Epoch: 49. start_index: 261504, end_index: 261536
# Step [1053000/---], Loss: 1.1290, Token Acc: 0.5625, Seq Acc: 0.2500
# Epoch: 49. start_index: 277504, end_index: 277536
# Step [1053500/---], Loss: 0.9350, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 49. start_index: 293504, end_index: 293536
# Step [1054000/---], Loss: 1.0794, Token Acc: 0.5521, Seq Acc: 0.2500
# Epoch: 49. start_index: 309504, end_index: 309536
# Step [1054500/---], Loss: 1.0184, Token Acc: 0.6146, Seq Acc: 0.2812
# Epoch: 49. start_index: 325504, end_index: 325536
# Step [1055000/---], Loss: 1.1939, Token Acc: 0.5312, Seq Acc: 0.2500
# Epoch: 49. start_index: 341504, end_index: 341536
# Step [1055500/---], Loss: 1.3046, Token Acc: 0.5208, Seq Acc: 0.2188
# Epoch: 49. start_index: 357504, end_index: 357536
# Step [1056000/---], Loss: 1.0935, Token Acc: 0.5833, Seq Acc: 0.2812
# Epoch: 49. start_index: 373504, end_index: 373536
# Step [1056500/---], Loss: 1.2098, Token Acc: 0.5208, Seq Acc: 0.1562
# Epoch: 49. start_index: 389504, end_index: 389536
# Step [1057000/---], Loss: 0.9412, Token Acc: 0.6250, Seq Acc: 0.3438
# Epoch: 49. start_index: 405504, end_index: 405536
# Step [1057500/---], Loss: 1.0367, Token Acc: 0.5938, Seq Acc: 0.2812
# Epoch: 49. start_index: 421504, end_index: 421536
# Step [1058000/---], Loss: 0.8923, Token Acc: 0.6771, Seq Acc: 0.4062
# Epoch: 49. start_index: 437504, end_index: 437536
# Step [1058500/---], Loss: 0.7846, Token Acc: 0.7188, Seq Acc: 0.5312
# Epoch: 49. start_index: 453504, end_index: 453536
# Step [1059000/---], Loss: 0.9018, Token Acc: 0.6979, Seq Acc: 0.5000
# Epoch: 49. start_index: 469504, end_index: 469536
# Step [1059500/---], Loss: 0.9285, Token Acc: 0.6667, Seq Acc: 0.3750
# Epoch: 49. start_index: 485504, end_index: 485536
# Step [1060000/---], Loss: 0.7649, Token Acc: 0.7188, Seq Acc: 0.4688
# Epoch: 49. start_index: 501504, end_index: 501536
# Step [1060500/---], Loss: 1.2078, Token Acc: 0.5104, Seq Acc: 0.2812
# Epoch: 49. start_index: 517504, end_index: 517536
# Step [1061000/---], Loss: 0.9334, Token Acc: 0.7083, Seq Acc: 0.4062
# Epoch: 49. start_index: 533504, end_index: 533536
# Step [1061500/---], Loss: 1.0579, Token Acc: 0.5729, Seq Acc: 0.2188
# Epoch: 49. start_index: 549504, end_index: 549536
# Step [1062000/---], Loss: 0.8167, Token Acc: 0.7188, Seq Acc: 0.5000
# Epoch: 49. start_index: 565504, end_index: 565536
# Step [1062500/---], Loss: 1.0724, Token Acc: 0.6771, Seq Acc: 0.3750
# Epoch: 49. start_index: 581504, end_index: 581536
# Step [1063000/---], Loss: 1.0626, Token Acc: 0.5833, Seq Acc: 0.3750
# Epoch: 49. start_index: 597504, end_index: 597536
# Step [1063500/---], Loss: 0.9343, Token Acc: 0.6250, Seq Acc: 0.2500
# Epoch: 49. start_index: 613504, end_index: 613536
# Step [1064000/---], Loss: 0.9012, Token Acc: 0.6875, Seq Acc: 0.4375
# Epoch: 49. start_index: 629504, end_index: 629536
# Step [1064500/---], Loss: 1.0456, Token Acc: 0.6042, Seq Acc: 0.3750
# Epoch: 49. start_index: 645504, end_index: 645536
# Step [1065000/---], Loss: 0.8443, Token Acc: 0.6875, Seq Acc: 0.4062
# Epoch: 49. start_index: 661504, end_index: 661536
# Step [1065500/---], Loss: 1.1355, Token Acc: 0.6042, Seq Acc: 0.3438
# Epoch: 49. start_index: 677504, end_index: 677536
# Step [1066000/---], Loss: 0.8354, Token Acc: 0.7083, Seq Acc: 0.4688
# Translator training finished.

# %%
# Training graphs
plot_metric(losses, step_size=50, metric_name='Translator Loss', save_path='translator_loss.png')
plot_metric(token_accuracies, step_size=50, metric_name='Translator Token Accuracy', save_path='translator_token_accuracy.png')
plot_metric(sequence_accuracies, step_size=50, metric_name='Translator Sequence Accuracy', save_path='translator_sequence_accuracy.png')
# Out:
# Plot saved to translator_loss.png
# Plot saved to translator_token_accuracy.png
# Plot saved to translator_sequence_accuracy.png

# %% [markdown]
# ### Inference

# %%
# Freeze translator model parameters
for param in translator_model.parameters():
    param.requires_grad = False

translator_model.eval()
# Out:
# Translator(
#   (translation_net): Sequential(
#     (0): Linear(in_features=12, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=128, out_features=128, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=128, out_features=39, bias=True)
#   )
# )

# %%
# Run a test example
print("\n--- Running a translator test example ---")

with torch.no_grad():
    W_test, X_test_mask, rule_test_tokens = load_batch(
        'translator_test', 204, 205, include_rules=True
    )

    print("Test World W has 5 objects.")
    print(f"Target set X is selected by mask: {X_test_mask[0]}")
    print(f"Ground truth rule tokens: {rule_test_tokens[0].tolist()}")

    # Get neuralese representation from the frozen speaker
    V_test = model(W_test, X_test_mask, return_neuralese_only=True)

    # Predict the rule tokens
    predicted_logits = translator_model(V_test)  # (1, max_rule_length, vocab_size)
    predicted_tokens = torch.argmax(predicted_logits, dim=2)  # (1, max_rule_length)

    print(f"Predicted rule tokens: {predicted_tokens[0].tolist()}")

    # Decode tokens to text
    decoded_predicted = [IDX_TO_TOKEN[t.item()] for t in predicted_tokens[0]]
    decoded_ground_truth = [IDX_TO_TOKEN[t.item()] for t in rule_test_tokens[0]]

    print(f"Decoded predicted rule: {decoded_predicted}")
    print(f"Decoded ground truth rule: {decoded_ground_truth}")
# Out:
# --- Running a translator test example ---
# Test World W has 5 objects.
# Target set X is selected by mask: tensor([0., 0., 0., 1., 1.])
# Ground truth rule tokens: [9, 0, 0]
# Predicted rule tokens: [6, 0, 9]
# Decoded predicted rule: ['purple', '<blank>', 'triangle']
# Decoded ground truth rule: ['triangle', '<blank>', '<blank>']

# %%
# Evaluate translator on full test set
print("\n--- Evaluating translator on full test set ---")
translator_model.eval()

test_losses = []
test_token_accs = []
test_seq_accs = []

N_TEST = len(dataset_splits['translator_test']['W'])
start_index = 0

with torch.no_grad():  # Important: no gradients during eval
    while start_index < N_TEST:
        batch_size = min(BATCH_SIZE, N_TEST - start_index)

        # Load test batch
        W_batch, X_mask_batch, rule_tokens_batch = load_batch(
            'translator_test', start_index, batch_size, include_rules=True
        )

        # Get neuralese from frozen speaker
        V_batch = model(W_batch, X_mask_batch, return_neuralese_only=True)

        # Predict
        predicted_logits = translator_model(V_batch)

        # Calculate loss
        loss = translator_criterion(
            predicted_logits.view(-1, len(VOCABULARY)),
            rule_tokens_batch.view(-1)
        )

        # Calculate accuracies
        predicted_tokens = torch.argmax(predicted_logits, dim=2)
        correct_tokens = (predicted_tokens == rule_tokens_batch).float()
        token_acc = correct_tokens.mean().item()
        seq_acc = (correct_tokens.sum(dim=1) == 3).float().mean().item()

        # Store metrics
        test_losses.append(loss.item())
        test_token_accs.append(token_acc)
        test_seq_accs.append(seq_acc)

        start_index += batch_size

# Print overall results
print(f"Test Loss: {np.mean(test_losses):.4f}")
print(f"Test Token Accuracy: {np.mean(test_token_accs):.4f}")
print(f"Test Sequence Accuracy: {np.mean(test_seq_accs):.4f}")
# Out:
# --- Evaluating translator on full test set ---
# Test Loss: 0.9192
# Test Token Accuracy: 0.6530
# Test Sequence Accuracy: 0.3975
