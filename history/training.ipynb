# %%
import json
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ### Hyperparameters

# %%
# the number of objects in each world
WORLD_SIZE = 5

# the dimension of the feature vector of each object
# as produced by the encoder
OBJECT_FEATURE_DIMENSION = 6

# the dimension of the speaker's generated vector representation
NEURALESE_DIMENSION = 12

# %% [markdown]
# ### Model Components

# %%
class ObjectEncoder(nn.Module):
    """
    Encodes a single (3x3) Object into a feature vector
    Input     : [[001][100][010]] or Purple-Cirle-No-Outline. See metadata.json
    InputSize : (3,3)
    OutputSize: (OBJECT_FEATURE_DIMENSION)
    """
    def __init__(self, output_dimension=OBJECT_FEATURE_DIMENSION):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size=2),  # → (batch, 4, 2, 2)
            nn.Flatten(),                    # → (batch, 16)
            nn.Linear(16, output_dimension)
        )
        
    def forward(self, x):
        return self.encoder(x)

# %%
class Speaker(nn.Module):
    """
    Transforms the encoded objects in world W + boolean inclusion mask for target subset X 
    into a representative vector
    
    InputSize : (WORLD_SIZE * OBJECT_FEATURE_DIMENSION) + WORLD_SIZE)
    OutputSize: (NEURALESE_DIMENSION)
    """
    def __init__(self, input_dimension=(WORLD_SIZE * OBJECT_FEATURE_DIMENSION) + WORLD_SIZE, 
                 output_dimension=NEURALESE_DIMENSION):
        super().__init__()
        self.speaker_net = nn.Sequential(
            nn.Linear(input_dimension, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, output_dimension)
        )
    
    def forward(self, x):
        return self.speaker_net(x)

# %%
class Listener(nn.Module):
    """
    Takes the resultant vector from the speaker, along with W_i (an element of the world W)
    and predicts whether this element belongs to X, the target subset.
    
    InputSize : (NEURALESE_DIMENSION + OBJECT_FEATURE_DIMENSION)
    OutputSize: (1) -> logit for binary classification
    """
    def __init__(self, input_dimension=NEURALESE_DIMENSION + OBJECT_FEATURE_DIMENSION, 
                 output_dimension=1):
        super().__init__()
        self.listener_net = nn.Sequential(
            nn.Linear(input_dimension, 32),
            nn.ReLU(),
            nn.Linear(32, 8),
            nn.ReLU(),
            nn.Linear(8, output_dimension)
        )
            
    def forward(self, x):
        return self.listener_net(x)

# %%
class SpeakerListenerSystem(nn.Module):
    """
    The end-to-end system.
    Encoder -> Speaker -> Listener
    """
    def __init__(self, world_size, feature_dimension, neuralese_dimension):
        super().__init__()
        
        self.world_size          = world_size
        self.feature_dimension   = feature_dimension
        self.neuralese_dimension = neuralese_dimension
        
        speaker_input_size  = (self.world_size * self.feature_dimension) + self.world_size
        listener_input_size = self.neuralese_dimension + self.feature_dimension
        
        self.encoder  = ObjectEncoder(output_dimension=self.feature_dimension)
        self.speaker  = Speaker(input_dimension=speaker_input_size, output_dimension=neuralese_dimension)
        self.listener = Listener(input_dimension=listener_input_size, output_dimension=1)
        
        
    def forward(self, W, X_mask):
        """
        W:      A batch of worlds. 
                Each world is a set of (3x3) objects.
                Tensor of shape (batch_size, world_size, 3, 3).
                
        X_mask: A batch of boolean masks
                Each value indicated whether the object at that index in W
                is included in the target subset X
                Tensor of shape (batch_size, world_size)
        """
        batch_size = W.shape[0]
        
        ### STEP 1: Encode all objects in the world
        # Reshape for batch processing ny the encoder (B, 5, 3, 3) -> (B*5, 1, 3, 3)
        W_flat = W.view(-1, 1, 3, 3)
        # Get features for all objects: (B*5, feature_dim)
        object_features_flat = self.encoder(W_flat)
        # Reshape back to per-batch item:(B, 5, feature_dim)
        object_features = object_features_flat.view(batch_size, self.world_size, self.feature_dimension)
        
        
        ### STEP 2: Assemble the inputs to the speaker model
        # Flatten object features: (B, 5, feature_dim) -> (B, 5*feature_dim)
        V_W =  object_features.view(batch_size, -1)
        # Create the indicator mask
        M_X = X_mask
        # Concatenate features and mask
        speaker_input = torch.cat([V_W, M_X], dim=1)
        
        
        ### STEP 3: Speaker generates neuralese
        # representation has shape (B, neuralese_dimension)
        representation = self.speaker(speaker_input)
        
        ### STEP 4: Prepare the listener's input
        # The listener needs to pair the speaker's representation with each object feature
        # Expand the representation to match the number of objects
        # (B, rep_dim) -> (B, 1, rep_dim) -> (B, world_size, rep_dim)
        r_expanded = representation.unsqueeze(1).repeat(1, self.world_size, 1)
        # Concatenate with object features: (B, 5, rep_dim) + (B, 5, feature_dim)
        listener_input = torch.cat([r_expanded, object_features], dim=2)
        
        
        ### STEP 5: Shuffle inputs to the listener
        # This is to avoid the speaker simply learning to tell the listener about X_mask
        # without learning anything about the objects in X themselves.
        # Create a random permutation for each item in the batch
        shuffled_indices = [torch.randperm(self.world_size) for _ in range(batch_size)]
        # Apply the shuffle
        shuffled_input   = torch.stack([features[p] for features, p in zip(listener_input, shuffled_indices)])
        shuffled_labels  = torch.stack([labels[p]   for labels,   p in zip(X_mask, shuffled_indices)])
        
        
        ### STEP 6: Listener makes an inclusion prediction for each object
        # Reshape for batch processing by the listener
        # (B, 5, rep_dim + feature_dim) -> (B*5, rep_dim + feature_dim)
        listener_input_flat = shuffled_input.view(-1, self.neuralese_dimension + self.feature_dimension)
        # Get predictions (logits) -> (B*5, 1)
        predictions_flat = self.listener(listener_input_flat)
        # Reshape back to (B, world_size)
        predictions = predictions_flat.view(batch_size, self.world_size)
        
        return predictions, shuffled_labels

# %%
class Translator(nn.Module):
    """
    Translates neuralese representation V into natural language rule R.

    Takes the learned communication vector V (produced by the speaker) and 
    predicts the original rule R as a fixed-length sequence of tokens.
    Each position in the sequence is predicted independently via classification 
    over the vocabulary (features, logical operators, and blank token).
    """
    def __init__(self, neuralese_dimension=NEURALESE_DIMENSION, 
                 max_rule_length=3, vocab_size=13, hidden_dimension=128):
        super().__init__() 
        self.max_rule_length     = max_rule_length
        self.neuralese_dimension = neuralese_dimension
        self.vocab_size          = vocab_size

        self.translation_net = nn.Sequential(
            nn.Linear(neuralese_dimension, hidden_dimension),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dimension, hidden_dimension),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dimension, max_rule_length * vocab_size)
        )
            
        
    def forward(self, V):
        """
        Arguments:
        V : A batch of neuralese representations (batch_size,  neuralese_dimension)

        Returns:
        logits : (batch_size, max_rule_length, vocab_size)
        """
        batch_size = V.shape[0]

        output = self.translation_net(V)  # (batch_size, max_rule_length * vocab_size)
        logits = output.view(batch_size, self.max_rule_length, self.vocab_size)

        return logits
    
# Alternative architectures to consider:

# Autoregressive (if you want token dependencies):
# Use an RNN/LSTM that generates one token at a time
# token_1 depends only on V
# token_2 depends on V and token_1, etc.

# Deeper MLP with position embeddings:
# Add learnable position embeddings to help the model 
# know which position it's predicting

# %% [markdown]
# ### Data Loading

# %%
def generate_batch(batch_size, world_size):
    """Generates a batch of dummy data"""
    
    # Random 3x3 objects for the world
    W_batch = torch.rand(batch_size, world_size, 3, 3)
    
    # Random binary masks
    X_mask_batch = torch.randint(0, 2, (batch_size, world_size)).float()
    
    # Ensure at least one object is selected in each world
    for i in range(batch_size):
        if X_mask_batch[i].sum() == 0:
            # Randomly select one object
            X_mask_batch[i, random.randint(0, world_size-1)] = 1.0
    
    
    return W_batch, X_mask_batch

# %%
def load_dataset(path='dataset.npz'):
    """Load the real dataset from npz file"""
    
    data = np.load(path, allow_pickle=True)
    
    W = data['W']
    X_mask = data['X_mask']
    rule_encodings = data['rule_encodings']
    rule_texts = data['rule_texts']
    
    # Load metadata
    metadata_path = path.replace('.npz', '_metadata.json')
    with open(metadata_path, 'r') as f:
        metadata = json.load(f)
    
    return W, X_mask, rule_encodings, rule_texts, metadata

# %%
def split_dataset(W, X_mask, rule_encodings, rule_texts, 
                speaker_listener_ratio=0.5,
                translator_train_ratio=0.4,
                translator_test_ratio =0.1,
                seed=42):
    
    """
    Split dataset into three portions with shuffling:
    1. Speaker-Listener training (50%)
    2. Translator training (40%)
    3. Translator testing (10%)
    
    Args:
        W: World matrices [N, 5, 3, 3]
        X_mask: Subset masks [N, 5]
        rule_encodings: Rule encodings [N, ...]
        rule_texts: Rule text strings [N]
        speaker_listener_ratio: Fraction for speaker-listener
        translator_train_ratio: Fraction for translator training
        translator_test_ratio: Fraction for translator testing
        seed: Random seed for reproducibility
    
    Returns:
        Dictionary with all splits
    """
    
    assert abs(speaker_listener_ratio + translator_train_ratio + translator_test_ratio - 1.0) < 1e-6, \
           "Ratios must sum to 1.0"
    np.random.seed(seed)

    # Shuffle the dataset
    N_total = len(W)
    indices = np.random.permutation(N_total)

    # Calculate sizes of data portions
    speaker_listener_size = int(N_total * speaker_listener_ratio)
    translator_train_size = int(N_total * translator_train_ratio)
    translator_test_size  = int(N_total * translator_test_ratio)

    # Calculate indices for splitting
    speaker_listener_idx = indices[:speaker_listener_size]
    translator_train_idx = indices[speaker_listener_size:speaker_listener_size + translator_train_size]
    translator_test_idx  = indices[speaker_listener_size + translator_train_size:]

    # Split the data
    split_dataset = {
        'speaker_listener': {
            'W':              torch.tensor(W[speaker_listener_idx]).float(),
            'X_mask':         torch.tensor(X_mask[speaker_listener_idx]).float(),
            'rule_encodings': rule_encodings[speaker_listener_idx],
            'rule_texts':     rule_texts[speaker_listener_idx]
        },
        'translator_train': {
            'W':              torch.tensor(W[translator_train_idx]).float(),
            'X_mask':         torch.tensor(X_mask[translator_train_idx]).float(),
            'rule_encodings': rule_encodings[translator_train_idx],
            'rule_texts':     rule_texts[translator_train_idx]
        },
        'translator_test': {
            'W':              torch.tensor(W[translator_test_idx]).float(),
            'X_mask':         torch.tensor(X_mask[translator_test_idx]).float(),
            'rule_encodings': rule_encodings[translator_test_idx],
            'rule_texts':     rule_texts[translator_test_idx]
        }
    }

    print("Dataset Split:")
    print(f"  Speaker-Listener:  {len(speaker_listener_idx):,} ({speaker_listener_ratio*100:.0f}%)")
    print(f"  Translator Train:  {len(translator_train_idx):,} ({translator_train_ratio*100:.0f}%)")
    print(f"  Translator Test:   {len(translator_test_idx):,}  ({translator_test_ratio*100:.0f}%)")
    print(f"  Total:             {N_total:,}")

    return split_dataset

# %%
# Load dataset and split
W_data, X_mask_data, rule_encodings_data, rule_texts_data, metadata = load_dataset('dataset.npz')
dataset_splits = split_dataset(W_data, X_mask_data, rule_encodings_data, rule_texts_data)

def load_batch(split_name, start_idx, batch_size):
    """Load a batch of data from the specified split"""
    split = dataset_splits[split_name]
    end_idx = start_idx + batch_size
    return split['W'][start_idx:end_idx], split['X_mask'][start_idx:end_idx]
# Out:
# Dataset Split:
#   Speaker-Listener:  852,916 (50%)
#   Translator Train:  682,333 (40%)
#   Translator Test:   170,584  (10%)
#   Total:             1,705,833

# %% [markdown]
# ### Visualizations

# %%
def plot_metric(values, step_size, metric_name, save_path=None, figsize=(10,6)):
    """
    Plot training metric (loss or accuracy) over epochs

    Args:
        values: List or array of metric values recorded during training
        step_size: Number of epochs between each recorded value (e.g., 50 if you log every 50 epochs)
        metric_name: Name of the metric for labels (e.g., 'Loss', 'Accuracy')
        save_path: Optional path to save the figure (e.g., 'speaker_loss.png')
        figsize: Tuple specifying figure size (width, height)
    
    Example:
        plot_metric(losses, 50, 'Loss', save_path='speaker_loss.png')
        plot_metric(accuracies, 50, 'Accuracy', save_path='speaker_accuracy
    """
    
    # Calculate epochs based on step size
    epochs = np.arange(step_size, len(values)*step_size + 1, step_size)

    # Create the plot
    plt.figure(figsize=figsize)
    plt.plot(epochs, values, linewidth=2, color="#B41F1F" if 'loss' in metric_name.lower() else "#35B457")

    # Styling 
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel(metric_name, fontsize=12)
    plt.title(f'{metric_name} over Training', fontsize=14)

    # Tight layout for better spacing
    plt.tight_layout()
    
    # Save if path provided
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Plot saved to {save_path}")
    
    plt.show()

# %% [markdown]
# ## The  Speaker Listener

# %% [markdown]
# ### Training

# %%
# Hyperparameters for training
BATCH_SIZE    = 32 # 32
NUM_EPOCHS    = 10_000 # 2000
LEARNING_RATE = 1e-4

# %%
# Instantiate the system
model = SpeakerListenerSystem(
    world_size          = WORLD_SIZE,
    feature_dimension   = OBJECT_FEATURE_DIMENSION,
    neuralese_dimension = NEURALESE_DIMENSION,
)

# %%
# Use BCEWithLogitsLoss because our model outputs raw logits (more stable)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

epoch = 0
start_index = 0
N_DATA = len(dataset_splits['speaker_listener']['W'])

losses = []
accuracies = []

print("Starting training...")
while True:
    epoch += 1
    
    # Generate a new batch of dummy data
    # W, X_mask = generate_batch(BATCH_SIZE, WORLD_SIZE)

    # Load real data
    W, X_mask = load_batch('speaker_listener', start_index, BATCH_SIZE)
    start_index += BATCH_SIZE
    if start_index + BATCH_SIZE > N_DATA:
        print("Reached end of training data.")
        break
    
    # Forward pass - y_truth is the shuffled X_mask
    optimizer.zero_grad()
    y_logits, y_truth = model(W, X_mask)
    
    # Calculate loss - (y_truth serves as the ground truth)
    loss = criterion(y_logits, y_truth)
    
    # Backward pass and optimize
    loss.backward()
    optimizer.step()
    
    if (epoch + 1) % 50 == 0:
        # Track data consumption
        print(f"start_index: {start_index}, end_index: {start_index + BATCH_SIZE}")

        # Calculate accuracy for monitoring
        preds    = torch.sigmoid(y_logits) > 0.5
        accuracy = (preds.float() == y_truth).float().mean() 
        print(f"Epoch [{epoch+1}/---], Loss: {loss.item():.4f}, Accuracy: {accuracy.item():.4f}")

        # Store metrics
        losses.append(loss.item())
        accuracies.append(accuracy.item())
        
print("Training finished.")
# Out:
# Starting training...
# start_index: 1568, end_index: 1600
# Epoch [50/---], Loss: 0.7021, Accuracy: 0.4625
# start_index: 3168, end_index: 3200
# Epoch [100/---], Loss: 0.6912, Accuracy: 0.5250
# start_index: 4768, end_index: 4800
# Epoch [150/---], Loss: 0.6935, Accuracy: 0.4938
# start_index: 6368, end_index: 6400
# Epoch [200/---], Loss: 0.6944, Accuracy: 0.3875
# start_index: 7968, end_index: 8000
# Epoch [250/---], Loss: 0.6867, Accuracy: 0.6625
# start_index: 9568, end_index: 9600
# Epoch [300/---], Loss: 0.6809, Accuracy: 0.6500
# start_index: 11168, end_index: 11200
# Epoch [350/---], Loss: 0.6623, Accuracy: 0.6875
# start_index: 12768, end_index: 12800
# Epoch [400/---], Loss: 0.6507, Accuracy: 0.6562
# start_index: 14368, end_index: 14400
# Epoch [450/---], Loss: 0.6443, Accuracy: 0.6500
# start_index: 15968, end_index: 16000
# Epoch [500/---], Loss: 0.6119, Accuracy: 0.6812
# start_index: 17568, end_index: 17600
# Epoch [550/---], Loss: 0.6161, Accuracy: 0.6687
# start_index: 19168, end_index: 19200
# Epoch [600/---], Loss: 0.6525, Accuracy: 0.6250
# start_index: 20768, end_index: 20800
# Epoch [650/---], Loss: 0.6026, Accuracy: 0.6812
# start_index: 22368, end_index: 22400
# Epoch [700/---], Loss: 0.5982, Accuracy: 0.6875
# start_index: 23968, end_index: 24000
# Epoch [750/---], Loss: 0.6135, Accuracy: 0.6687
# start_index: 25568, end_index: 25600
# Epoch [800/---], Loss: 0.6297, Accuracy: 0.6500
# start_index: 27168, end_index: 27200
# Epoch [850/---], Loss: 0.5921, Accuracy: 0.6938
# start_index: 28768, end_index: 28800
# Epoch [900/---], Loss: 0.6131, Accuracy: 0.6687
# start_index: 30368, end_index: 30400
# Epoch [950/---], Loss: 0.6245, Accuracy: 0.6562
# start_index: 31968, end_index: 32000
# Epoch [1000/---], Loss: 0.6038, Accuracy: 0.6812
# start_index: 33568, end_index: 33600
# Epoch [1050/---], Loss: 0.5696, Accuracy: 0.7188
# start_index: 35168, end_index: 35200
# Epoch [1100/---], Loss: 0.5977, Accuracy: 0.6875
# start_index: 36768, end_index: 36800
# Epoch [1150/---], Loss: 0.6078, Accuracy: 0.6750
# start_index: 38368, end_index: 38400
# Epoch [1200/---], Loss: 0.6194, Accuracy: 0.6625
# start_index: 39968, end_index: 40000
# Epoch [1250/---], Loss: 0.5976, Accuracy: 0.6875
# start_index: 41568, end_index: 41600
# Epoch [1300/---], Loss: 0.6088, Accuracy: 0.6750
# start_index: 43168, end_index: 43200
# Epoch [1350/---], Loss: 0.6079, Accuracy: 0.6750
# start_index: 44768, end_index: 44800
# Epoch [1400/---], Loss: 0.6199, Accuracy: 0.6625
# start_index: 46368, end_index: 46400
# Epoch [1450/---], Loss: 0.5920, Accuracy: 0.6938
# start_index: 47968, end_index: 48000
# Epoch [1500/---], Loss: 0.6086, Accuracy: 0.6750
# start_index: 49568, end_index: 49600
# Epoch [1550/---], Loss: 0.6302, Accuracy: 0.6500
# start_index: 51168, end_index: 51200
# Epoch [1600/---], Loss: 0.6143, Accuracy: 0.6687
# start_index: 52768, end_index: 52800
# Epoch [1650/---], Loss: 0.6253, Accuracy: 0.6562
# start_index: 54368, end_index: 54400
# Epoch [1700/---], Loss: 0.5979, Accuracy: 0.6875
# start_index: 55968, end_index: 56000
# Epoch [1750/---], Loss: 0.5971, Accuracy: 0.6875
# start_index: 57568, end_index: 57600
# Epoch [1800/---], Loss: 0.6135, Accuracy: 0.6687
# start_index: 59168, end_index: 59200
# Epoch [1850/---], Loss: 0.6246, Accuracy: 0.6562
# start_index: 60768, end_index: 60800
# Epoch [1900/---], Loss: 0.5766, Accuracy: 0.7125
# start_index: 62368, end_index: 62400
# Epoch [1950/---], Loss: 0.6022, Accuracy: 0.6812
# start_index: 63968, end_index: 64000
# Epoch [2000/---], Loss: 0.5917, Accuracy: 0.6938
# start_index: 65568, end_index: 65600
# Epoch [2050/---], Loss: 0.6031, Accuracy: 0.6812
# start_index: 67168, end_index: 67200
# Epoch [2100/---], Loss: 0.6031, Accuracy: 0.6812
# start_index: 68768, end_index: 68800
# Epoch [2150/---], Loss: 0.5977, Accuracy: 0.6875
# start_index: 70368, end_index: 70400
# Epoch [2200/---], Loss: 0.6030, Accuracy: 0.6812
# start_index: 71968, end_index: 72000
# Epoch [2250/---], Loss: 0.6236, Accuracy: 0.6562
# start_index: 73568, end_index: 73600
# Epoch [2300/---], Loss: 0.6133, Accuracy: 0.6687
# start_index: 75168, end_index: 75200
# Epoch [2350/---], Loss: 0.5865, Accuracy: 0.7000
# start_index: 76768, end_index: 76800
# Epoch [2400/---], Loss: 0.5819, Accuracy: 0.7063
# start_index: 78368, end_index: 78400
# Epoch [2450/---], Loss: 0.5977, Accuracy: 0.6875
# start_index: 79968, end_index: 80000
# Epoch [2500/---], Loss: 0.5923, Accuracy: 0.6938
# start_index: 81568, end_index: 81600
# Epoch [2550/---], Loss: 0.6021, Accuracy: 0.6812
# start_index: 83168, end_index: 83200
# Epoch [2600/---], Loss: 0.6024, Accuracy: 0.6812
# start_index: 84768, end_index: 84800
# Epoch [2650/---], Loss: 0.5867, Accuracy: 0.7000
# start_index: 86368, end_index: 86400
# Epoch [2700/---], Loss: 0.6080, Accuracy: 0.6750
# start_index: 87968, end_index: 88000
# Epoch [2750/---], Loss: 0.5977, Accuracy: 0.6875
# start_index: 89568, end_index: 89600
# Epoch [2800/---], Loss: 0.5921, Accuracy: 0.6938
# start_index: 91168, end_index: 91200
# Epoch [2850/---], Loss: 0.5925, Accuracy: 0.6938
# start_index: 92768, end_index: 92800
# Epoch [2900/---], Loss: 0.5918, Accuracy: 0.6938
# start_index: 94368, end_index: 94400
# Epoch [2950/---], Loss: 0.6084, Accuracy: 0.6750
# start_index: 95968, end_index: 96000
# Epoch [3000/---], Loss: 0.5970, Accuracy: 0.6875
# start_index: 97568, end_index: 97600
# Epoch [3050/---], Loss: 0.5974, Accuracy: 0.6875
# start_index: 99168, end_index: 99200
# Epoch [3100/---], Loss: 0.5813, Accuracy: 0.7063
# start_index: 100768, end_index: 100800
# Epoch [3150/---], Loss: 0.6019, Accuracy: 0.6812
# start_index: 102368, end_index: 102400
# Epoch [3200/---], Loss: 0.6249, Accuracy: 0.6562
# start_index: 103968, end_index: 104000
# Epoch [3250/---], Loss: 0.5860, Accuracy: 0.7000
# start_index: 105568, end_index: 105600
# Epoch [3300/---], Loss: 0.6186, Accuracy: 0.6625
# start_index: 107168, end_index: 107200
# Epoch [3350/---], Loss: 0.5803, Accuracy: 0.7063
# start_index: 108768, end_index: 108800
# Epoch [3400/---], Loss: 0.5968, Accuracy: 0.6875
# start_index: 110368, end_index: 110400
# Epoch [3450/---], Loss: 0.6135, Accuracy: 0.6687
# start_index: 111968, end_index: 112000
# Epoch [3500/---], Loss: 0.6190, Accuracy: 0.6625
# start_index: 113568, end_index: 113600
# Epoch [3550/---], Loss: 0.6137, Accuracy: 0.6687
# start_index: 115168, end_index: 115200
# Epoch [3600/---], Loss: 0.5965, Accuracy: 0.6875
# start_index: 116768, end_index: 116800
# Epoch [3650/---], Loss: 0.5967, Accuracy: 0.6875
# start_index: 118368, end_index: 118400
# Epoch [3700/---], Loss: 0.5694, Accuracy: 0.7188
# start_index: 119968, end_index: 120000
# Epoch [3750/---], Loss: 0.5650, Accuracy: 0.7250
# start_index: 121568, end_index: 121600
# Epoch [3800/---], Loss: 0.5970, Accuracy: 0.6875
# start_index: 123168, end_index: 123200
# Epoch [3850/---], Loss: 0.6029, Accuracy: 0.6812
# start_index: 124768, end_index: 124800
# Epoch [3900/---], Loss: 0.5969, Accuracy: 0.6875
# start_index: 126368, end_index: 126400
# Epoch [3950/---], Loss: 0.5900, Accuracy: 0.6938
# start_index: 127968, end_index: 128000
# Epoch [4000/---], Loss: 0.5801, Accuracy: 0.7063
# start_index: 129568, end_index: 129600
# Epoch [4050/---], Loss: 0.6450, Accuracy: 0.6313
# start_index: 131168, end_index: 131200
# Epoch [4100/---], Loss: 0.5867, Accuracy: 0.7000
# start_index: 132768, end_index: 132800
# Epoch [4150/---], Loss: 0.5957, Accuracy: 0.6875
# start_index: 134368, end_index: 134400
# Epoch [4200/---], Loss: 0.6308, Accuracy: 0.6500
# start_index: 135968, end_index: 136000
# Epoch [4250/---], Loss: 0.6383, Accuracy: 0.6375
# start_index: 137568, end_index: 137600
# Epoch [4300/---], Loss: 0.6082, Accuracy: 0.6750
# start_index: 139168, end_index: 139200
# Epoch [4350/---], Loss: 0.5957, Accuracy: 0.6875
# start_index: 140768, end_index: 140800
# Epoch [4400/---], Loss: 0.6075, Accuracy: 0.6750
# start_index: 142368, end_index: 142400
# Epoch [4450/---], Loss: 0.6010, Accuracy: 0.6812
# start_index: 143968, end_index: 144000
# Epoch [4500/---], Loss: 0.6007, Accuracy: 0.6812
# start_index: 145568, end_index: 145600
# Epoch [4550/---], Loss: 0.6007, Accuracy: 0.6812
# start_index: 147168, end_index: 147200
# Epoch [4600/---], Loss: 0.6014, Accuracy: 0.6812
# start_index: 148768, end_index: 148800
# Epoch [4650/---], Loss: 0.6190, Accuracy: 0.6562
# start_index: 150368, end_index: 150400
# Epoch [4700/---], Loss: 0.6186, Accuracy: 0.6562
# start_index: 151968, end_index: 152000
# Epoch [4750/---], Loss: 0.6059, Accuracy: 0.6750
# start_index: 153568, end_index: 153600
# Epoch [4800/---], Loss: 0.5720, Accuracy: 0.7063
# start_index: 155168, end_index: 155200
# Epoch [4850/---], Loss: 0.5839, Accuracy: 0.6938
# start_index: 156768, end_index: 156800
# Epoch [4900/---], Loss: 0.6030, Accuracy: 0.6687
# start_index: 158368, end_index: 158400
# Epoch [4950/---], Loss: 0.5913, Accuracy: 0.6812
# start_index: 159968, end_index: 160000
# Epoch [5000/---], Loss: 0.5689, Accuracy: 0.7000
# start_index: 161568, end_index: 161600
# Epoch [5050/---], Loss: 0.5668, Accuracy: 0.7000
# start_index: 163168, end_index: 163200
# Epoch [5100/---], Loss: 0.5750, Accuracy: 0.7000
# start_index: 164768, end_index: 164800
# Epoch [5150/---], Loss: 0.5911, Accuracy: 0.6812
# start_index: 166368, end_index: 166400
# Epoch [5200/---], Loss: 0.5515, Accuracy: 0.7188
# start_index: 167968, end_index: 168000
# Epoch [5250/---], Loss: 0.5429, Accuracy: 0.7125
# start_index: 169568, end_index: 169600
# Epoch [5300/---], Loss: 0.5831, Accuracy: 0.7125
# start_index: 171168, end_index: 171200
# Epoch [5350/---], Loss: 0.5423, Accuracy: 0.7437
# start_index: 172768, end_index: 172800
# Epoch [5400/---], Loss: 0.5472, Accuracy: 0.7312
# start_index: 174368, end_index: 174400
# Epoch [5450/---], Loss: 0.5218, Accuracy: 0.7563
# start_index: 175968, end_index: 176000
# Epoch [5500/---], Loss: 0.5101, Accuracy: 0.7875
# start_index: 177568, end_index: 177600
# Epoch [5550/---], Loss: 0.5196, Accuracy: 0.7063
# start_index: 179168, end_index: 179200
# Epoch [5600/---], Loss: 0.5178, Accuracy: 0.7688
# start_index: 180768, end_index: 180800
# Epoch [5650/---], Loss: 0.4960, Accuracy: 0.7750
# start_index: 182368, end_index: 182400
# Epoch [5700/---], Loss: 0.5311, Accuracy: 0.7500
# start_index: 183968, end_index: 184000
# Epoch [5750/---], Loss: 0.4858, Accuracy: 0.7500
# start_index: 185568, end_index: 185600
# Epoch [5800/---], Loss: 0.4811, Accuracy: 0.7750
# start_index: 187168, end_index: 187200
# Epoch [5850/---], Loss: 0.5419, Accuracy: 0.7188
# start_index: 188768, end_index: 188800
# Epoch [5900/---], Loss: 0.5146, Accuracy: 0.7188
# start_index: 190368, end_index: 190400
# Epoch [5950/---], Loss: 0.4822, Accuracy: 0.7250
# start_index: 191968, end_index: 192000
# Epoch [6000/---], Loss: 0.4847, Accuracy: 0.7625
# start_index: 193568, end_index: 193600
# Epoch [6050/---], Loss: 0.5193, Accuracy: 0.7500
# start_index: 195168, end_index: 195200
# Epoch [6100/---], Loss: 0.4611, Accuracy: 0.7688
# start_index: 196768, end_index: 196800
# Epoch [6150/---], Loss: 0.4686, Accuracy: 0.7750
# start_index: 198368, end_index: 198400
# Epoch [6200/---], Loss: 0.4660, Accuracy: 0.7688
# start_index: 199968, end_index: 200000
# Epoch [6250/---], Loss: 0.4829, Accuracy: 0.7437
# start_index: 201568, end_index: 201600
# Epoch [6300/---], Loss: 0.4855, Accuracy: 0.7312
# start_index: 203168, end_index: 203200
# Epoch [6350/---], Loss: 0.4881, Accuracy: 0.7500
# start_index: 204768, end_index: 204800
# Epoch [6400/---], Loss: 0.4247, Accuracy: 0.7812
# start_index: 206368, end_index: 206400
# Epoch [6450/---], Loss: 0.4630, Accuracy: 0.7750
# start_index: 207968, end_index: 208000
# Epoch [6500/---], Loss: 0.4425, Accuracy: 0.7937
# start_index: 209568, end_index: 209600
# Epoch [6550/---], Loss: 0.4478, Accuracy: 0.7812
# start_index: 211168, end_index: 211200
# Epoch [6600/---], Loss: 0.4825, Accuracy: 0.7312
# start_index: 212768, end_index: 212800
# Epoch [6650/---], Loss: 0.4358, Accuracy: 0.7750
# start_index: 214368, end_index: 214400
# Epoch [6700/---], Loss: 0.3967, Accuracy: 0.7688
# start_index: 215968, end_index: 216000
# Epoch [6750/---], Loss: 0.5125, Accuracy: 0.7312
# start_index: 217568, end_index: 217600
# Epoch [6800/---], Loss: 0.4735, Accuracy: 0.7688
# start_index: 219168, end_index: 219200
# Epoch [6850/---], Loss: 0.4541, Accuracy: 0.7688
# start_index: 220768, end_index: 220800
# Epoch [6900/---], Loss: 0.3910, Accuracy: 0.8250
# start_index: 222368, end_index: 222400
# Epoch [6950/---], Loss: 0.4961, Accuracy: 0.7375
# start_index: 223968, end_index: 224000
# Epoch [7000/---], Loss: 0.4552, Accuracy: 0.7625
# start_index: 225568, end_index: 225600
# Epoch [7050/---], Loss: 0.4201, Accuracy: 0.8000
# start_index: 227168, end_index: 227200
# Epoch [7100/---], Loss: 0.4143, Accuracy: 0.7812
# start_index: 228768, end_index: 228800
# Epoch [7150/---], Loss: 0.3839, Accuracy: 0.8062
# start_index: 230368, end_index: 230400
# Epoch [7200/---], Loss: 0.4333, Accuracy: 0.7375
# start_index: 231968, end_index: 232000
# Epoch [7250/---], Loss: 0.4446, Accuracy: 0.7563
# start_index: 233568, end_index: 233600
# Epoch [7300/---], Loss: 0.4260, Accuracy: 0.7875
# start_index: 235168, end_index: 235200
# Epoch [7350/---], Loss: 0.4433, Accuracy: 0.7688
# start_index: 236768, end_index: 236800
# Epoch [7400/---], Loss: 0.3840, Accuracy: 0.8188
# start_index: 238368, end_index: 238400
# Epoch [7450/---], Loss: 0.4230, Accuracy: 0.7812
# start_index: 239968, end_index: 240000
# Epoch [7500/---], Loss: 0.3974, Accuracy: 0.7812
# start_index: 241568, end_index: 241600
# Epoch [7550/---], Loss: 0.4216, Accuracy: 0.7750
# start_index: 243168, end_index: 243200
# Epoch [7600/---], Loss: 0.3906, Accuracy: 0.7750
# start_index: 244768, end_index: 244800
# Epoch [7650/---], Loss: 0.3951, Accuracy: 0.7750
# start_index: 246368, end_index: 246400
# Epoch [7700/---], Loss: 0.3920, Accuracy: 0.7875
# start_index: 247968, end_index: 248000
# Epoch [7750/---], Loss: 0.3659, Accuracy: 0.8062
# start_index: 249568, end_index: 249600
# Epoch [7800/---], Loss: 0.4018, Accuracy: 0.8000
# start_index: 251168, end_index: 251200
# Epoch [7850/---], Loss: 0.4481, Accuracy: 0.7563
# start_index: 252768, end_index: 252800
# Epoch [7900/---], Loss: 0.3449, Accuracy: 0.8250
# start_index: 254368, end_index: 254400
# Epoch [7950/---], Loss: 0.3924, Accuracy: 0.7688
# start_index: 255968, end_index: 256000
# Epoch [8000/---], Loss: 0.3704, Accuracy: 0.8250
# start_index: 257568, end_index: 257600
# Epoch [8050/---], Loss: 0.4011, Accuracy: 0.8000
# start_index: 259168, end_index: 259200
# Epoch [8100/---], Loss: 0.3404, Accuracy: 0.8188
# start_index: 260768, end_index: 260800
# Epoch [8150/---], Loss: 0.3939, Accuracy: 0.7875
# start_index: 262368, end_index: 262400
# Epoch [8200/---], Loss: 0.3673, Accuracy: 0.7937
# start_index: 263968, end_index: 264000
# Epoch [8250/---], Loss: 0.3578, Accuracy: 0.7937
# start_index: 265568, end_index: 265600
# Epoch [8300/---], Loss: 0.3806, Accuracy: 0.7812
# start_index: 267168, end_index: 267200
# Epoch [8350/---], Loss: 0.3523, Accuracy: 0.8125
# start_index: 268768, end_index: 268800
# Epoch [8400/---], Loss: 0.3255, Accuracy: 0.8687
# start_index: 270368, end_index: 270400
# Epoch [8450/---], Loss: 0.3504, Accuracy: 0.8313
# start_index: 271968, end_index: 272000
# Epoch [8500/---], Loss: 0.3311, Accuracy: 0.8375
# start_index: 273568, end_index: 273600
# Epoch [8550/---], Loss: 0.3972, Accuracy: 0.8000
# start_index: 275168, end_index: 275200
# Epoch [8600/---], Loss: 0.3510, Accuracy: 0.8250
# start_index: 276768, end_index: 276800
# Epoch [8650/---], Loss: 0.3714, Accuracy: 0.8438
# start_index: 278368, end_index: 278400
# Epoch [8700/---], Loss: 0.3055, Accuracy: 0.8500
# start_index: 279968, end_index: 280000
# Epoch [8750/---], Loss: 0.3559, Accuracy: 0.7937
# start_index: 281568, end_index: 281600
# Epoch [8800/---], Loss: 0.3030, Accuracy: 0.8313
# start_index: 283168, end_index: 283200
# Epoch [8850/---], Loss: 0.3412, Accuracy: 0.8313
# start_index: 284768, end_index: 284800
# Epoch [8900/---], Loss: 0.2886, Accuracy: 0.8750
# start_index: 286368, end_index: 286400
# Epoch [8950/---], Loss: 0.3445, Accuracy: 0.8000
# start_index: 287968, end_index: 288000
# Epoch [9000/---], Loss: 0.3661, Accuracy: 0.8313
# start_index: 289568, end_index: 289600
# Epoch [9050/---], Loss: 0.2985, Accuracy: 0.8875
# start_index: 291168, end_index: 291200
# Epoch [9100/---], Loss: 0.3487, Accuracy: 0.8375
# start_index: 292768, end_index: 292800
# Epoch [9150/---], Loss: 0.2725, Accuracy: 0.8750
# start_index: 294368, end_index: 294400
# Epoch [9200/---], Loss: 0.3368, Accuracy: 0.8438
# start_index: 295968, end_index: 296000
# Epoch [9250/---], Loss: 0.3353, Accuracy: 0.8438
# start_index: 297568, end_index: 297600
# Epoch [9300/---], Loss: 0.3646, Accuracy: 0.7875
# start_index: 299168, end_index: 299200
# Epoch [9350/---], Loss: 0.3086, Accuracy: 0.8188
# start_index: 300768, end_index: 300800
# Epoch [9400/---], Loss: 0.3523, Accuracy: 0.8125
# start_index: 302368, end_index: 302400
# Epoch [9450/---], Loss: 0.2987, Accuracy: 0.8375
# start_index: 303968, end_index: 304000
# Epoch [9500/---], Loss: 0.3300, Accuracy: 0.8562
# start_index: 305568, end_index: 305600
# Epoch [9550/---], Loss: 0.3082, Accuracy: 0.8438
# start_index: 307168, end_index: 307200
# Epoch [9600/---], Loss: 0.2920, Accuracy: 0.8562
# start_index: 308768, end_index: 308800
# Epoch [9650/---], Loss: 0.3848, Accuracy: 0.7875
# start_index: 310368, end_index: 310400
# Epoch [9700/---], Loss: 0.2821, Accuracy: 0.8750
# start_index: 311968, end_index: 312000
# Epoch [9750/---], Loss: 0.2692, Accuracy: 0.8750
# start_index: 313568, end_index: 313600
# Epoch [9800/---], Loss: 0.3157, Accuracy: 0.8375
# start_index: 315168, end_index: 315200
# Epoch [9850/---], Loss: 0.2524, Accuracy: 0.8813
# start_index: 316768, end_index: 316800
# Epoch [9900/---], Loss: 0.3518, Accuracy: 0.8062
# start_index: 318368, end_index: 318400
# Epoch [9950/---], Loss: 0.2658, Accuracy: 0.8813
# start_index: 319968, end_index: 320000
# Epoch [10000/---], Loss: 0.2932, Accuracy: 0.8687
# start_index: 321568, end_index: 321600
# Epoch [10050/---], Loss: 0.3369, Accuracy: 0.8375
# start_index: 323168, end_index: 323200
# Epoch [10100/---], Loss: 0.3101, Accuracy: 0.8375
# start_index: 324768, end_index: 324800
# Epoch [10150/---], Loss: 0.3062, Accuracy: 0.8250
# start_index: 326368, end_index: 326400
# Epoch [10200/---], Loss: 0.3138, Accuracy: 0.8687
# start_index: 327968, end_index: 328000
# Epoch [10250/---], Loss: 0.2804, Accuracy: 0.8687
# start_index: 329568, end_index: 329600
# Epoch [10300/---], Loss: 0.3393, Accuracy: 0.8250
# start_index: 331168, end_index: 331200
# Epoch [10350/---], Loss: 0.2520, Accuracy: 0.8562
# start_index: 332768, end_index: 332800
# Epoch [10400/---], Loss: 0.3729, Accuracy: 0.8250
# start_index: 334368, end_index: 334400
# Epoch [10450/---], Loss: 0.2690, Accuracy: 0.8813
# start_index: 335968, end_index: 336000
# Epoch [10500/---], Loss: 0.2958, Accuracy: 0.8625
# start_index: 337568, end_index: 337600
# Epoch [10550/---], Loss: 0.3328, Accuracy: 0.8562
# start_index: 339168, end_index: 339200
# Epoch [10600/---], Loss: 0.2554, Accuracy: 0.8938
# start_index: 340768, end_index: 340800
# Epoch [10650/---], Loss: 0.2922, Accuracy: 0.8750
# start_index: 342368, end_index: 342400
# Epoch [10700/---], Loss: 0.2429, Accuracy: 0.9125
# start_index: 343968, end_index: 344000
# Epoch [10750/---], Loss: 0.2855, Accuracy: 0.8375
# start_index: 345568, end_index: 345600
# Epoch [10800/---], Loss: 0.3238, Accuracy: 0.8375
# start_index: 347168, end_index: 347200
# Epoch [10850/---], Loss: 0.3088, Accuracy: 0.8188
# start_index: 348768, end_index: 348800
# Epoch [10900/---], Loss: 0.2773, Accuracy: 0.8750
# start_index: 350368, end_index: 350400
# Epoch [10950/---], Loss: 0.2908, Accuracy: 0.8562
# start_index: 351968, end_index: 352000
# Epoch [11000/---], Loss: 0.3157, Accuracy: 0.8438
# start_index: 353568, end_index: 353600
# Epoch [11050/---], Loss: 0.2708, Accuracy: 0.9000
# start_index: 355168, end_index: 355200
# Epoch [11100/---], Loss: 0.1919, Accuracy: 0.9250
# start_index: 356768, end_index: 356800
# Epoch [11150/---], Loss: 0.3032, Accuracy: 0.8500
# start_index: 358368, end_index: 358400
# Epoch [11200/---], Loss: 0.2702, Accuracy: 0.8750
# start_index: 359968, end_index: 360000
# Epoch [11250/---], Loss: 0.2623, Accuracy: 0.8875
# start_index: 361568, end_index: 361600
# Epoch [11300/---], Loss: 0.2530, Accuracy: 0.8938
# start_index: 363168, end_index: 363200
# Epoch [11350/---], Loss: 0.2843, Accuracy: 0.8438
# start_index: 364768, end_index: 364800
# Epoch [11400/---], Loss: 0.2571, Accuracy: 0.8875
# start_index: 366368, end_index: 366400
# Epoch [11450/---], Loss: 0.2563, Accuracy: 0.8938
# start_index: 367968, end_index: 368000
# Epoch [11500/---], Loss: 0.2534, Accuracy: 0.8625
# start_index: 369568, end_index: 369600
# Epoch [11550/---], Loss: 0.3050, Accuracy: 0.8750
# start_index: 371168, end_index: 371200
# Epoch [11600/---], Loss: 0.3404, Accuracy: 0.8188
# start_index: 372768, end_index: 372800
# Epoch [11650/---], Loss: 0.2772, Accuracy: 0.8438
# start_index: 374368, end_index: 374400
# Epoch [11700/---], Loss: 0.2873, Accuracy: 0.8500
# start_index: 375968, end_index: 376000
# Epoch [11750/---], Loss: 0.2884, Accuracy: 0.8562
# start_index: 377568, end_index: 377600
# Epoch [11800/---], Loss: 0.2389, Accuracy: 0.8938
# start_index: 379168, end_index: 379200
# Epoch [11850/---], Loss: 0.3245, Accuracy: 0.8250
# start_index: 380768, end_index: 380800
# Epoch [11900/---], Loss: 0.2310, Accuracy: 0.9062
# start_index: 382368, end_index: 382400
# Epoch [11950/---], Loss: 0.2404, Accuracy: 0.9312
# start_index: 383968, end_index: 384000
# Epoch [12000/---], Loss: 0.2519, Accuracy: 0.8875
# start_index: 385568, end_index: 385600
# Epoch [12050/---], Loss: 0.2697, Accuracy: 0.8875
# start_index: 387168, end_index: 387200
# Epoch [12100/---], Loss: 0.3111, Accuracy: 0.8438
# start_index: 388768, end_index: 388800
# Epoch [12150/---], Loss: 0.1974, Accuracy: 0.9312
# start_index: 390368, end_index: 390400
# Epoch [12200/---], Loss: 0.2064, Accuracy: 0.8938
# start_index: 391968, end_index: 392000
# Epoch [12250/---], Loss: 0.2113, Accuracy: 0.9000
# start_index: 393568, end_index: 393600
# Epoch [12300/---], Loss: 0.2549, Accuracy: 0.8938
# start_index: 395168, end_index: 395200
# Epoch [12350/---], Loss: 0.2036, Accuracy: 0.9125
# start_index: 396768, end_index: 396800
# Epoch [12400/---], Loss: 0.2724, Accuracy: 0.8813
# start_index: 398368, end_index: 398400
# Epoch [12450/---], Loss: 0.2559, Accuracy: 0.8750
# start_index: 399968, end_index: 400000
# Epoch [12500/---], Loss: 0.2492, Accuracy: 0.9062
# start_index: 401568, end_index: 401600
# Epoch [12550/---], Loss: 0.2272, Accuracy: 0.8750
# start_index: 403168, end_index: 403200
# Epoch [12600/---], Loss: 0.2382, Accuracy: 0.9125
# start_index: 404768, end_index: 404800
# Epoch [12650/---], Loss: 0.2355, Accuracy: 0.8687
# start_index: 406368, end_index: 406400
# Epoch [12700/---], Loss: 0.2300, Accuracy: 0.9125
# start_index: 407968, end_index: 408000
# Epoch [12750/---], Loss: 0.2818, Accuracy: 0.8625
# start_index: 409568, end_index: 409600
# Epoch [12800/---], Loss: 0.3139, Accuracy: 0.8500
# start_index: 411168, end_index: 411200
# Epoch [12850/---], Loss: 0.2513, Accuracy: 0.8500
# start_index: 412768, end_index: 412800
# Epoch [12900/---], Loss: 0.2370, Accuracy: 0.8938
# start_index: 414368, end_index: 414400
# Epoch [12950/---], Loss: 0.2391, Accuracy: 0.9000
# start_index: 415968, end_index: 416000
# Epoch [13000/---], Loss: 0.2687, Accuracy: 0.8625
# start_index: 417568, end_index: 417600
# Epoch [13050/---], Loss: 0.2150, Accuracy: 0.8938
# start_index: 419168, end_index: 419200
# Epoch [13100/---], Loss: 0.2584, Accuracy: 0.9000
# start_index: 420768, end_index: 420800
# Epoch [13150/---], Loss: 0.3160, Accuracy: 0.8438
# start_index: 422368, end_index: 422400
# Epoch [13200/---], Loss: 0.2362, Accuracy: 0.8875
# start_index: 423968, end_index: 424000
# Epoch [13250/---], Loss: 0.3150, Accuracy: 0.8438
# start_index: 425568, end_index: 425600
# Epoch [13300/---], Loss: 0.2404, Accuracy: 0.8562
# start_index: 427168, end_index: 427200
# Epoch [13350/---], Loss: 0.2080, Accuracy: 0.9062
# start_index: 428768, end_index: 428800
# Epoch [13400/---], Loss: 0.2239, Accuracy: 0.9062
# start_index: 430368, end_index: 430400
# Epoch [13450/---], Loss: 0.2053, Accuracy: 0.9000
# start_index: 431968, end_index: 432000
# Epoch [13500/---], Loss: 0.2041, Accuracy: 0.9125
# start_index: 433568, end_index: 433600
# Epoch [13550/---], Loss: 0.2236, Accuracy: 0.9125
# start_index: 435168, end_index: 435200
# Epoch [13600/---], Loss: 0.2303, Accuracy: 0.8938
# start_index: 436768, end_index: 436800
# Epoch [13650/---], Loss: 0.1989, Accuracy: 0.9000
# start_index: 438368, end_index: 438400
# Epoch [13700/---], Loss: 0.2016, Accuracy: 0.9000
# start_index: 439968, end_index: 440000
# Epoch [13750/---], Loss: 0.2270, Accuracy: 0.8875
# start_index: 441568, end_index: 441600
# Epoch [13800/---], Loss: 0.2332, Accuracy: 0.8875
# start_index: 443168, end_index: 443200
# Epoch [13850/---], Loss: 0.2163, Accuracy: 0.9062
# start_index: 444768, end_index: 444800
# Epoch [13900/---], Loss: 0.2384, Accuracy: 0.9062
# start_index: 446368, end_index: 446400
# Epoch [13950/---], Loss: 0.2123, Accuracy: 0.8875
# start_index: 447968, end_index: 448000
# Epoch [14000/---], Loss: 0.2302, Accuracy: 0.8938
# start_index: 449568, end_index: 449600
# Epoch [14050/---], Loss: 0.2176, Accuracy: 0.9062
# start_index: 451168, end_index: 451200
# Epoch [14100/---], Loss: 0.1852, Accuracy: 0.9187
# start_index: 452768, end_index: 452800
# Epoch [14150/---], Loss: 0.2015, Accuracy: 0.9312
# start_index: 454368, end_index: 454400
# Epoch [14200/---], Loss: 0.2318, Accuracy: 0.8813
# start_index: 455968, end_index: 456000
# Epoch [14250/---], Loss: 0.2059, Accuracy: 0.8938
# start_index: 457568, end_index: 457600
# Epoch [14300/---], Loss: 0.2409, Accuracy: 0.9000
# start_index: 459168, end_index: 459200
# Epoch [14350/---], Loss: 0.2060, Accuracy: 0.9000
# start_index: 460768, end_index: 460800
# Epoch [14400/---], Loss: 0.1691, Accuracy: 0.9375
# start_index: 462368, end_index: 462400
# Epoch [14450/---], Loss: 0.2475, Accuracy: 0.8687
# start_index: 463968, end_index: 464000
# Epoch [14500/---], Loss: 0.2338, Accuracy: 0.9125
# start_index: 465568, end_index: 465600
# Epoch [14550/---], Loss: 0.2571, Accuracy: 0.8750
# start_index: 467168, end_index: 467200
# Epoch [14600/---], Loss: 0.1958, Accuracy: 0.9062
# start_index: 468768, end_index: 468800
# Epoch [14650/---], Loss: 0.1923, Accuracy: 0.9187
# start_index: 470368, end_index: 470400
# Epoch [14700/---], Loss: 0.2191, Accuracy: 0.8813
# start_index: 471968, end_index: 472000
# Epoch [14750/---], Loss: 0.2686, Accuracy: 0.8625
# start_index: 473568, end_index: 473600
# Epoch [14800/---], Loss: 0.2133, Accuracy: 0.8875
# start_index: 475168, end_index: 475200
# Epoch [14850/---], Loss: 0.2019, Accuracy: 0.8875
# start_index: 476768, end_index: 476800
# Epoch [14900/---], Loss: 0.1831, Accuracy: 0.9062
# start_index: 478368, end_index: 478400
# Epoch [14950/---], Loss: 0.1125, Accuracy: 0.9625
# start_index: 479968, end_index: 480000
# Epoch [15000/---], Loss: 0.2246, Accuracy: 0.8875
# start_index: 481568, end_index: 481600
# Epoch [15050/---], Loss: 0.1875, Accuracy: 0.9250
# start_index: 483168, end_index: 483200
# Epoch [15100/---], Loss: 0.2085, Accuracy: 0.9125
# start_index: 484768, end_index: 484800
# Epoch [15150/---], Loss: 0.2187, Accuracy: 0.8938
# start_index: 486368, end_index: 486400
# Epoch [15200/---], Loss: 0.1913, Accuracy: 0.9187
# start_index: 487968, end_index: 488000
# Epoch [15250/---], Loss: 0.2269, Accuracy: 0.9000
# start_index: 489568, end_index: 489600
# Epoch [15300/---], Loss: 0.2046, Accuracy: 0.9187
# start_index: 491168, end_index: 491200
# Epoch [15350/---], Loss: 0.1815, Accuracy: 0.9062
# start_index: 492768, end_index: 492800
# Epoch [15400/---], Loss: 0.2567, Accuracy: 0.8562
# start_index: 494368, end_index: 494400
# Epoch [15450/---], Loss: 0.2218, Accuracy: 0.8938
# start_index: 495968, end_index: 496000
# Epoch [15500/---], Loss: 0.1971, Accuracy: 0.9125
# start_index: 497568, end_index: 497600
# Epoch [15550/---], Loss: 0.2335, Accuracy: 0.8938
# start_index: 499168, end_index: 499200
# Epoch [15600/---], Loss: 0.2213, Accuracy: 0.8875
# start_index: 500768, end_index: 500800
# Epoch [15650/---], Loss: 0.2897, Accuracy: 0.8375
# start_index: 502368, end_index: 502400
# Epoch [15700/---], Loss: 0.2331, Accuracy: 0.9125
# start_index: 503968, end_index: 504000
# Epoch [15750/---], Loss: 0.1754, Accuracy: 0.9062
# start_index: 505568, end_index: 505600
# Epoch [15800/---], Loss: 0.1794, Accuracy: 0.9125
# start_index: 507168, end_index: 507200
# Epoch [15850/---], Loss: 0.2361, Accuracy: 0.8813
# start_index: 508768, end_index: 508800
# Epoch [15900/---], Loss: 0.1774, Accuracy: 0.9250
# start_index: 510368, end_index: 510400
# Epoch [15950/---], Loss: 0.1868, Accuracy: 0.9125
# start_index: 511968, end_index: 512000
# Epoch [16000/---], Loss: 0.1882, Accuracy: 0.9000
# start_index: 513568, end_index: 513600
# Epoch [16050/---], Loss: 0.2218, Accuracy: 0.8938
# start_index: 515168, end_index: 515200
# Epoch [16100/---], Loss: 0.2055, Accuracy: 0.9000
# start_index: 516768, end_index: 516800
# Epoch [16150/---], Loss: 0.1584, Accuracy: 0.9312
# start_index: 518368, end_index: 518400
# Epoch [16200/---], Loss: 0.1843, Accuracy: 0.9000
# start_index: 519968, end_index: 520000
# Epoch [16250/---], Loss: 0.1903, Accuracy: 0.9125
# start_index: 521568, end_index: 521600
# Epoch [16300/---], Loss: 0.1980, Accuracy: 0.9125
# start_index: 523168, end_index: 523200
# Epoch [16350/---], Loss: 0.2015, Accuracy: 0.9187
# start_index: 524768, end_index: 524800
# Epoch [16400/---], Loss: 0.1687, Accuracy: 0.9125
# start_index: 526368, end_index: 526400
# Epoch [16450/---], Loss: 0.1728, Accuracy: 0.9250
# start_index: 527968, end_index: 528000
# Epoch [16500/---], Loss: 0.1852, Accuracy: 0.9187
# start_index: 529568, end_index: 529600
# Epoch [16550/---], Loss: 0.1621, Accuracy: 0.9438
# start_index: 531168, end_index: 531200
# Epoch [16600/---], Loss: 0.2155, Accuracy: 0.8875
# start_index: 532768, end_index: 532800
# Epoch [16650/---], Loss: 0.1778, Accuracy: 0.9125
# start_index: 534368, end_index: 534400
# Epoch [16700/---], Loss: 0.1849, Accuracy: 0.9125
# start_index: 535968, end_index: 536000
# Epoch [16750/---], Loss: 0.1823, Accuracy: 0.9062
# start_index: 537568, end_index: 537600
# Epoch [16800/---], Loss: 0.1523, Accuracy: 0.9125
# start_index: 539168, end_index: 539200
# Epoch [16850/---], Loss: 0.2298, Accuracy: 0.8813
# start_index: 540768, end_index: 540800
# Epoch [16900/---], Loss: 0.1965, Accuracy: 0.9125
# start_index: 542368, end_index: 542400
# Epoch [16950/---], Loss: 0.1797, Accuracy: 0.9125
# start_index: 543968, end_index: 544000
# Epoch [17000/---], Loss: 0.1713, Accuracy: 0.9250
# start_index: 545568, end_index: 545600
# Epoch [17050/---], Loss: 0.1848, Accuracy: 0.9062
# start_index: 547168, end_index: 547200
# Epoch [17100/---], Loss: 0.1672, Accuracy: 0.9250
# start_index: 548768, end_index: 548800
# Epoch [17150/---], Loss: 0.2374, Accuracy: 0.8875
# start_index: 550368, end_index: 550400
# Epoch [17200/---], Loss: 0.2176, Accuracy: 0.9000
# start_index: 551968, end_index: 552000
# Epoch [17250/---], Loss: 0.1659, Accuracy: 0.9312
# start_index: 553568, end_index: 553600
# Epoch [17300/---], Loss: 0.2054, Accuracy: 0.8938
# start_index: 555168, end_index: 555200
# Epoch [17350/---], Loss: 0.2020, Accuracy: 0.9062
# start_index: 556768, end_index: 556800
# Epoch [17400/---], Loss: 0.1807, Accuracy: 0.9125
# start_index: 558368, end_index: 558400
# Epoch [17450/---], Loss: 0.1748, Accuracy: 0.9312
# start_index: 559968, end_index: 560000
# Epoch [17500/---], Loss: 0.1905, Accuracy: 0.9000
# start_index: 561568, end_index: 561600
# Epoch [17550/---], Loss: 0.1586, Accuracy: 0.9312
# start_index: 563168, end_index: 563200
# Epoch [17600/---], Loss: 0.1317, Accuracy: 0.9625
# start_index: 564768, end_index: 564800
# Epoch [17650/---], Loss: 0.1951, Accuracy: 0.9250
# start_index: 566368, end_index: 566400
# Epoch [17700/---], Loss: 0.1433, Accuracy: 0.9312
# start_index: 567968, end_index: 568000
# Epoch [17750/---], Loss: 0.1484, Accuracy: 0.9312
# start_index: 569568, end_index: 569600
# Epoch [17800/---], Loss: 0.2040, Accuracy: 0.8875
# start_index: 571168, end_index: 571200
# Epoch [17850/---], Loss: 0.1585, Accuracy: 0.9250
# start_index: 572768, end_index: 572800
# Epoch [17900/---], Loss: 0.2124, Accuracy: 0.9125
# start_index: 574368, end_index: 574400
# Epoch [17950/---], Loss: 0.1795, Accuracy: 0.9187
# start_index: 575968, end_index: 576000
# Epoch [18000/---], Loss: 0.1849, Accuracy: 0.9250
# start_index: 577568, end_index: 577600
# Epoch [18050/---], Loss: 0.2296, Accuracy: 0.8875
# start_index: 579168, end_index: 579200
# Epoch [18100/---], Loss: 0.1462, Accuracy: 0.9438
# start_index: 580768, end_index: 580800
# Epoch [18150/---], Loss: 0.1472, Accuracy: 0.9563
# start_index: 582368, end_index: 582400
# Epoch [18200/---], Loss: 0.1659, Accuracy: 0.9312
# start_index: 583968, end_index: 584000
# Epoch [18250/---], Loss: 0.2096, Accuracy: 0.8938
# start_index: 585568, end_index: 585600
# Epoch [18300/---], Loss: 0.1583, Accuracy: 0.9438
# start_index: 587168, end_index: 587200
# Epoch [18350/---], Loss: 0.2085, Accuracy: 0.9125
# start_index: 588768, end_index: 588800
# Epoch [18400/---], Loss: 0.1755, Accuracy: 0.9312
# start_index: 590368, end_index: 590400
# Epoch [18450/---], Loss: 0.1374, Accuracy: 0.9563
# start_index: 591968, end_index: 592000
# Epoch [18500/---], Loss: 0.1912, Accuracy: 0.9187
# start_index: 593568, end_index: 593600
# Epoch [18550/---], Loss: 0.2114, Accuracy: 0.9062
# start_index: 595168, end_index: 595200
# Epoch [18600/---], Loss: 0.0972, Accuracy: 0.9625
# start_index: 596768, end_index: 596800
# Epoch [18650/---], Loss: 0.1864, Accuracy: 0.9187
# start_index: 598368, end_index: 598400
# Epoch [18700/---], Loss: 0.2066, Accuracy: 0.8938
# start_index: 599968, end_index: 600000
# Epoch [18750/---], Loss: 0.1828, Accuracy: 0.9125
# start_index: 601568, end_index: 601600
# Epoch [18800/---], Loss: 0.1947, Accuracy: 0.9250
# start_index: 603168, end_index: 603200
# Epoch [18850/---], Loss: 0.1577, Accuracy: 0.9250
# start_index: 604768, end_index: 604800
# Epoch [18900/---], Loss: 0.1538, Accuracy: 0.9375
# start_index: 606368, end_index: 606400
# Epoch [18950/---], Loss: 0.1931, Accuracy: 0.9062
# start_index: 607968, end_index: 608000
# Epoch [19000/---], Loss: 0.1720, Accuracy: 0.9187
# start_index: 609568, end_index: 609600
# Epoch [19050/---], Loss: 0.1406, Accuracy: 0.9438
# start_index: 611168, end_index: 611200
# Epoch [19100/---], Loss: 0.1905, Accuracy: 0.9187
# start_index: 612768, end_index: 612800
# Epoch [19150/---], Loss: 0.2252, Accuracy: 0.8750
# start_index: 614368, end_index: 614400
# Epoch [19200/---], Loss: 0.2288, Accuracy: 0.9000
# start_index: 615968, end_index: 616000
# Epoch [19250/---], Loss: 0.2184, Accuracy: 0.9187
# start_index: 617568, end_index: 617600
# Epoch [19300/---], Loss: 0.1742, Accuracy: 0.9250
# start_index: 619168, end_index: 619200
# Epoch [19350/---], Loss: 0.1413, Accuracy: 0.9563
# start_index: 620768, end_index: 620800
# Epoch [19400/---], Loss: 0.1548, Accuracy: 0.9438
# start_index: 622368, end_index: 622400
# Epoch [19450/---], Loss: 0.1481, Accuracy: 0.9250
# start_index: 623968, end_index: 624000
# Epoch [19500/---], Loss: 0.1572, Accuracy: 0.9500
# start_index: 625568, end_index: 625600
# Epoch [19550/---], Loss: 0.1981, Accuracy: 0.9062
# start_index: 627168, end_index: 627200
# Epoch [19600/---], Loss: 0.1449, Accuracy: 0.9500
# start_index: 628768, end_index: 628800
# Epoch [19650/---], Loss: 0.1451, Accuracy: 0.9438
# start_index: 630368, end_index: 630400
# Epoch [19700/---], Loss: 0.1536, Accuracy: 0.9250
# start_index: 631968, end_index: 632000
# Epoch [19750/---], Loss: 0.1826, Accuracy: 0.9250
# start_index: 633568, end_index: 633600
# Epoch [19800/---], Loss: 0.1657, Accuracy: 0.9375
# start_index: 635168, end_index: 635200
# Epoch [19850/---], Loss: 0.1589, Accuracy: 0.9250
# start_index: 636768, end_index: 636800
# Epoch [19900/---], Loss: 0.1674, Accuracy: 0.9250
# start_index: 638368, end_index: 638400
# Epoch [19950/---], Loss: 0.1635, Accuracy: 0.9250
# start_index: 639968, end_index: 640000
# Epoch [20000/---], Loss: 0.1670, Accuracy: 0.9187
# start_index: 641568, end_index: 641600
# Epoch [20050/---], Loss: 0.1287, Accuracy: 0.9563
# start_index: 643168, end_index: 643200
# Epoch [20100/---], Loss: 0.1744, Accuracy: 0.9375
# start_index: 644768, end_index: 644800
# Epoch [20150/---], Loss: 0.1674, Accuracy: 0.9125
# start_index: 646368, end_index: 646400
# Epoch [20200/---], Loss: 0.1216, Accuracy: 0.9563
# start_index: 647968, end_index: 648000
# Epoch [20250/---], Loss: 0.1869, Accuracy: 0.9125
# start_index: 649568, end_index: 649600
# Epoch [20300/---], Loss: 0.1494, Accuracy: 0.9500
# start_index: 651168, end_index: 651200
# Epoch [20350/---], Loss: 0.1491, Accuracy: 0.9438
# start_index: 652768, end_index: 652800
# Epoch [20400/---], Loss: 0.1266, Accuracy: 0.9625
# start_index: 654368, end_index: 654400
# Epoch [20450/---], Loss: 0.1949, Accuracy: 0.9125
# start_index: 655968, end_index: 656000
# Epoch [20500/---], Loss: 0.1603, Accuracy: 0.9312
# start_index: 657568, end_index: 657600
# Epoch [20550/---], Loss: 0.2167, Accuracy: 0.9125
# start_index: 659168, end_index: 659200
# Epoch [20600/---], Loss: 0.1847, Accuracy: 0.9000
# start_index: 660768, end_index: 660800
# Epoch [20650/---], Loss: 0.1878, Accuracy: 0.9062
# start_index: 662368, end_index: 662400
# Epoch [20700/---], Loss: 0.1775, Accuracy: 0.9312
# start_index: 663968, end_index: 664000
# Epoch [20750/---], Loss: 0.2083, Accuracy: 0.9125
# start_index: 665568, end_index: 665600
# Epoch [20800/---], Loss: 0.1874, Accuracy: 0.9125
# start_index: 667168, end_index: 667200
# Epoch [20850/---], Loss: 0.1919, Accuracy: 0.9187
# start_index: 668768, end_index: 668800
# Epoch [20900/---], Loss: 0.1434, Accuracy: 0.9312
# start_index: 670368, end_index: 670400
# Epoch [20950/---], Loss: 0.1622, Accuracy: 0.9250
# start_index: 671968, end_index: 672000
# Epoch [21000/---], Loss: 0.1835, Accuracy: 0.9187
# start_index: 673568, end_index: 673600
# Epoch [21050/---], Loss: 0.2110, Accuracy: 0.8875
# start_index: 675168, end_index: 675200
# Epoch [21100/---], Loss: 0.1462, Accuracy: 0.9375
# start_index: 676768, end_index: 676800
# Epoch [21150/---], Loss: 0.1406, Accuracy: 0.9438
# start_index: 678368, end_index: 678400
# Epoch [21200/---], Loss: 0.1255, Accuracy: 0.9438
# start_index: 679968, end_index: 680000
# Epoch [21250/---], Loss: 0.1750, Accuracy: 0.9250
# start_index: 681568, end_index: 681600
# Epoch [21300/---], Loss: 0.1594, Accuracy: 0.9375
# start_index: 683168, end_index: 683200
# Epoch [21350/---], Loss: 0.1180, Accuracy: 0.9500
# start_index: 684768, end_index: 684800
# Epoch [21400/---], Loss: 0.1120, Accuracy: 0.9438
# start_index: 686368, end_index: 686400
# Epoch [21450/---], Loss: 0.1652, Accuracy: 0.9312
# start_index: 687968, end_index: 688000
# Epoch [21500/---], Loss: 0.1192, Accuracy: 0.9563
# start_index: 689568, end_index: 689600
# Epoch [21550/---], Loss: 0.2129, Accuracy: 0.9187
# start_index: 691168, end_index: 691200
# Epoch [21600/---], Loss: 0.1563, Accuracy: 0.9375
# start_index: 692768, end_index: 692800
# Epoch [21650/---], Loss: 0.1900, Accuracy: 0.9000
# start_index: 694368, end_index: 694400
# Epoch [21700/---], Loss: 0.1357, Accuracy: 0.9438
# start_index: 695968, end_index: 696000
# Epoch [21750/---], Loss: 0.1415, Accuracy: 0.9438
# start_index: 697568, end_index: 697600
# Epoch [21800/---], Loss: 0.1209, Accuracy: 0.9375
# start_index: 699168, end_index: 699200
# Epoch [21850/---], Loss: 0.1245, Accuracy: 0.9625
# start_index: 700768, end_index: 700800
# Epoch [21900/---], Loss: 0.1411, Accuracy: 0.9375
# start_index: 702368, end_index: 702400
# Epoch [21950/---], Loss: 0.1515, Accuracy: 0.9312
# start_index: 703968, end_index: 704000
# Epoch [22000/---], Loss: 0.1357, Accuracy: 0.9375
# start_index: 705568, end_index: 705600
# Epoch [22050/---], Loss: 0.2030, Accuracy: 0.9062
# start_index: 707168, end_index: 707200
# Epoch [22100/---], Loss: 0.1470, Accuracy: 0.9312
# start_index: 708768, end_index: 708800
# Epoch [22150/---], Loss: 0.1272, Accuracy: 0.9375
# start_index: 710368, end_index: 710400
# Epoch [22200/---], Loss: 0.1565, Accuracy: 0.9312
# start_index: 711968, end_index: 712000
# Epoch [22250/---], Loss: 0.1590, Accuracy: 0.9375
# start_index: 713568, end_index: 713600
# Epoch [22300/---], Loss: 0.1327, Accuracy: 0.9438
# start_index: 715168, end_index: 715200
# Epoch [22350/---], Loss: 0.1820, Accuracy: 0.9125
# start_index: 716768, end_index: 716800
# Epoch [22400/---], Loss: 0.1781, Accuracy: 0.9250
# start_index: 718368, end_index: 718400
# Epoch [22450/---], Loss: 0.1535, Accuracy: 0.9438
# start_index: 719968, end_index: 720000
# Epoch [22500/---], Loss: 0.1905, Accuracy: 0.9187
# start_index: 721568, end_index: 721600
# Epoch [22550/---], Loss: 0.1955, Accuracy: 0.9000
# start_index: 723168, end_index: 723200
# Epoch [22600/---], Loss: 0.1303, Accuracy: 0.9625
# start_index: 724768, end_index: 724800
# Epoch [22650/---], Loss: 0.1964, Accuracy: 0.9062
# start_index: 726368, end_index: 726400
# Epoch [22700/---], Loss: 0.1465, Accuracy: 0.9438
# start_index: 727968, end_index: 728000
# Epoch [22750/---], Loss: 0.1428, Accuracy: 0.9312
# start_index: 729568, end_index: 729600
# Epoch [22800/---], Loss: 0.1585, Accuracy: 0.9312
# start_index: 731168, end_index: 731200
# Epoch [22850/---], Loss: 0.1621, Accuracy: 0.9187
# start_index: 732768, end_index: 732800
# Epoch [22900/---], Loss: 0.1950, Accuracy: 0.9062
# start_index: 734368, end_index: 734400
# Epoch [22950/---], Loss: 0.2055, Accuracy: 0.9000
# start_index: 735968, end_index: 736000
# Epoch [23000/---], Loss: 0.1578, Accuracy: 0.9187
# start_index: 737568, end_index: 737600
# Epoch [23050/---], Loss: 0.1432, Accuracy: 0.9375
# start_index: 739168, end_index: 739200
# Epoch [23100/---], Loss: 0.1842, Accuracy: 0.9062
# start_index: 740768, end_index: 740800
# Epoch [23150/---], Loss: 0.1645, Accuracy: 0.9375
# start_index: 742368, end_index: 742400
# Epoch [23200/---], Loss: 0.1503, Accuracy: 0.9312
# start_index: 743968, end_index: 744000
# Epoch [23250/---], Loss: 0.1305, Accuracy: 0.9500
# start_index: 745568, end_index: 745600
# Epoch [23300/---], Loss: 0.1659, Accuracy: 0.9187
# start_index: 747168, end_index: 747200
# Epoch [23350/---], Loss: 0.1805, Accuracy: 0.9062
# start_index: 748768, end_index: 748800
# Epoch [23400/---], Loss: 0.2226, Accuracy: 0.8813
# start_index: 750368, end_index: 750400
# Epoch [23450/---], Loss: 0.1378, Accuracy: 0.9250
# start_index: 751968, end_index: 752000
# Epoch [23500/---], Loss: 0.1632, Accuracy: 0.9438
# start_index: 753568, end_index: 753600
# Epoch [23550/---], Loss: 0.1559, Accuracy: 0.9312
# start_index: 755168, end_index: 755200
# Epoch [23600/---], Loss: 0.2201, Accuracy: 0.8938
# start_index: 756768, end_index: 756800
# Epoch [23650/---], Loss: 0.1422, Accuracy: 0.9500
# start_index: 758368, end_index: 758400
# Epoch [23700/---], Loss: 0.1587, Accuracy: 0.9125
# start_index: 759968, end_index: 760000
# Epoch [23750/---], Loss: 0.1748, Accuracy: 0.9312
# start_index: 761568, end_index: 761600
# Epoch [23800/---], Loss: 0.0931, Accuracy: 0.9563
# start_index: 763168, end_index: 763200
# Epoch [23850/---], Loss: 0.2053, Accuracy: 0.9125
# start_index: 764768, end_index: 764800
# Epoch [23900/---], Loss: 0.1392, Accuracy: 0.9375
# start_index: 766368, end_index: 766400
# Epoch [23950/---], Loss: 0.1970, Accuracy: 0.9125
# start_index: 767968, end_index: 768000
# Epoch [24000/---], Loss: 0.1869, Accuracy: 0.8875
# start_index: 769568, end_index: 769600
# Epoch [24050/---], Loss: 0.1298, Accuracy: 0.9500
# start_index: 771168, end_index: 771200
# Epoch [24100/---], Loss: 0.1720, Accuracy: 0.9187
# start_index: 772768, end_index: 772800
# Epoch [24150/---], Loss: 0.1931, Accuracy: 0.9062
# start_index: 774368, end_index: 774400
# Epoch [24200/---], Loss: 0.1178, Accuracy: 0.9563
# start_index: 775968, end_index: 776000
# Epoch [24250/---], Loss: 0.1730, Accuracy: 0.9125
# start_index: 777568, end_index: 777600
# Epoch [24300/---], Loss: 0.1112, Accuracy: 0.9500
# start_index: 779168, end_index: 779200
# Epoch [24350/---], Loss: 0.1455, Accuracy: 0.9312
# start_index: 780768, end_index: 780800
# Epoch [24400/---], Loss: 0.1437, Accuracy: 0.9250
# start_index: 782368, end_index: 782400
# Epoch [24450/---], Loss: 0.1651, Accuracy: 0.9250
# start_index: 783968, end_index: 784000
# Epoch [24500/---], Loss: 0.1576, Accuracy: 0.9187
# start_index: 785568, end_index: 785600
# Epoch [24550/---], Loss: 0.1626, Accuracy: 0.9187
# start_index: 787168, end_index: 787200
# Epoch [24600/---], Loss: 0.1123, Accuracy: 0.9438
# start_index: 788768, end_index: 788800
# Epoch [24650/---], Loss: 0.1626, Accuracy: 0.9187
# start_index: 790368, end_index: 790400
# Epoch [24700/---], Loss: 0.1367, Accuracy: 0.9438
# start_index: 791968, end_index: 792000
# Epoch [24750/---], Loss: 0.1423, Accuracy: 0.9250
# start_index: 793568, end_index: 793600
# Epoch [24800/---], Loss: 0.1888, Accuracy: 0.9125
# start_index: 795168, end_index: 795200
# Epoch [24850/---], Loss: 0.1826, Accuracy: 0.9125
# start_index: 796768, end_index: 796800
# Epoch [24900/---], Loss: 0.1761, Accuracy: 0.9125
# start_index: 798368, end_index: 798400
# Epoch [24950/---], Loss: 0.1339, Accuracy: 0.9438
# start_index: 799968, end_index: 800000
# Epoch [25000/---], Loss: 0.1032, Accuracy: 0.9563
# start_index: 801568, end_index: 801600
# Epoch [25050/---], Loss: 0.1385, Accuracy: 0.9312
# start_index: 803168, end_index: 803200
# Epoch [25100/---], Loss: 0.1348, Accuracy: 0.9375
# start_index: 804768, end_index: 804800
# Epoch [25150/---], Loss: 0.1306, Accuracy: 0.9500
# start_index: 806368, end_index: 806400
# Epoch [25200/---], Loss: 0.1159, Accuracy: 0.9500
# start_index: 807968, end_index: 808000
# Epoch [25250/---], Loss: 0.1997, Accuracy: 0.9000
# start_index: 809568, end_index: 809600
# Epoch [25300/---], Loss: 0.1842, Accuracy: 0.8813
# start_index: 811168, end_index: 811200
# Epoch [25350/---], Loss: 0.1534, Accuracy: 0.9375
# start_index: 812768, end_index: 812800
# Epoch [25400/---], Loss: 0.1517, Accuracy: 0.9438
# start_index: 814368, end_index: 814400
# Epoch [25450/---], Loss: 0.1292, Accuracy: 0.9563
# start_index: 815968, end_index: 816000
# Epoch [25500/---], Loss: 0.1478, Accuracy: 0.9375
# start_index: 817568, end_index: 817600
# Epoch [25550/---], Loss: 0.1697, Accuracy: 0.9312
# start_index: 819168, end_index: 819200
# Epoch [25600/---], Loss: 0.1486, Accuracy: 0.9187
# start_index: 820768, end_index: 820800
# Epoch [25650/---], Loss: 0.1527, Accuracy: 0.9250
# start_index: 822368, end_index: 822400
# Epoch [25700/---], Loss: 0.1597, Accuracy: 0.9312
# start_index: 823968, end_index: 824000
# Epoch [25750/---], Loss: 0.1632, Accuracy: 0.9250
# start_index: 825568, end_index: 825600
# Epoch [25800/---], Loss: 0.1143, Accuracy: 0.9563
# start_index: 827168, end_index: 827200
# Epoch [25850/---], Loss: 0.1192, Accuracy: 0.9500
# start_index: 828768, end_index: 828800
# Epoch [25900/---], Loss: 0.1451, Accuracy: 0.9250
# start_index: 830368, end_index: 830400
# Epoch [25950/---], Loss: 0.1334, Accuracy: 0.9438
# start_index: 831968, end_index: 832000
# Epoch [26000/---], Loss: 0.2049, Accuracy: 0.9125
# start_index: 833568, end_index: 833600
# Epoch [26050/---], Loss: 0.1191, Accuracy: 0.9438
# start_index: 835168, end_index: 835200
# Epoch [26100/---], Loss: 0.1315, Accuracy: 0.9375
# start_index: 836768, end_index: 836800
# Epoch [26150/---], Loss: 0.1303, Accuracy: 0.9375
# start_index: 838368, end_index: 838400
# Epoch [26200/---], Loss: 0.2055, Accuracy: 0.8938
# start_index: 839968, end_index: 840000
# Epoch [26250/---], Loss: 0.1381, Accuracy: 0.9375
# start_index: 841568, end_index: 841600
# Epoch [26300/---], Loss: 0.1460, Accuracy: 0.9312
# start_index: 843168, end_index: 843200
# Epoch [26350/---], Loss: 0.1347, Accuracy: 0.9375
# start_index: 844768, end_index: 844800
# Epoch [26400/---], Loss: 0.1476, Accuracy: 0.9312
# start_index: 846368, end_index: 846400
# Epoch [26450/---], Loss: 0.1696, Accuracy: 0.9187
# start_index: 847968, end_index: 848000
# Epoch [26500/---], Loss: 0.1093, Accuracy: 0.9500
# start_index: 849568, end_index: 849600
# Epoch [26550/---], Loss: 0.1239, Accuracy: 0.9500
# start_index: 851168, end_index: 851200
# Epoch [26600/---], Loss: 0.2040, Accuracy: 0.9125
# start_index: 852768, end_index: 852800
# Epoch [26650/---], Loss: 0.1377, Accuracy: 0.9375
# Reached end of training data.
# Training finished.

# %%
# Training graphs
plot_metric(losses, step_size=50, metric_name='Speaker Listener Loss', save_path='speaker_loss.png')
plot_metric(accuracies, step_size=50, metric_name='Speaker Listener Accuracy', save_path='speaker_accuracy.png')
# Out:
# Plot saved to speaker_loss.png
# Plot saved to speaker_accuracy.png

# %% [markdown]
# ### Inference

# %%
print("\n--- Running a test example ---")

# Set model to evaluation mode
model.eval() 
with torch.no_grad():
    W_test, X_test_mask = dataset_splits['speaker_listener']['W'][0:1], dataset_splits['speaker_listener']['X_mask'][0:1]

    # dummy data
    # generate_batch(1, WORLD_SIZE)
    
    print("Test World W has 5 objects.")
    print(f"Target set X is selected by mask: {X_test_mask[0]}")
    
    
    y_test_logits, y_test_labels = model(W_test, X_test_mask)
    y_test_probs  = torch.sigmoid(y_test_logits)

    print(f"Ground truth vector: {y_test_labels.numpy().flatten()}")
    
    print(f"Model prediction (probabilities): {y_test_probs.numpy().flatten()}")
    print(f"Final prediction (rounded): {[round(p, 2) for p in y_test_probs.numpy().flatten()]}")
# Out:
# --- Running a test example ---
# Test World W has 5 objects.
# Target set X is selected by mask: tensor([0., 1., 1., 1., 1.])
# Ground truth vector: [1. 1. 1. 1. 0.]
# Model prediction (probabilities): [9.5294100e-01 9.9999976e-01 9.5724666e-01 1.0000000e+00 2.3415541e-07]
# Final prediction (rounded): [np.float32(0.95), np.float32(1.0), np.float32(0.96), np.float32(1.0), np.float32(0.0)]

# %%
# Sense check by testing the speaker-listener on translator data

# %% [markdown]
# ## The Translator

# %% [markdown]
# ### Prepare Translator Data

# %%
   print(dataset_splits['translator_train']['rule_texts'][0:10])
# Out:
# ['green and triangle' 'not square' 'purple or square'
#  'triangle or slim-outline' 'circle' 'red and circle' 'slim-outline'
#  'not thick-outline' 'square' 'red and circle']

# %%
# load the translator training data 

# convert rules to token sequences

# %% [markdown]
# ### Training

# %%
# run the speaker-listener model and collect neuralese representation V

# batch the data (V, rule_tokens)

# loss

# backward and optimize

# %% [markdown]
# ### Inference
